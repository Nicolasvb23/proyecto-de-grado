# %% [markdown]
# En esta pagina de gub.uy se exponen algunos ejemplos de endpoints para interactuar con el catalogo de datos implementado en CKAN:
#
# https://catalogodatos.gub.uy/es/api/1/util/snippet/api_info.html?resource_id=dec0a55d-1d86-4100-88ec-fc8dad06a363&datastore_root_url=https%3A%2F%2Fcatalogodatos.gub.uy%2Fapi%2Faction
#
# Aunque solo muestran endpoints para crear, actualizar y mostrar recursos, sabemos que por estar implementado en CKAN hay más.
# https://docs.ckan.org/en/2.9/api/#api-examples
#
# La idea de este collab es tener a mano que obtenemos con cada ruta e indagar un poco más en las funcionalidades que nos proveé CKAN. Es importante tener en cuenta que para acciones de creación ó actualización, se requiere de una cookie que nos identifique y autorice, por lo tanto vamos a reducirnos unicamente a hacer GETs.

# %%
# !pip install requests

import urllib.request
import json
import requests
import os
from google.colab import files

endpoint_prefix = "https://catalogodatos.gub.uy/es/api/3/action/"
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.1.31)

# %%
def do_get_request(url):
  with urllib.request.urlopen(url) as response:
    data = response.read().decode('utf-8')
    return json.loads(data)

def build_url(suffix):
  return endpoint_prefix + suffix

def pretty_print_json(loaded_json):
  print(json.dumps(loaded_json, indent=2, ensure_ascii=False))

# %%
# Package Search
#
# En CKAN, un package es la unidad de organización y gestión de datos de recursos.
# Buscando un package, obtenemos tanto los tags que lo describen, como el link
# a los enlaces de descarga de todos los recursos y además la descripción de que
# abarca el mismo.
endpoint_suffix = 'package_search?fq=tags:"Transparencia+activa"'
url = build_url(endpoint_suffix)

pretty_print_json(do_get_request(url))
# Out:
# {
#   "help": "https://catalogodatos.gub.uy/es/api/3/action/help_show?name=package_search",
#   "success": true,
#   "result": {
#     "count": 132,
#     "facets": {},
#     "results": [
#       {
#         "author": "Secretaría General",
#         "author_email": "sgeneral@bcu.gub.uy",
#         "creator_user_id": "ce41e1d7-fa6f-4ba2-b716-50edba1c0e10",
#         "id": "219bf63c-29e1-4e1a-b4ab-85eb4508990e",
#         "isopen": true,
#         "license_id": "odc-uy",
#         "license_title": "Licencia de DAG de Uruguay",
#         "license_url": "https://www.gub.uy/agencia-gobierno-electronico-sociedad-informacion-conocimiento/sites/agencia-gobierno-electronico-sociedad-informacion-conocimiento/files/documentos/publicaciones/licencia_de_datos_abiertos_0.pdf",
#         "maintainer": "Secretaría General",
#         "maintainer_email": "sgeneral@bcu.gub.uy",
#         "metadata_created": "2020-10-05T18:04:31.353790",
#         "metadata_modified": "2025-01-24T14:01:12.811859",
#         "name": "banco-central-del-uruguay-resoluciones",
#         "notes": "Datos de resoluciones y otros dictámenes que emanen de la máxima jerarquía del Organismo (jerarca, sesiones de comisión, de directorio, de plenario, de asamblea, etc.)",
#         "num_resources": 4,
#         "num_tags": 4,
#         "organization": {
#           "id": "9c5ad6c0-3a7a-48ae-ab0c-3a22844ad037",
#           "name": "banco-central-del-uruguay",
#           "title": "Banco Central del Uruguay",
#           "type": "organization",
#           "description": "El BCU fue creado en 1967. Tiene autonomía técnica, administrativa y financiera en los términos de la Constitución de la República y de la Carta Orgánica.\r\nSus principales finalidades son la estabilidad de precios y la regulación y supervisión del sistema financiero y del sistema de pagos.",
#           "image_url": "2019-08-29-150224.894071BCU.jpg",
#           "created": "2019-08-29T12:02:24.922671",
#           "is_organization": true,
#           "approval_status": "approved",
#           "state": "active"
#         },
#         "owner_org": "9c5ad6c0-3a7a-48ae-ab0c-3a22844ad037",
#         "private": false,
#         "state": "active",
#         "title": "Resoluciones de Directorio",
#         "type": "dataset",
#         "update_frequency": "30",
#         "url": "https://www.bcu.gub.uy/Acerca-de-BCU/Paginas/Resoluciones-de-Directorio.aspx",
#         "version": "2.0",
#         "groups": [
#           {
#             "description": "",
#             "display_name": "Transparencia",
#             "id": "8552e8e2-e342-43fe-ab27-4e3c50564f9b",
#             "image_display_url": "https://catalogodatos.gub.uy/uploads/group/2019-08-22-234010.387437transparencia.png",
#             "name": "transparencia",
#             "title": "Transparencia"
#           }
#         ],
#         "resources": [
#           {
#             "cache_last_updated": null,
#             "cache_url": null,
#             "created": "2022-09-22T16:03:44.241366",
#             "datastore_active": false,
#             "description": "Datos descriptivos de las resoluciones ",
#             "format": "JSON",
#             "hash": "",
#             "id": "df944828-f8a8-44b6-b947-1951cc2a17fd",
#             "last_modified": "2025-01-24T14:01:12.767274",
#             "licence": "Licencia de DAG de Uruguay",
#             "metadata_modified": "2025-01-24T14:01:12.830822",
#             "mimetype": "application/json",
#             "mimetype_inner": null,
#             "name": "Metadatos de resoluciones",
#             "package_id": "219bf63c-29e1-4e1a-b4ab-85eb4508990e",
#             "position": 0,
#             "resource_type": null,
#             "size": 2972,
#             "spatial_coverage": "Uruguay",
#             "state": "active",
#             "temporal_coverage": "2019-01 - 2023-09",
#             "update_frequency": "30",
#             "url": "https://catalogodatos.gub.uy/dataset/219bf63c-29e1-4e1a-b4ab-85eb4508990e/resource/df944828-f8a8-44b6-b947-1951cc2a17fd/download/metadatos_resoluciones.json",
#             "url_type": "upload"
#           },
#           {
#             "cache_last_updated": null,
#             "cache_url": null,
#             "created": "2022-09-22T16:03:47.564267",
#             "datastore_active": true,
#             "description": "Este recurso contiene los datos de las resoluciones del Banco Central del Uruguay",
#             "format": "CSV",
#             "hash": "",
#             "id": "74c06e9d-a1e2-4104-bb4c-09e89cc9096d",
#             "last_modified": "2025-01-24T14:01:09.759383",
#             "licence": "Licencia de DAG de Uruguay",
#             "metadata_modified": "2025-01-24T14:01:09.810234",
#             "mimetype": "text/csv",
#             "mimetype_inner": null,
#             "name": "Resoluciones",
#             "package_id": "219bf63c-29e1-4e1a-b4ab-85eb4508990e",
#             "position": 1,
#             "resource_type": null,
#             "size": 777563,
#             "spatial_coverage": "Uruguay",
#             "state": "active",
#             "temporal_coverage": "2019-01 - 2023-09",
#             "update_frequency": "30",
#             "url": "https://catalogodatos.gub.uy/dataset/219bf63c-29e1-4e1a-b4ab-85eb4508990e/resource/74c06e9d-a1e2-4104-bb4c-09e89cc9096d/download/resoluciones.csv",
#             "url_type": "upload"
#           },
#           {
#             "cache_last_updated": null,
#             "cache_url": null,
#             "created": "2022-09-22T16:03:52.297395",
#             "datastore_active": true,
#             "description": "Este recurso contiene los datos de las resoluciones del Banco Central del Uruguay",
#             "format": "XLSX",
#             "hash": "",
#             "id": "fc9cc1c6-125f-48c5-a752-bab940b5d464",
#             "last_modified": "2025-01-24T14:01:08.626078",
#             "licence": "Licencia de DAG de Uruguay",
#             "metadata_modified": "2025-01-24T14:01:08.677880",
#             "mimetype": "application/vnd.openxmlformats-officedocument.spreadsheetml.sheet",
#             "mimetype_inner": null,
#             "name": "Resoluciones",
#             "package_id": "219bf63c-29e1-4e1a-b4ab-85eb4508990e",
#             "position": 2,
#             "resource_type": null,
#             "size": 313024,
#             "spatial_coverage": "Uruguay",
#             "state": "active",
#             "temporal_coverage": "2019-01 - 2023-09",
#             "update_frequency": "30",
#             "url": "https://catalogodatos.gub.uy/dataset/219bf63c-29e1-4e1a-b4ab-85eb4508990e/resource/fc9cc1c6-125f-48c5-a752-bab940b5d464/download/resoluciones.xlsx",
#             "url_type": "upload"
#           },
#           {
#             "cache_last_updated": null,
#             "cache_url": null,
#             "created": "2022-09-22T16:03:56.807970",
#             "datastore_active": false,
#             "description": "Este recurso contiene los datos de las resoluciones del Banco Central del Uruguay",
#             "format": "XML",
#             "hash": "",
#             "id": "8a3aefe6-5d0a-446b-8a63-4a069cc0f5d0",
#             "last_modified": "2025-01-24T14:01:11.889489",
#             "licence": "Licencia de DAG de Uruguay",
#             "metadata_modified": "2025-01-24T14:01:11.978516",
#             "mimetype": "application/xml",
#             "mimetype_inner": null,
#             "name": "Resoluciones",
#             "package_id": "219bf63c-29e1-4e1a-b4ab-85eb4508990e",
#             "position": 3,
#             "resource_type": null,
#             "size": 1579879,
#             "spatial_coverage": "Uruguay",
#             "state": "active",
#             "temporal_coverage": "2019-01 - 2023-09",
#             "update_frequency": "30",
#             "url": "https://catalogodatos.gub.uy/dataset/219bf63c-29e1-4e1a-b4ab-85eb4508990e/resource/8a3aefe6-5d0a-446b-8a63-4a069cc0f5d0/download/resoluciones.xml",
#             "url_type": "upload"
#           }
#         ],
#         "tags": [
#           {
#             "display_name": "Banco Central",
#             "id": "07200105-fe02-4b0b-b92a-17d36f0935d5",
#             "name": "Banco Central",
#             "state": "active",
#             "vocabulary_id": null
#           },
#           {
#             "display_name": "Banco Central del Uruguay",
#             "id": "bfbd18ad-a04e-4a0a-b592-49a1fd813cd1",
#             "name": "Banco Central del Uruguay",
#             "state": "active",
#             "vocabulary_id": null
#           },
#           {
#             "display_name": "Resoluciones",
#             "id": "1e764f01-7be3-40f0-bcc7-9c40deb65733",
#             "name": "Resoluciones",
#             "state": "active",
#             "vocabulary_id": null
#           },
#           {
#             "display_name": "Transparencia activa",
#             "id": "7cd56379-e4bb-44e4-9a3e-7ea87fda3d2f",
#             "name": "Transparencia activa",
#             "state": "active",
#             "vocabulary_id": null
#           }
#         ],
#         "relationships_as_subject": [],
#         "relationships_as_object": []
#       },
#       {
#         "author": "Secretaria General",
#         "author_email": "sgeneral@bcu.gub.uy",
#         "creator_user_id": "ce41e1d7-fa6f-4ba2-b716-50edba1c0e10",
#         "id": "6dd983f9-6973-4cf9-aac0-476d3fb6f330",
#         "isopen": true,
#         "license_id": "odc-uy",
#         "license_title": "Licencia de DAG de Uruguay",
#         "license_url": "https://www.gub.uy/agencia-gobierno-electronico-sociedad-informacion-conocimiento/sites/agencia-gobierno-electronico-sociedad-informacion-conocimiento/files/documentos/publicaciones/licencia_de_datos_abiertos_0.pdf",
#         "maintainer": "Secretaria General",
#         "maintainer_email": "sgeneral@bcu.gub.uy",
#         "metadata_created": "2020-10-05T19:59:21.002271",
#         "metadata_modified": "2025-01-24T14:00:24.060105",
#         "name": "banco-central-del-uruguay-diario_sesiones",
#         "notes": "Información sobre lo acontecido en las distintas sesiones.",
#         "num_resources": 4,
#         "num_tags": 5,
#         "organization": {
#           "id": "9c5ad6c0-3a7a-48ae-ab0c-3a22844ad037",
#           "name": "banco-central-del-uruguay",
#           "title": "Banco Central del Uruguay",
#           "type": "organization",
#           "description": "El BCU fue creado en 1967. Tiene autonomía técnica, administrativa y financiera en los términos de la Constitución de la República y de la Carta Orgánica.\r\nSus principales finalidades son la estabilidad de precios y la regulación y supervisión del sistema financiero y del sistema de pagos.",
#           "image_url": "2019-08-29-150224.894071BCU.jpg",
#           "created": "2019-08-29T12:02:24.922671",
#           "is_organization": true,
#           "approval_status": "approved",
#           "state": "active"
#         },
#         "owner_org": "9c5ad6c0-3a7a-48ae-ab0c-3a22844ad037",
#         "private": false,
#         "state": "active",
#         "title": "Diario de sesiones",
#         "type": "dataset",
#         "update_frequency": "30",
#         "url": "https://www.bcu.gub.uy/Acerca-de-BCU/Paginas/Actas_Directorio.aspx",
#         "version": "2.0",
#         "groups": [
#           {
#             "description": "",
#             "display_name": "Transparencia",
#             "id": "8552e8e2-e342-43fe-ab27-4e3c50564f9b",
#             "image_display_url": "https://catalogodatos.gub.uy/uploads/group/2019-08-22-234010.387437transparencia.png",
#             "name": "transparencia",
#             "title": "Transparencia"
#           }
#         ],
#         "resources": [
#           {
#             "cache_last_updated": null,
#             "cache_url": null,
#             "created": "2022-07-29T13:33:14.445981",
#             "datastore_active": false,
#             "description": "Datos descriptivos del diario de sesiones",
#             "format": "JSON",
#             "hash": "",
#             "id": "1538d01c-6127-4c83-9f99-4442c11ff9f6",
#             "last_modified": "2025-01-24T14:00:24.030533",
#             "licence": "Licencia de DAG de Uruguay",
#             "metadata_modified": "2025-01-24T14:00:24.073142",
#             "mimetype": "application/json",
#             "mimetype_inner": null,
#             "name": "Metadatos de diario de sesiones",
#             "package_id": "6dd983f9-6973-4cf9-aac0-476d3fb6f330",
#             "position": 0,
#             "resource_type": null,
#             "size": 3239,
#             "spatial_coverage": "Uruguay",
#             "state": "active",
#             "temporal_coverage": "2019-01 - 2023-09",
#             "update_frequency": "30",
#             "url": "https://catalogodatos.gub.uy/dataset/6dd983f9-6973-4cf9-aac0-476d3fb6f330/resource/1538d01c-6127-4c83-9f99-4442c11ff9f6/download/metadatos_diario-sesiones.json",
#             "url_type": "upload"
#           },
#           {
#             "cache_last_updated": null,
#             "cache_url": null,
#             "created": "2022-07-29T13:33:17.134161",
#             "datastore_active": true,
#             "description": "Este recurso contiene los datos de los diarios de sesiones del Banco Central del Uruguay",
#             "format": "CSV",
#             "hash": "",
#             "id": "68f769bd-bee0-44a8-b09c-2513cd6e0ffa",
#             "last_modified": "2025-01-24T14:00:22.326631",
#             "licence": "Licencia de DAG de Uruguay",
#             "metadata_modified": "2025-01-24T14:00:22.374192",
#             "mimetype": "text/csv",
#             "mimetype_inner": null,
#             "name": "Diario de sesiones",
#             "package_id": "6dd983f9-6973-4cf9-aac0-476d3fb6f330",
#             "position": 1,
#             "resource_type": null,
#             "size": 87356,
#             "spatial_coverage": "Uruguay",
#             "state": "active",
#             "temporal_coverage": "2019-01 - 2023-09",
#             "update_frequency": "30",
#             "url": "https://catalogodatos.gub.uy/dataset/6dd983f9-6973-4cf9-aac0-476d3fb6f330/resource/68f769bd-bee0-44a8-b09c-2513cd6e0ffa/download/diario-sesiones.csv",
#             "url_type": "upload"
#           },
#           {
#             "cache_last_updated": null,
#             "cache_url": null,
#             "created": "2022-07-29T13:33:20.226948",
#             "datastore_active": true,
#             "description": "Este recurso contiene los datos de los diarios de sesiones del Banco Central del Uruguay",
#             "format": "XLSX",
#             "hash": "",
#             "id": "e3402839-0d73-4415-b11c-55b406198e42",
#             "last_modified": "2025-01-24T14:00:21.514486",
#             "licence": "Licencia de DAG de Uruguay",
#             "metadata_modified": "2025-01-24T14:00:21.562131",
#             "mimetype": "application/vnd.openxmlformats-officedocument.spreadsheetml.sheet",
#             "mimetype_inner": null,
#             "name": "Diario de sesiones",
#             "package_id": "6dd983f9-6973-4cf9-aac0-476d3fb6f330",
#             "position": 2,
#             "resource_type": null,
#             "size": 48702,
#             "spatial_coverage": "Uruguay",
#             "state": "active",
#             "temporal_coverage": "2019-01 - 2023-09",
#             "update_frequency": "30",
#             "url": "https://catalogodatos.gub.uy/dataset/6dd983f9-6973-4cf9-aac0-476d3fb6f330/resource/e3402839-0d73-4415-b11c-55b406198e42/download/diario-sesiones.xlsx",
#             "url_type": "upload"
#           },
#           {
#             "cache_last_updated": null,
#             "cache_url": null,
#             "created": "2022-07-29T13:33:23.354368",
#             "datastore_active": false,
#             "description": "Este recurso contiene los datos de los diarios de sesiones del Banco Central del Uruguay",
#             "format": "XML",
#             "hash": "",
#             "id": "a9e35151-22c5-4630-a831-c1acc21387a5",
#             "last_modified": "2025-01-24T14:00:23.161134",
#             "licence": "Licencia de DAG de Uruguay",
#             "metadata_modified": "2025-01-24T14:00:23.208143",
#             "mimetype": "application/xml",
#             "mimetype_inner": null,
#             "name": "Diario de sesiones",
#             "package_id": "6dd983f9-6973-4cf9-aac0-476d3fb6f330",
#             "position": 3,
#             "resource_type": null,
#             "size": 202164,
#             "spatial_coverage": "Uruguay",
#             "state": "active",
#             "temporal_coverage": "2019-01 - 2023-09",
#             "update_frequency": "30",
#             "url": "https://catalogodatos.gub.uy/dataset/6dd983f9-6973-4cf9-aac0-476d3fb6f330/resource/a9e35151-22c5-4630-a831-c1acc21387a5/download/diario-sesiones.xml",
#             "url_type": "upload"
#           }
#         ],
#         "tags": [
#           {
#             "display_name": "BCU",
#             "id": "b9ebb544-100b-4ce1-9c78-7c21e9e78818",
#             "name": "BCU",
#             "state": "active",
#             "vocabulary_id": null
#           },
#           {
#             "display_name": "Banco Central del Uruguay",
#             "id": "bfbd18ad-a04e-4a0a-b592-49a1fd813cd1",
#             "name": "Banco Central del Uruguay",
#             "state": "active",
#             "vocabulary_id": null
#           },
#           {
#             "display_name": "Diario",
#             "id": "73e0c021-ad6d-4e80-8114-1e6389534de7",
#             "name": "Diario",
#             "state": "active",
#             "vocabulary_id": null
#           },
#           {
#             "display_name": "Diario de sesiones",
#             "id": "8f9e08b6-ff5c-49ce-b93f-e3e59e8feac9",
#             "name": "Diario de sesiones",
#             "state": "active",
#             "vocabulary_id": null
#           },
#           {
#             "display_name": "Transparencia activa",
#             "id": "7cd56379-e4bb-44e4-9a3e-7ea87fda3d2f",
#             "name": "Transparencia activa",
#             "state": "active",
#             "vocabulary_id": null
#           }
#         ],
#         "relationships_as_subject": [],
#         "relationships_as_object": []
#       },
#       {
#         "author": "Secretaría General",
#         "author_email": "sgeneral@bcu.gub.uy",
#         "creator_user_id": "ce41e1d7-fa6f-4ba2-b716-50edba1c0e10",
#         "id": "ecd6edcc-ec34-4e18-9d99-b02763570259",
#         "isopen": true,
#         "license_id": "odc-uy",
#         "license_title": "Licencia de DAG de Uruguay",
#         "license_url": "https://www.gub.uy/agencia-gobierno-electronico-sociedad-informacion-conocimiento/sites/agencia-gobierno-electronico-sociedad-informacion-conocimiento/files/documentos/publicaciones/licencia_de_datos_abiertos_0.pdf",
#         "maintainer": "Secretaría General",
#         "maintainer_email": "sgeneral@bcu.gub.uy",
#         "metadata_created": "2019-11-22T13:00:19.977210",
#         "metadata_modified": "2025-01-24T13:59:45.608939",
#         "name": "banco-central-del-uruguay-calendario_reuniones",
#         "notes": "Calendario de reuniones del Banco Central del Uruguay",
#         "num_resources": 4,
#         "num_tags": 4,
#         "organization": {
#           "id": "9c5ad6c0-3a7a-48ae-ab0c-3a22844ad037",
#           "name": "banco-central-del-uruguay",
#           "title": "Banco Central del Uruguay",
#           "type": "organization",
#           "description": "El BCU fue creado en 1967. Tiene autonomía técnica, administrativa y financiera en los términos de la Constitución de la República y de la Carta Orgánica.\r\nSus principales finalidades son la estabilidad de precios y la regulación y supervisión del sistema financiero y del sistema de pagos.",
#           "image_url": "2019-08-29-150224.894071BCU.jpg",
#           "created": "2019-08-29T12:02:24.922671",
#           "is_organization": true,
#           "approval_status": "approved",
#           "state": "active"
#         },
#         "owner_org": "9c5ad6c0-3a7a-48ae-ab0c-3a22844ad037",
#         "private": false,
#         "state": "active",
#         "title": "Calendario de reuniones del Banco Central del Uruguay",
#         "type": "dataset",
#         "update_frequency": "30",
#         "url": "https://www.bcu.gub.uy/Acerca-de-BCU/Paginas/Orden_Directorio.aspx",
#         "version": "2.0",
#         "groups": [
#           {
#             "description": "",
#             "display_name": "Transparencia",
#             "id": "8552e8e2-e342-43fe-ab27-4e3c50564f9b",
#             "image_display_url": "https://catalogodatos.gub.uy/uploads/group/2019-08-22-234010.387437transparencia.png",
#             "name": "transparencia",
#             "title": "Transparencia"
#           }
#         ],
#         "resources": [
#           {
#             "cache_last_updated": null,
#             "cache_url": null,
#             "created": "2022-07-29T13:32:27.450376",
#             "datastore_active": false,
#             "description": "Datos descriptivos del calendario de reuniones",
#             "format": "JSON",
#             "hash": "",
#             "id": "34eebe8e-a96d-4273-b499-9d0e03e02f3e",
#             "last_modified": "2025-01-24T13:59:45.575685",
#             "licence": "Licencia de DAG de Uruguay",
#             "metadata_modified": "2025-01-24T13:59:45.626688",
#             "mimetype": "application/json",
#             "mimetype_inner": null,
#             "name": "Metadatos de calendario de reuniones",
#             "package_id": "ecd6edcc-ec34-4e18-9d99-b02763570259",
#             "position": 0,
#             "resource_type": null,
#             "size": 3609,
#             "spatial_coverage": "Uruguay",
#             "state": "active",
#             "temporal_coverage": "2019-01 - 2023-09",
#             "update_frequency": "30",
#             "url": "https://catalogodatos.gub.uy/dataset/ecd6edcc-ec34-4e18-9d99-b02763570259/resource/34eebe8e-a96d-4273-b499-9d0e03e02f3e/download/metadatos_calendario_reuniones.json",
#             "url_type": "upload"
#           },
#           {
#             "cache_last_updated": null,
#             "cache_url": null,
#             "created": "2022-07-29T13:32:33.106943",
#             "datastore_active": true,
#             "description": "Este recuso contiene el calendario de reuniones del Banco Central del Uruguay",
#             "format": "CSV",
#             "hash": "",
#             "id": "cc318596-395f-45d2-bfa5-e0ef6a58af1b",
#             "last_modified": "2025-01-24T13:59:44.120945",
#             "licence": "Licencia de DAG de Uruguay",
#             "metadata_modified": "2025-01-24T13:59:45.626859",
#             "mimetype": "text/csv",
#             "mimetype_inner": null,
#             "name": "Calendario de reuniones",
#             "package_id": "ecd6edcc-ec34-4e18-9d99-b02763570259",
#             "position": 1,
#             "resource_type": null,
#             "size": 112889,
#             "spatial_coverage": "Uruguay",
#             "state": "active",
#             "temporal_coverage": "2019-01 - 2023-09",
#             "update_frequency": "30",
#             "url": "https://catalogodatos.gub.uy/dataset/ecd6edcc-ec34-4e18-9d99-b02763570259/resource/cc318596-395f-45d2-bfa5-e0ef6a58af1b/download/calendario_reuniones.csv",
#             "url_type": "upload"
#           },
#           {
#             "cache_last_updated": null,
#             "cache_url": null,
#             "created": "2022-07-29T13:32:37.853600",
#             "datastore_active": true,
#             "description": "Este recuso contiene el calendario de reuniones del Banco Central del Uruguay",
#             "format": "XLSX",
#             "hash": "",
#             "id": "c6bb2a32-937b-4a4e-9c12-1031553e38a3",
#             "last_modified": "2025-01-24T13:59:43.460555",
#             "licence": "Licencia de DAG de Uruguay",
#             "metadata_modified": "2025-01-24T13:59:43.511930",
#             "mimetype": "application/vnd.openxmlformats-officedocument.spreadsheetml.sheet",
#             "mimetype_inner": null,
#             "name": "Calendario de reuniones",
#             "package_id": "ecd6edcc-ec34-4e18-9d99-b02763570259",
#             "position": 2,
#             "resource_type": null,
#             "size": 52990,
#             "spatial_coverage": "Uruguay",
#             "state": "active",
#             "temporal_coverage": "2019-01 - 2023-09",
#             "update_frequency": "30",
#             "url": "https://catalogodatos.gub.uy/dataset/ecd6edcc-ec34-4e18-9d99-b02763570259/resource/c6bb2a32-937b-4a4e-9c12-1031553e38a3/download/calendario_reuniones.xlsx",
#             "url_type": "upload"
#           },
#           {
#             "cache_last_updated": null,
#             "cache_url": null,
#             "created": "2022-07-29T13:32:42.567078",
#             "datastore_active": false,
#             "description": "Este recuso contiene el calendario de reuniones del Banco Central del Uruguay",
#             "format": "XML",
#             "hash": "",
#             "id": "7bee4c9f-f0e5-4aa6-a8d6-8bc0ed3b1302",
#             "last_modified": "2025-01-24T13:59:45.044795",
#             "licence": "Licencia de DAG de Uruguay",
#             "metadata_modified": "2025-01-24T13:59:45.081589",
#             "mimetype": "application/xml",
#             "mimetype_inner": null,
#             "name": "Calendario de reuniones",
#             "package_id": "ecd6edcc-ec34-4e18-9d99-b02763570259",
#             "position": 3,
#             "resource_type": null,
#             "size": 253585,
#             "spatial_coverage": "Uruguay",
#             "state": "active",
#             "temporal_coverage": "2019-01 - 2023-09",
#             "update_frequency": "30",
#             "url": "https://catalogodatos.gub.uy/dataset/ecd6edcc-ec34-4e18-9d99-b02763570259/resource/7bee4c9f-f0e5-4aa6-a8d6-8bc0ed3b1302/download/calendario_reuniones.xml",
#             "url_type": "upload"
#           }
#         ],
#         "tags": [
#           {
#             "display_name": "BCU",
#             "id": "b9ebb544-100b-4ce1-9c78-7c21e9e78818",
#             "name": "BCU",
#             "state": "active",
#             "vocabulary_id": null
#           },
#           {
#             "display_name": "Banco Central del Uruguay",
#             "id": "bfbd18ad-a04e-4a0a-b592-49a1fd813cd1",
#             "name": "Banco Central del Uruguay",
#             "state": "active",
#             "vocabulary_id": null
#           },
#           {
#             "display_name": "Calendario",
#             "id": "c122938b-722c-48f8-9216-ad194d0ac822",
#             "name": "Calendario",
#             "state": "active",
#             "vocabulary_id": null
#           },
#           {
#             "display_name": "Transparencia activa",
#             "id": "7cd56379-e4bb-44e4-9a3e-7ea87fda3d2f",
#             "name": "Transparencia activa",
#             "state": "active",
#             "vocabulary_id": null
#           }
#         ],
#         "relationships_as_subject": [],
#         "relationships_as_object": []
#       },
#       {
#         "author": "Gestión Humana",
#         "author_email": "datos.abiertos@imcanelones.gub.uy",
#         "creator_user_id": "ecee534f-a475-4f7a-8bfd-86e422a8d0b1",
#         "id": "08ba88cd-4e71-4694-b140-2d846f444258",
#         "isopen": true,
#         "license_id": "odc-uy",
#         "license_title": "Licencia de DAG de Uruguay",
#         "license_url": "https://www.gub.uy/agencia-gobierno-electronico-sociedad-informacion-conocimiento/sites/agencia-gobierno-electronico-sociedad-informacion-conocimiento/files/documentos/publicaciones/licencia_de_datos_abiertos_0.pdf",
#         "maintainer": "Unidad de Transparencia y Datos Personales",
#         "maintainer_email": "datos.abiertos@imcanelones.gub.uy",
#         "metadata_created": "2023-07-24T19:11:07.637800",
#         "metadata_modified": "2025-01-20T16:43:36.817821",
#         "name": "intendencia-de-canelones-remuneraciones",
#         "notes": "Este conjunto cuenta con información sobre el sistema de remuneraciones de los funcionarios del organismo. Se pubica de forma semestral consecuentemente a los ajustes salariales (enero-julio).",
#         "num_resources": 4,
#         "num_tags": 2,
#         "organization": {
#           "id": "fd498770-9ba4-4c73-9eb2-ba69d9c6af2c",
#           "name": "intendencia-de-canelones",
#           "title": "Intendencia de Canelones",
#           "type": "organization",
#           "description": "Ejerce las funciones ejecutivas del Gobierno Departamental de Canelones. Fue creada por Ley 3.417 de 18 de diciembre de 1908 y sus funciones están mayormente reguladas por la Ley 9.515 de 28 de julio de 1935.",
#           "image_url": "2023-04-11-191756.468405Logo.png",
#           "created": "2023-04-11T16:17:56.487703",
#           "is_organization": true,
#           "approval_status": "approved",
#           "state": "active"
#         },
#         "owner_org": "fd498770-9ba4-4c73-9eb2-ba69d9c6af2c",
#         "private": false,
#         "state": "active",
#         "title": "Remuneraciones",
#         "type": "dataset",
#         "update_frequency": "182",
#         "url": "",
#         "version": "1.3",
#         "groups": [
#           {
#             "description": "",
#             "display_name": "Transparencia",
#             "id": "8552e8e2-e342-43fe-ab27-4e3c50564f9b",
#             "image_display_url": "https://catalogodatos.gub.uy/uploads/group/2019-08-22-234010.387437transparencia.png",
#             "name": "transparencia",
#             "title": "Transparencia"
#           }
#         ],
#         "resources": [
#           {
#             "cache_last_updated": null,
#             "cache_url": null,
#             "created": "2023-07-24T19:11:09.351484",
#             "datastore_active": false,
#             "description": "Este recurso contiene los datos de las remuneraciones del organismo",
#             "format": "XLSX",
#             "hash": "",
#             "id": "b0b1fc95-ac2b-401c-98ae-4206c97a0470",
#             "last_modified": "2025-01-20T16:43:34.599250",
#             "licence": "Licencia de DAG de Uruguay",
#             "metadata_modified": "2025-01-20T16:43:34.648905",
#             "mimetype": "application/vnd.openxmlformats-officedocument.spreadsheetml.sheet",
#             "mimetype_inner": null,
#             "name": "Remuneraciones del organismo",
#             "package_id": "08ba88cd-4e71-4694-b140-2d846f444258",
#             "position": 0,
#             "resource_type": null,
#             "size": 49833,
#             "spatial_coverage": "Uruguay",
#             "state": "active",
#             "temporal_coverage": "2023 - 2024 - 2025",
#             "update_frequency": "182",
#             "url": "https://catalogodatos.gub.uy/dataset/08ba88cd-4e71-4694-b140-2d846f444258/resource/b0b1fc95-ac2b-401c-98ae-4206c97a0470/download/remuneraciones-del-organismo.xlsx",
#             "url_type": "upload"
#           },
#           {
#             "cache_last_updated": null,
#             "cache_url": null,
#             "created": "2023-07-24T19:11:10.308569",
#             "datastore_active": true,
#             "description": "Este recurso contiene los datos de las remuneraciones del organismo",
#             "format": "CSV",
#             "hash": "",
#             "id": "5aea8c41-0500-4d68-ba11-ea7e8e7d02db",
#             "last_modified": "2025-01-20T16:43:35.194447",
#             "licence": "Licencia de DAG de Uruguay",
#             "metadata_modified": "2025-01-20T16:43:36.842811",
#             "mimetype": "text/csv",
#             "mimetype_inner": null,
#             "name": "Remuneraciones del organismo",
#             "package_id": "08ba88cd-4e71-4694-b140-2d846f444258",
#             "position": 1,
#             "resource_type": null,
#             "size": 146289,
#             "spatial_coverage": "Uruguay",
#             "state": "active",
#             "temporal_coverage": "2023 - 2024 - 2025",
#             "update_frequency": "182",
#             "url": "https://catalogodatos.gub.uy/dataset/08ba88cd-4e71-4694-b140-2d846f444258/resource/5aea8c41-0500-4d68-ba11-ea7e8e7d02db/download/remuneraciones-del-organismo.csv",
#             "url_type": "upload"
#           },
#           {
#             "cache_last_updated": null,
#             "cache_url": null,
#             "created": "2023-07-24T19:11:11.144318",
#             "datastore_active": false,
#             "description": "Este recurso contiene los datos de las remuneraciones del organismo",
#             "format": "XML",
#             "hash": "",
#             "id": "df05a1b9-efe3-4028-8d2f-2b4f2694bde4",
#             "last_modified": "2025-01-20T16:43:36.157622",
#             "licence": "Licencia de DAG de Uruguay",
#             "metadata_modified": "2025-01-20T16:43:36.201290",
#             "mimetype": "application/xml",
#             "mimetype_inner": null,
#             "name": "Remuneraciones del organismo",
#             "package_id": "08ba88cd-4e71-4694-b140-2d846f444258",
#             "position": 2,
#             "resource_type": null,
#             "size": 436113,
#             "spatial_coverage": "Uruguay",
#             "state": "active",
#             "temporal_coverage": "2023 - 2024 - 2025",
#             "update_frequency": "182",
#             "url": "https://catalogodatos.gub.uy/dataset/08ba88cd-4e71-4694-b140-2d846f444258/resource/df05a1b9-efe3-4028-8d2f-2b4f2694bde4/download/remuneraciones-del-organismo.xml",
#             "url_type": "upload"
#           },
#           {
#             "cache_last_updated": null,
#             "cache_url": null,
#             "created": "2023-07-24T19:11:11.931458",
#             "datastore_active": false,
#             "description": "Este recurso contiene los datos descriptivos de las remuneraciones del organismo.",
#             "format": "JSON",
#             "hash": "",
#             "id": "5c13ff12-d6d6-42b2-a112-f4811f7a4ad8",
#             "last_modified": "2025-01-20T16:43:36.779250",
#             "licence": "Licencia de DAG de Uruguay",
#             "metadata_modified": "2025-01-20T16:43:36.843051",
#             "mimetype": "application/json",
#             "mimetype_inner": null,
#             "name": "Metadatos de remuneraciones del organismo",
#             "package_id": "08ba88cd-4e71-4694-b140-2d846f444258",
#             "position": 3,
#             "resource_type": null,
#             "size": 3803,
#             "spatial_coverage": "Uruguay",
#             "state": "active",
#             "temporal_coverage": "2023 - 2024 - 2025",
#             "update_frequency": "182",
#             "url": "https://catalogodatos.gub.uy/dataset/08ba88cd-4e71-4694-b140-2d846f444258/resource/5c13ff12-d6d6-42b2-a112-f4811f7a4ad8/download/metadatos_remuneraciones-del-organismo.json",
#             "url_type": "upload"
#           }
#         ],
#         "tags": [
#           {
#             "display_name": "Remuneraciones",
#             "id": "fec921fc-15ee-4af6-bfa2-a67e770be678",
#             "name": "Remuneraciones",
#             "state": "active",
#             "vocabulary_id": null
#           },
#           {
#             "display_name": "Transparencia activa",
#             "id": "7cd56379-e4bb-44e4-9a3e-7ea87fda3d2f",
#             "name": "Transparencia activa",
#             "state": "active",
#             "vocabulary_id": null
#           }
#         ],
#         "relationships_as_subject": [],
#         "relationships_as_object": []
#       },
#       {
#         "author": "Secretaría General",
#         "author_email": "sgeneral@bcu.gub.uy",
#         "creator_user_id": "b1cd472e-d1a1-4c30-9e3c-8c19a58c6b9b",
#         "id": "e97331e3-8a41-4b04-b191-2953b826a452",
#         "isopen": true,
#         "license_id": "odc-uy",
#         "license_title": "Licencia de DAG de Uruguay",
#         "license_url": "https://www.gub.uy/agencia-gobierno-electronico-sociedad-informacion-conocimiento/sites/agencia-gobierno-electronico-sociedad-informacion-conocimiento/files/documentos/publicaciones/licencia_de_datos_abiertos_0.pdf",
#         "maintainer": "Secretaría General",
#         "maintainer_email": "sgeneral@bcu.gub.uy",
#         "metadata_created": "2019-11-04T17:00:45.901684",
#         "metadata_modified": "2025-01-17T18:36:30.046189",
#         "name": "banco-central-del-uruguay-informacion_de_servicios_y_tramites",
#         "notes": "Este conjunto presenta toda la información relevante sobre los tramites y servicios del Banco Central del Uruguay",
#         "num_resources": 4,
#         "num_tags": 6,
#         "organization": {
#           "id": "9c5ad6c0-3a7a-48ae-ab0c-3a22844ad037",
#           "name": "banco-central-del-uruguay",
#           "title": "Banco Central del Uruguay",
#           "type": "organization",
#           "description": "El BCU fue creado en 1967. Tiene autonomía técnica, administrativa y financiera en los términos de la Constitución de la República y de la Carta Orgánica.\r\nSus principales finalidades son la estabilidad de precios y la regulación y supervisión del sistema financiero y del sistema de pagos.",
#           "image_url": "2019-08-29-150224.894071BCU.jpg",
#           "created": "2019-08-29T12:02:24.922671",
#           "is_organization": true,
#           "approval_status": "approved",
#           "state": "active"
#         },
#         "owner_org": "9c5ad6c0-3a7a-48ae-ab0c-3a22844ad037",
#         "private": false,
#         "state": "active",
#         "title": "Listado de trámites y servicios en el Banco Central del Uruguay",
#         "type": "dataset",
#         "update_frequency": "365",
#         "url": "https://www.bcu.gub.uy/Acerca-de-BCU/Paginas/TranspInformPublicada.aspx",
#         "version": "1.0",
#         "groups": [
#           {
#             "description": "",
#             "display_name": "Transparencia",
#             "id": "8552e8e2-e342-43fe-ab27-4e3c50564f9b",
#             "image_display_url": "https://catalogodatos.gub.uy/uploads/group/2019-08-22-234010.387437transparencia.png",
#             "name": "transparencia",
#             "title": "Transparencia"
#           }
#         ],
#         "resources": [
#           {
#             "cache_last_updated": null,
#             "cache_url": null,
#             "created": "2019-11-04T17:00:51.716796",
#             "datastore_active": true,
#             "description": "Este recurso contiene los datos de la información de los servicios y trámites del organismo",
#             "format": "CSV",
#             "hash": "",
#             "id": "df0a032e-93d8-452d-86e0-201a813ded1b",
#             "last_modified": "2025-01-17T18:36:28.478151",
#             "licence": "Licencia de DAG de Uruguay",
#             "metadata_modified": "2025-01-17T18:36:29.466409",
#             "mimetype": "text/csv",
#             "mimetype_inner": null,
#             "name": "Información de servicios y trámites del organismo",
#             "package_id": "e97331e3-8a41-4b04-b191-2953b826a452",
#             "position": 0,
#             "qa": {
#               "resource_timestamp": null,
#               "archival_timestamp": "2022-05-31T07:46:02.216940",
#               "openness_score": 3,
#               "openness_score_reason": "Content of file appeared to be format \"CSV\" which receives openness score: 3.",
#               "format": "CSV",
#               "created": "2019-11-05T07:01:43.658399",
#               "updated": "2022-05-31T11:30:55.128625"
#             },
#             "resource_type": null,
#             "size": 23347,
#             "spatial_coverage": "Uruguay",
#             "state": "active",
#             "temporal_coverage": "202024",
#             "update_frequency": "365",
#             "url": "https://catalogodatos.gub.uy/dataset/e97331e3-8a41-4b04-b191-2953b826a452/resource/df0a032e-93d8-452d-86e0-201a813ded1b/download/servicios_tramites.csv",
#             "url_type": "upload"
#           },
#           {
#             "cache_last_updated": null,
#             "cache_url": null,
#             "created": "2019-11-04T17:00:53.360042",
#             "datastore_active": true,
#             "description": "Este recurso contiene los datos de la información de los servicios y trámites del organismo",
#             "format": "XLSX",
#             "hash": "",
#             "id": "08073a1f-0e70-4aa9-bedb-2367471cb6e4",
#             "last_modified": "2025-01-17T18:36:27.909261",
#             "licence": "Licencia de DAG de Uruguay",
#             "metadata_modified": "2025-01-17T18:36:28.510820",
#             "mimetype": "application/vnd.openxmlformats-officedocument.spreadsheetml.sheet",
#             "mimetype_inner": null,
#             "name": "Información de servicios y trámites del organismo",
#             "package_id": "e97331e3-8a41-4b04-b191-2953b826a452",
#             "position": 1,
#             "qa": {
#               "resource_timestamp": null,
#               "archival_timestamp": "2022-05-31T07:46:03.141043",
#               "openness_score": 2,
#               "openness_score_reason": "Content of file appeared to be format \"XLSX\" which receives openness score: 2.",
#               "format": "XLSX",
#               "created": "2019-11-05T07:01:43.762188",
#               "updated": "2022-05-31T11:30:55.139833"
#             },
#             "resource_type": null,
#             "size": 24856,
#             "spatial_coverage": "Uruguay",
#             "state": "active",
#             "temporal_coverage": "202024",
#             "update_frequency": "365",
#             "url": "https://catalogodatos.gub.uy/dataset/e97331e3-8a41-4b04-b191-2953b826a452/resource/08073a1f-0e70-4aa9-bedb-2367471cb6e4/download/servicios_tramites.xlsx",
#             "url_type": "upload"
#           },
#           {
#             "cache_last_updated": null,
#             "cache_url": null,
#             "created": "2019-11-04T17:00:54.644775",
#             "datastore_active": false,
#             "description": "Este recurso contiene los datos de la información de los servicios y trámites del organismo",
#             "format": "XML",
#             "hash": "",
#             "id": "fee862ef-0db4-4a7c-94d4-42c182891b58",
#             "last_modified": "2025-01-17T18:36:29.413454",
#             "licence": "Licencia de DAG de Uruguay",
#             "metadata_modified": "2025-01-17T18:36:30.057932",
#             "mimetype": "application/xml",
#             "mimetype_inner": null,
#             "name": "Información de servicios y trámites del organismo",
#             "package_id": "e97331e3-8a41-4b04-b191-2953b826a452",
#             "position": 2,
#             "qa": {
#               "resource_timestamp": null,
#               "archival_timestamp": "2022-05-31T07:46:04.172882",
#               "openness_score": 3,
#               "openness_score_reason": "Content of file appeared to be format \"XML\" which receives openness score: 3.",
#               "format": "XML",
#               "created": "2019-11-05T07:01:43.777245",
#               "updated": "2022-05-31T11:30:55.150382"
#             },
#             "resource_type": null,
#             "size": 34811,
#             "spatial_coverage": "Uruguay",
#             "state": "active",
#             "temporal_coverage": "202024",
#             "update_frequency": "365",
#             "url": "https://catalogodatos.gub.uy/dataset/e97331e3-8a41-4b04-b191-2953b826a452/resource/fee862ef-0db4-4a7c-94d4-42c182891b58/download/servicios_tramites.xml",
#             "url_type": "upload"
#           },
#           {
#             "cache_last_updated": null,
#             "cache_url": null,
#             "created": "2019-11-04T17:00:50.182930",
#             "datastore_active": false,
#             "description": "Este recurso contiene la información de los servicios y trámites que pueden realizarse en el Banco Central del Uruguay en forma electrónica\n\n",
#             "format": "JSON",
#             "hash": "",
#             "id": "f6915d30-41d1-4cc3-b178-205915f2254e",
#             "last_modified": "2025-01-17T18:36:30.020051",
#             "licence": "Licencia de DAG de Uruguay",
#             "metadata_modified": "2025-01-17T18:36:30.058023",
#             "mimetype": "application/json",
#             "mimetype_inner": null,
#             "name": "Metadatos de información de servicios y trámites del organismo",
#             "package_id": "e97331e3-8a41-4b04-b191-2953b826a452",
#             "position": 3,
#             "qa": {
#               "resource_timestamp": null,
#               "archival_timestamp": "2022-05-31T07:46:01.368263",
#               "openness_score": 3,
#               "openness_score_reason": "Content of file appeared to be format \"CSV\" which receives openness score: 3.",
#               "format": "CSV",
#               "created": "2019-11-05T07:01:43.620040",
#               "updated": "2022-05-31T11:30:55.088750"
#             },
#             "resource_type": null,
#             "size": 3162,
#             "spatial_coverage": "Uruguay",
#             "state": "active",
#             "temporal_coverage": "202024",
#             "update_frequency": "365",
#             "url": "https://catalogodatos.gub.uy/dataset/e97331e3-8a41-4b04-b191-2953b826a452/resource/f6915d30-41d1-4cc3-b178-205915f2254e/download/metadatos_servicios_tramites.json",
#             "url_type": "upload"
#           }
#         ],
#         "tags": [
#           {
#             "display_name": "BCU",
#             "id": "b9ebb544-100b-4ce1-9c78-7c21e9e78818",
#             "name": "BCU",
#             "state": "active",
#             "vocabulary_id": null
#           },
#           {
#             "display_name": "Banco Central",
#             "id": "07200105-fe02-4b0b-b92a-17d36f0935d5",
#             "name": "Banco Central",
#             "state": "active",
#             "vocabulary_id": null
#           },
#           {
#             "display_name": "Secretaría General",
#             "id": "f39af13b-5e3d-4912-8166-ec1b3f5bb1b3",
#             "name": "Secretaría General",
#             "state": "active",
#             "vocabulary_id": null
#           },
#           {
#             "display_name": "Servicios",
#             "id": "589b2271-803c-47c8-9f8c-9ecdb148af55",
#             "name": "Servicios",
#             "state": "active",
#             "vocabulary_id": null
#           },
#           {
#             "display_name": "Transparencia activa",
#             "id": "7cd56379-e4bb-44e4-9a3e-7ea87fda3d2f",
#             "name": "Transparencia activa",
#             "state": "active",
#             "vocabulary_id": null
#           },
#           {
#             "display_name": "Trámites",
#             "id": "5a9498e8-801c-48e5-bd00-0820e79677a0",
#             "name": "Trámites",
#             "state": "active",
#             "vocabulary_id": null
#           }
#         ],
#         "relationships_as_subject": [],
#         "relationships_as_object": []
#       },
#       {
#         "author": "Departamento de Comunicación Institucional",
#         "author_email": "comunicaciones@ursec.gub.uy",
#         "creator_user_id": "623baab1-bba9-4143-a52c-cf6720400784",
#         "id": "57190d6e-7f19-45c7-ab50-d56433faa4f9",
#         "isopen": true,
#         "license_id": "odc-uy",
#         "license_title": "Licencia de DAG de Uruguay",
#         "license_url": "https://www.gub.uy/agencia-gobierno-electronico-sociedad-informacion-conocimiento/sites/agencia-gobierno-electronico-sociedad-informacion-conocimiento/files/documentos/publicaciones/licencia_de_datos_abiertos_0.pdf",
#         "maintainer": "Liliana María Ceballos Berdún",
#         "maintainer_email": "lceballos@ursec.gub.uy",
#         "metadata_created": "2025-01-14T20:16:22.189108",
#         "metadata_modified": "2025-01-17T17:08:16.850277",
#         "name": "ursec-resoluciones_ursec",
#         "notes": "Datos de resoluciones y otros dictámenes que emanen de la máxima jerarquía del Organismo (jerarca, sesiones de comisión, de directorio, de plenario, de asamblea, etc.)",
#         "num_resources": 4,
#         "num_tags": 2,
#         "organization": {
#           "id": "c554eaf1-fe3a-4853-abe9-0beb7207ed4f",
#           "name": "ursec",
#           "title": "URSEC",
#           "type": "organization",
#           "description": "El 21 de febrero de 2001 se creó la Unidad Reguladora de Servicios de Comunicaciones (URSEC) como órgano desconcentrado del Poder Ejecutivo ( Ley 17.296 de 21 de febrero de 2001).\r\nEn el 2020, la Ley 19.889 de 9 de julio, creó la Unidad Reguladora de Servicios de Comunicaciones como un servicio descentralizado del Poder Ejecutivo, dirigida por una Comisión de tres miembros.",
#           "image_url": "2019-09-10-160539.092857ursec.jpg",
#           "created": "2019-09-10T13:05:39.120782",
#           "is_organization": true,
#           "approval_status": "approved",
#           "state": "active"
#         },
#         "owner_org": "c554eaf1-fe3a-4853-abe9-0beb7207ed4f",
#         "private": false,
#         "state": "active",
#         "title": "Resoluciones",
#         "type": "dataset",
#         "update_frequency": "365",
#         "url": "https://www.gub.uy/unidad-reguladora-servicios-comunicaciones/institucional/normativa?field_tipo_de_norma_target_id=23&year=all&month=all&field_tematica_target_id=All&field_publico_target_id=All",
#         "version": "4",
#         "groups": [
#           {
#             "description": "",
#             "display_name": "Transparencia",
#             "id": "8552e8e2-e342-43fe-ab27-4e3c50564f9b",
#             "image_display_url": "https://catalogodatos.gub.uy/uploads/group/2019-08-22-234010.387437transparencia.png",
#             "name": "transparencia",
#             "title": "Transparencia"
#           }
#         ],
#         "resources": [
#           {
# ...
#         "id": "96cab02c-2629-455d-9555-c72dcdde1b7d",
#         "isopen": true,
#         "license_id": "odc-uy",
#         "license_title": "Licencia de DAG de Uruguay",
#         "license_url": "https://www.gub.uy/agencia-gobierno-electronico-sociedad-informacion-conocimiento/sites/agencia-gobierno-electronico-sociedad-informacion-conocimiento/files/documentos/publicaciones/licencia_de_datos_abiertos_0.pdf",
#         "maintainer": "Tecnologías de la Información",
#         "maintainer_email": "informatica@aduanas.gub.uy",
#         "metadata_created": "2024-11-06T14:56:19.737688",
#         "metadata_modified": "2025-01-13T18:26:51.391409",
#         "name": "dna-resoluciones",
#         "notes": "Datos de resoluciones y otros dictámenes que emanen de la máxima jerarquía del Organismo (jerarca, sesiones de comisión, de directorio, de plenario, de asamblea, etc.)",
#         "num_resources": 4,
#         "num_tags": 2,
#         "organization": {
#           "id": "77f9debb-9934-4495-a5ee-759970e843e2",
#           "name": "dna",
#           "title": "DNA",
#           "type": "organization",
#           "description": "La Dirección Nacional de Aduanas fue fundada en 1779 y tiene como misión velar por la seguridad de la sociedad uruguaya y apoyar el desarrollo económico del país, a través del control de las mercaderías que cruzan las fronteras aduaneras",
#           "image_url": "2020-10-26-190324.802350logoweb.png",
#           "created": "2020-10-26T16:03:24.844613",
#           "is_organization": true,
#           "approval_status": "approved",
#           "state": "active"
#         },
#         "owner_org": "77f9debb-9934-4495-a5ee-759970e843e2",
#         "private": false,
#         "state": "active",
#         "title": "Resoluciones",
#         "type": "dataset",
#         "update_frequency": "90",
#         "url": "",
#         "version": "1.0",
#         "groups": [
#           {
#             "description": "",
#             "display_name": "Transparencia",
#             "id": "8552e8e2-e342-43fe-ab27-4e3c50564f9b",
#             "image_display_url": "https://catalogodatos.gub.uy/uploads/group/2019-08-22-234010.387437transparencia.png",
#             "name": "transparencia",
#             "title": "Transparencia"
#           }
#         ],
#         "resources": [
#           {
#             "cache_last_updated": null,
#             "cache_url": null,
#             "created": "2024-11-06T14:56:21.482917",
#             "datastore_active": false,
#             "description": "Este recurso contiene los datos de las resoluciones y otros dictámenes",
#             "format": "XLSX",
#             "hash": "",
#             "id": "a01c67a0-666e-445f-ad66-34cc5309cf97",
#             "last_modified": "2025-01-13T18:26:49.339789",
#             "licence": "Licencia de DAG de Uruguay",
#             "metadata_modified": "2025-01-13T18:26:49.382003",
#             "mimetype": "application/vnd.openxmlformats-officedocument.spreadsheetml.sheet",
#             "mimetype_inner": null,
#             "name": "Resoluciones y otros dictámenes",
#             "package_id": "96cab02c-2629-455d-9555-c72dcdde1b7d",
#             "position": 0,
#             "resource_type": null,
#             "size": 24129,
#             "spatial_coverage": "Uruguay",
#             "state": "active",
#             "temporal_coverage": "2024",
#             "update_frequency": "90",
#             "url": "https://catalogodatos.gub.uy/dataset/96cab02c-2629-455d-9555-c72dcdde1b7d/resource/a01c67a0-666e-445f-ad66-34cc5309cf97/download/datos-de-las-resoluciones-y-otros-dictamenes.xlsx",
#             "url_type": "upload"
#           },
#           {
#             "cache_last_updated": null,
#             "cache_url": null,
#             "created": "2024-11-06T14:56:22.103241",
#             "datastore_active": true,
#             "description": "Este recurso contiene los datos de las resoluciones y otros dictámenes",
#             "format": "CSV",
#             "hash": "",
#             "id": "587a1880-f658-4fb1-8b60-935100eba0a8",
#             "last_modified": "2025-01-13T18:26:50.026009",
#             "licence": "Licencia de DAG de Uruguay",
#             "metadata_modified": "2025-01-13T18:26:50.062214",
#             "mimetype": "text/csv",
#             "mimetype_inner": null,
#             "name": "Resoluciones y otros dictámenes",
#             "package_id": "96cab02c-2629-455d-9555-c72dcdde1b7d",
#             "position": 1,
#             "resource_type": null,
#             "size": 32846,
#             "spatial_coverage": "Uruguay",
#             "state": "active",
#             "temporal_coverage": "2024",
#             "update_frequency": "90",
#             "url": "https://catalogodatos.gub.uy/dataset/96cab02c-2629-455d-9555-c72dcdde1b7d/resource/587a1880-f658-4fb1-8b60-935100eba0a8/download/datos-de-las-resoluciones-y-otros-dictamenes.csv",
#             "url_type": "upload"
#           },
#           {
#             "cache_last_updated": null,
#             "cache_url": null,
#             "created": "2024-11-06T14:56:22.829420",
#             "datastore_active": false,
#             "description": "Este recurso contiene los datos de las resoluciones y otros dictámenes",
#             "format": "XML",
#             "hash": "",
#             "id": "c1916c2b-2df0-47f5-b37e-f8246ebff9ef",
#             "last_modified": "2025-01-13T18:26:50.794660",
#             "licence": "Licencia de DAG de Uruguay",
#             "metadata_modified": "2025-01-13T18:26:50.839669",
#             "mimetype": "application/xml",
#             "mimetype_inner": null,
#             "name": "Resoluciones y otros dictámenes",
#             "package_id": "96cab02c-2629-455d-9555-c72dcdde1b7d",
#             "position": 2,
#             "resource_type": null,
#             "size": 59067,
#             "spatial_coverage": "Uruguay",
#             "state": "active",
#             "temporal_coverage": "2024",
#             "update_frequency": "90",
#             "url": "https://catalogodatos.gub.uy/dataset/96cab02c-2629-455d-9555-c72dcdde1b7d/resource/c1916c2b-2df0-47f5-b37e-f8246ebff9ef/download/datos-de-las-resoluciones-y-otros-dictamenes.xml",
#             "url_type": "upload"
#           },
#           {
#             "cache_last_updated": null,
#             "cache_url": null,
#             "created": "2024-11-06T14:56:23.345635",
#             "datastore_active": false,
#             "description": "Este recurso contiene los metadatos de los datos de las resoluciones y otros dictámenes",
#             "format": "JSON",
#             "hash": "",
#             "id": "a9778f0f-3b2b-454c-8799-4e5dc9158d8a",
#             "last_modified": "2025-01-13T18:26:51.367768",
#             "licence": "Licencia de DAG de Uruguay",
#             "metadata_modified": "2025-01-13T18:26:51.405519",
#             "mimetype": "application/json",
#             "mimetype_inner": null,
#             "name": "Metadatos de resoluciones y otros dictámenes",
#             "package_id": "96cab02c-2629-455d-9555-c72dcdde1b7d",
#             "position": 3,
#             "resource_type": null,
#             "size": 3011,
#             "spatial_coverage": "Uruguay",
#             "state": "active",
#             "temporal_coverage": "2024",
#             "update_frequency": "90",
#             "url": "https://catalogodatos.gub.uy/dataset/96cab02c-2629-455d-9555-c72dcdde1b7d/resource/a9778f0f-3b2b-454c-8799-4e5dc9158d8a/download/metadatos_datos-de-las-resoluciones-y-otros-dictamenes.json",
#             "url_type": "upload"
#           }
#         ],
#         "tags": [
#           {
#             "display_name": "Resoluciones",
#             "id": "1e764f01-7be3-40f0-bcc7-9c40deb65733",
#             "name": "Resoluciones",
#             "state": "active",
#             "vocabulary_id": null
#           },
#           {
#             "display_name": "Transparencia activa",
#             "id": "7cd56379-e4bb-44e4-9a3e-7ea87fda3d2f",
#             "name": "Transparencia activa",
#             "state": "active",
#             "vocabulary_id": null
#           }
#         ],
#         "relationships_as_subject": [],
#         "relationships_as_object": []
#       },
#       {
#         "author": "Departamento Transparencia Institucional",
#         "author_email": "Transparencia@aduanas.gub.uy",
#         "creator_user_id": "2753ffd5-57b3-444c-811e-fbdadfa8884f",
#         "id": "e0d6824c-0dde-4f22-8f06-343ba0f33d64",
#         "isopen": true,
#         "license_id": "odc-uy",
#         "license_title": "Licencia de DAG de Uruguay",
#         "license_url": "https://www.gub.uy/agencia-gobierno-electronico-sociedad-informacion-conocimiento/sites/agencia-gobierno-electronico-sociedad-informacion-conocimiento/files/documentos/publicaciones/licencia_de_datos_abiertos_0.pdf",
#         "maintainer": "Tecnologías de la Información",
#         "maintainer_email": "informatica@aduanas.gub.uy",
#         "metadata_created": "2024-11-06T14:42:51.489902",
#         "metadata_modified": "2025-01-13T18:25:27.086479",
#         "name": "dna-organigrama",
#         "notes": "Estructura orgánica del organismo con información adicional de las distintas unidades que lo conforman y sus respectivos jerarcas.",
#         "num_resources": 4,
#         "num_tags": 2,
#         "organization": {
#           "id": "77f9debb-9934-4495-a5ee-759970e843e2",
#           "name": "dna",
#           "title": "DNA",
#           "type": "organization",
#           "description": "La Dirección Nacional de Aduanas fue fundada en 1779 y tiene como misión velar por la seguridad de la sociedad uruguaya y apoyar el desarrollo económico del país, a través del control de las mercaderías que cruzan las fronteras aduaneras",
#           "image_url": "2020-10-26-190324.802350logoweb.png",
#           "created": "2020-10-26T16:03:24.844613",
#           "is_organization": true,
#           "approval_status": "approved",
#           "state": "active"
#         },
#         "owner_org": "77f9debb-9934-4495-a5ee-759970e843e2",
#         "private": false,
#         "state": "active",
#         "title": "Organigrama",
#         "type": "dataset",
#         "update_frequency": "365",
#         "url": "",
#         "version": "1.0",
#         "groups": [
#           {
#             "description": "",
#             "display_name": "Transparencia",
#             "id": "8552e8e2-e342-43fe-ab27-4e3c50564f9b",
#             "image_display_url": "https://catalogodatos.gub.uy/uploads/group/2019-08-22-234010.387437transparencia.png",
#             "name": "transparencia",
#             "title": "Transparencia"
#           }
#         ],
#         "resources": [
#           {
#             "cache_last_updated": null,
#             "cache_url": null,
#             "created": "2024-11-06T14:42:53.318988",
#             "datastore_active": false,
#             "description": "Este recurso contiene los datos del organigrama del organismo",
#             "format": "XLSX",
#             "hash": "",
#             "id": "271dfefa-746e-4dc4-b365-91ed3baf9696",
#             "last_modified": "2025-01-13T18:25:25.146335",
#             "licence": "Licencia de DAG de Uruguay",
#             "metadata_modified": "2025-01-13T18:25:25.188456",
#             "mimetype": "application/vnd.openxmlformats-officedocument.spreadsheetml.sheet",
#             "mimetype_inner": null,
#             "name": "Organigrama del organismo",
#             "package_id": "e0d6824c-0dde-4f22-8f06-343ba0f33d64",
#             "position": 0,
#             "resource_type": null,
#             "size": 30231,
#             "spatial_coverage": "Uruguay",
#             "state": "active",
#             "temporal_coverage": "2024-2025",
#             "update_frequency": "365",
#             "url": "https://catalogodatos.gub.uy/dataset/e0d6824c-0dde-4f22-8f06-343ba0f33d64/resource/271dfefa-746e-4dc4-b365-91ed3baf9696/download/organigrama-del-organismo.xlsx",
#             "url_type": "upload"
#           },
#           {
#             "cache_last_updated": null,
#             "cache_url": null,
#             "created": "2024-11-06T14:42:53.972844",
#             "datastore_active": true,
#             "description": "Este recurso contiene los datos del organigrama del organismo",
#             "format": "CSV",
#             "hash": "",
#             "id": "0bb92ddf-01da-4336-812b-21488d8aeed5",
#             "last_modified": "2025-01-13T18:25:25.793809",
#             "licence": "Licencia de DAG de Uruguay",
#             "metadata_modified": "2025-01-13T18:25:25.828139",
#             "mimetype": "text/csv",
#             "mimetype_inner": null,
#             "name": "Organigrama del organismo",
#             "package_id": "e0d6824c-0dde-4f22-8f06-343ba0f33d64",
#             "position": 1,
#             "resource_type": null,
#             "size": 28804,
#             "spatial_coverage": "Uruguay",
#             "state": "active",
#             "temporal_coverage": "2024-2025",
#             "update_frequency": "365",
#             "url": "https://catalogodatos.gub.uy/dataset/e0d6824c-0dde-4f22-8f06-343ba0f33d64/resource/0bb92ddf-01da-4336-812b-21488d8aeed5/download/organigrama-del-organismo.csv",
#             "url_type": "upload"
#           },
#           {
#             "cache_last_updated": null,
#             "cache_url": null,
#             "created": "2024-11-06T14:42:54.681732",
#             "datastore_active": false,
#             "description": "Este recurso contiene los datos del organigrama del organismo",
#             "format": "XML",
#             "hash": "",
#             "id": "944135ef-8a9d-47cf-bd13-6c83681395c3",
#             "last_modified": "2025-01-13T18:25:26.431565",
#             "licence": "Licencia de DAG de Uruguay",
#             "metadata_modified": "2025-01-13T18:25:26.470531",
#             "mimetype": "application/xml",
#             "mimetype_inner": null,
#             "name": "Organigrama del organismo",
#             "package_id": "e0d6824c-0dde-4f22-8f06-343ba0f33d64",
#             "position": 2,
#             "resource_type": null,
#             "size": 63555,
#             "spatial_coverage": "Uruguay",
#             "state": "active",
#             "temporal_coverage": "2024-2025",
#             "update_frequency": "365",
#             "url": "https://catalogodatos.gub.uy/dataset/e0d6824c-0dde-4f22-8f06-343ba0f33d64/resource/944135ef-8a9d-47cf-bd13-6c83681395c3/download/organigrama-del-organismo.xml",
#             "url_type": "upload"
#           },
#           {
#             "cache_last_updated": null,
#             "cache_url": null,
#             "created": "2024-11-06T14:42:55.261263",
#             "datastore_active": false,
#             "description": "Este recurso contiene los metadatos de los datos del organigrama del organismo",
#             "format": "JSON",
#             "hash": "",
#             "id": "bed17142-1d91-471a-bb66-cdbe8b8df3f0",
#             "last_modified": "2025-01-13T18:25:27.063088",
#             "licence": "Licencia de DAG de Uruguay",
#             "metadata_modified": "2025-01-13T18:25:27.099793",
#             "mimetype": "application/json",
#             "mimetype_inner": null,
#             "name": "Metadatos de organigrama del organismo",
#             "package_id": "e0d6824c-0dde-4f22-8f06-343ba0f33d64",
#             "position": 3,
#             "resource_type": null,
#             "size": 4975,
#             "spatial_coverage": "Uruguay",
#             "state": "active",
#             "temporal_coverage": "2024-2025",
#             "update_frequency": "365",
#             "url": "https://catalogodatos.gub.uy/dataset/e0d6824c-0dde-4f22-8f06-343ba0f33d64/resource/bed17142-1d91-471a-bb66-cdbe8b8df3f0/download/metadatos_organigrama-del-organismo.json",
#             "url_type": "upload"
#           }
#         ],
#         "tags": [
#           {
#             "display_name": "Organigrama",
#             "id": "070a15a1-bfb9-4606-a648-fe6918837325",
#             "name": "Organigrama",
#             "state": "active",
#             "vocabulary_id": null
#           },
#           {
#             "display_name": "Transparencia activa",
#             "id": "7cd56379-e4bb-44e4-9a3e-7ea87fda3d2f",
#             "name": "Transparencia activa",
#             "state": "active",
#             "vocabulary_id": null
#           }
#         ],
#         "relationships_as_subject": [],
#         "relationships_as_object": []
#       }
#     ],
#     "sort": "score desc, metadata_modified desc",
#     "search_facets": {}
#   }
# }

# %%
# Podemos incluso hacer queries pidiendo solo packages que tengan ciertos tags asociados,
# en este caso buscamos los relacionados a "Transparencia Activa"
endpoint_suffix = 'package_search?fq=id:9e0dc092-a669-4697-b3ba-88808165c902'
url = build_url(endpoint_suffix)

pretty_print_json(do_get_request(url))
# Out:
# {
#   "help": "https://catalogodatos.gub.uy/es/api/3/action/help_show?name=package_search",
#   "success": true,
#   "result": {
#     "count": 1,
#     "facets": {},
#     "results": [
#       {
#         "author": "Cartografía",
#         "author_email": "cartografia@catastro.gub.uy",
#         "creator_user_id": "4d4c73eb-ecd3-4522-856c-54e1eff9bd37",
#         "id": "9e0dc092-a669-4697-b3ba-88808165c902",
#         "isopen": true,
#         "license_id": "odc-uy",
#         "license_title": "Licencia de DAG de Uruguay",
#         "license_url": "https://www.gub.uy/agencia-gobierno-electronico-sociedad-informacion-conocimiento/sites/agencia-gobierno-electronico-sociedad-informacion-conocimiento/files/documentos/publicaciones/licencia_de_datos_abiertos_0.pdf",
#         "maintainer": "Cartografía",
#         "maintainer_email": "cartografia@catastro.gub.uy",
#         "metadata_created": "2016-07-26T19:30:01.525227",
#         "metadata_modified": "2025-03-07T14:15:29.266976",
#         "name": "direccion-nacional-de-catastro-shapes-del-parcelario-rural-y-urbano",
#         "notes": "Archivos shape para descargar de los parcelarios catastrales del Uruguay.",
#         "num_resources": 4,
#         "num_tags": 2,
#         "organization": {
#           "id": "ed6fae59-43aa-4635-87ab-6e2456c80a96",
#           "name": "direccion-nacional-de-catastro",
#           "title": "Dirección Nacional de Catastro",
#           "type": "organization",
#           "description": "Dirección Nacional de Catastro",
#           "image_url": "20141202-183106.657696Logo-DNC-color",
#           "created": "2014-12-02T16:31:06.710780",
#           "is_organization": true,
#           "approval_status": "approved",
#           "state": "active"
#         },
#         "owner_org": "ed6fae59-43aa-4635-87ab-6e2456c80a96",
#         "private": false,
#         "state": "active",
#         "title": "Shapes del parcelario rural y urbano",
#         "type": "dataset",
#         "update_frequency": "30",
#         "url": "www.catastro.gub.uy",
#         "version": "1.0",
#         "groups": [
#           {
#             "description": "",
#             "display_name": "Geográficos",
#             "id": "ca616161-97f8-4a12-8370-2fa3fde262a4",
#             "image_display_url": "https://catalogodatos.gub.uy/uploads/group/2019-08-22-233710.601300geograficos.png",
#             "name": "geograficos",
#             "title": "Geográficos"
#           }
#         ],
#         "resources": [
#           {
#             "cache_last_updated": null,
#             "cache_url": null,
#             "created": "2016-07-26T16:47:56.841536",
#             "datastore_active": false,
#             "description": "Parcelas no Rurales del Uruguay",
#             "format": "SHP",
#             "hash": "",
#             "id": "3d211675-14a6-4e69-bc0b-6cc549060633",
#             "last_modified": "2025-03-07T13:46:26.928878",
#             "metadata_modified": "2025-03-07T14:04:08.557040",
#             "mimetype": "application/zip",
#             "mimetype_inner": null,
#             "name": "Total País - Urbano",
#             "package_id": "9e0dc092-a669-4697-b3ba-88808165c902",
#             "position": 0,
#             "qa": {
#               "resource_timestamp": null,
#               "archival_timestamp": "2022-05-31T07:59:40.226533",
#               "openness_score": 2,
#               "openness_score_reason": "Content of file appeared to be format \"SHP\" which receives openness score: 2.",
#               "format": "SHP",
#               "created": "2018-02-28T17:30:10.382489",
#               "updated": "2022-05-31T11:33:40.358858"
#             },
#             "resource_type": null,
#             "size": 117487456,
#             "spatial_coverage": "Uruguay",
#             "spatial_ref_system": "SIRGAS- ROU 98",
#             "state": "active",
#             "temporal_coverage": "Febrero de 2025",
#             "update_frequency": "30",
#             "url": "https://catalogodatos.gub.uy/dataset/9e0dc092-a669-4697-b3ba-88808165c902/resource/3d211675-14a6-4e69-bc0b-6cc549060633/download/paisurbano_shp.zip",
#             "url_type": "upload"
#           },
#           {
#             "cache_last_updated": null,
#             "cache_url": null,
#             "created": "2018-06-11T19:00:30.440103",
#             "datastore_active": false,
#             "description": "Parcelas Rurales del Uruguay",
#             "format": "SHP",
#             "hash": "",
#             "id": "2073596d-f122-4030-9eb4-eaca1cdf1e9c",
#             "last_modified": "2025-03-07T14:04:08.520956",
#             "metadata_modified": "2025-03-07T14:14:54.224605",
#             "mimetype": "application/zip",
#             "mimetype_inner": null,
#             "name": "Total País - Rural",
#             "package_id": "9e0dc092-a669-4697-b3ba-88808165c902",
#             "position": 1,
#             "qa": {
#               "resource_timestamp": null,
#               "archival_timestamp": "2022-05-31T07:59:41.474787",
#               "openness_score": 2,
#               "openness_score_reason": "Content of file appeared to be format \"SHP\" which receives openness score: 2.",
#               "format": "SHP",
#               "created": "2018-06-12T05:07:35.084375",
#               "updated": "2022-05-31T11:33:40.374747"
#             },
#             "resource_type": null,
#             "size": 173705596,
#             "spatial_coverage": "Uruguay",
#             "spatial_ref_system": "SIRGAS- ROU 98",
#             "state": "active",
#             "temporal_coverage": "Febrero de 2025",
#             "update_frequency": "30",
#             "url": "https://catalogodatos.gub.uy/dataset/9e0dc092-a669-4697-b3ba-88808165c902/resource/2073596d-f122-4030-9eb4-eaca1cdf1e9c/download/paisrural_shp.zip",
#             "url_type": "upload"
#           },
#           {
#             "cache_last_updated": null,
#             "cache_url": null,
#             "created": "2018-06-12T20:11:58.953201",
#             "datastore_active": false,
#             "description": "Secciones Catastrales del Uruguay",
#             "format": "SHP",
#             "hash": "",
#             "id": "5ab54026-7ce8-4604-be54-17dcde0a02be",
#             "last_modified": "2025-03-07T14:14:54.180533",
#             "metadata_modified": "2025-03-07T14:15:29.280853",
#             "mimetype": "application/zip",
#             "mimetype_inner": null,
#             "name": "Total País - Secciones Catastrales",
#             "package_id": "9e0dc092-a669-4697-b3ba-88808165c902",
#             "position": 2,
#             "qa": {
#               "resource_timestamp": null,
#               "archival_timestamp": "2022-05-31T07:59:42.389554",
#               "openness_score": 2,
#               "openness_score_reason": "Content of file appeared to be format \"SHP\" which receives openness score: 2.",
#               "format": "SHP",
#               "created": "2018-06-27T23:12:24.894137",
#               "updated": "2022-05-31T11:33:40.401711"
#             },
#             "resource_type": null,
#             "size": 6950968,
#             "spatial_coverage": "Uruguay",
#             "spatial_ref_system": "SIRGAS- ROU 98",
#             "state": "active",
#             "temporal_coverage": "Febrero de 2025",
#             "update_frequency": "30",
#             "url": "https://catalogodatos.gub.uy/dataset/9e0dc092-a669-4697-b3ba-88808165c902/resource/5ab54026-7ce8-4604-be54-17dcde0a02be/download/paisseccat_shp.zip",
#             "url_type": "upload"
#           },
#           {
#             "cache_last_updated": null,
#             "cache_url": null,
#             "created": "2018-06-12T20:13:45.549784",
#             "datastore_active": false,
#             "description": "Localidades Catastrales del Uruguay",
#             "format": "SHP",
#             "hash": "",
#             "id": "510012c9-12b0-4e96-9dbb-52bb10180a91",
#             "last_modified": "2025-03-07T14:15:29.245950",
#             "metadata_modified": "2025-03-07T14:15:29.280940",
#             "mimetype": "application/zip",
#             "mimetype_inner": null,
#             "name": "Total País - Localidades",
#             "package_id": "9e0dc092-a669-4697-b3ba-88808165c902",
#             "position": 3,
#             "qa": {
#               "resource_timestamp": null,
#               "archival_timestamp": "2022-05-31T07:59:43.279428",
#               "openness_score": 2,
#               "openness_score_reason": "Content of file appeared to be format \"SHP\" which receives openness score: 2.",
#               "format": "SHP",
#               "created": "2018-06-27T23:12:24.904765",
#               "updated": "2022-05-31T11:33:40.413438"
#             },
#             "resource_type": null,
#             "size": 411092,
#             "spatial_coverage": "Uruguay",
#             "spatial_ref_system": "SIRGAS- ROU 98",
#             "state": "active",
#             "temporal_coverage": "Febrero de 2025",
#             "update_frequency": "30",
#             "url": "https://catalogodatos.gub.uy/dataset/9e0dc092-a669-4697-b3ba-88808165c902/resource/510012c9-12b0-4e96-9dbb-52bb10180a91/download/paislocalidades_shp.zip",
#             "url_type": "upload"
#           }
#         ],
#         "tags": [
#           {
#             "display_name": "Catastro",
#             "id": "b97e7107-be79-4ddf-8e79-a311f0c1c4d0",
#             "name": "Catastro",
#             "state": "active",
#             "vocabulary_id": null
#           },
#           {
#             "display_name": "Parcelario",
#             "id": "ae4c0b9c-e0a4-4e9b-9351-fa5d3ddf8bd5",
#             "name": "Parcelario",
#             "state": "active",
#             "vocabulary_id": null
#           }
#         ],
#         "relationships_as_subject": [],
#         "relationships_as_object": []
#       }
#     ],
#     "sort": "score desc, metadata_modified desc",
#     "search_facets": {}
#   }
# }

# %%
# Package list
#
# Lista todos los packages de catalogo de datos. Los packages son los datasets, por ejemplo
# se ve que abajo se lista "ancap-proyectos". En la web se accede a través de "https://catalogodatos.gub.uy/dataset/ancap-proyectos"
endpoint_suffix = 'package_list'
url = build_url(endpoint_suffix)

pretty_print_json(do_get_request(url))
# Out:
# {
#   "help": "https://catalogodatos.gub.uy/es/api/3/action/help_show?name=package_list",
#   "success": true,
#   "result": [
#     "acau-fondos-de-acau",
#     "acce-catalogo-acce",
#     "acce-compras-estatales",
#     "acce-registro-unico-de-proveedores-del-estado-rupe-2019",
#     "acce-registro-unico-de-proveedores-del-estado-rupe-2020",
#     "acce-registro-unico-de-proveedores-del-estado-rupe-2021",
#     "acce-registro-unico-de-proveedores-del-estado-rupe-2022",
#     "acce-rupe-2018",
#     "aceras-y-cabezales-de-numeracion",
#     "a-donde-van-nuestros-impuestos",
#     "agesic-autoridades_agesic",
#     "agesic-creacion-de-empresas-a-traves-de-empresa-en-el-dia",
#     "agesic-datos-referenciales-codigueras",
#     "agesic-diario_sesiones_agesic",
#     "agesic-encuestas-cap",
#     "agesic-encuestas-de-uso-de-tic",
#     "agesic-evaluacion_de_accesibilidad_digital_en_organismos_del_estado",
#     "agesic-evolucion_organismo_agesic",
#     "agesic-guia-de-tramites",
#     "agesic-indicadores-de-atencion-a-la-ciudadania",
#     "agesic-indicadores-de-la-gestion-administrativa-digital",
#     "agesic-informes-de-autoevaluacion-del-segundo-plan-nacional-de-gobierno-abierto",
#     "agesic-informes-de-avances-del-cuarto-plan-de-accion-nacional-de-gobierno-abierto-2018-2020",
#     "agesic-informes-de-avances-del-quinto-plan-de-accion-nacional-de-gobierno-abierto",
#     "agesic-informes-de-avances-del-tercer-plan-de-accion-nacional-de-gobierno-abierto-2016-2018",
#     "agesic-la-unaoid",
#     "agesic-marco_juridico_agesic",
#     "agesic-metadatos-para-la-definicion-de-vocabularios-y-datos-referenciales",
#     "agesic-observaciones-meteorologicas",
#     "agesic-organigrama_agesic",
#     "agesic-relevamiento-de-ambitos-de-participacion-ciudadana",
#     "agesic-remuneraciones_agesic",
#     "agesic-temperatura_2019",
#     "agesic-trazabilidadtramites",
#     "agesic-vocabulario-de-direcciones",
#     "agesic-vocabulario-de-empresa",
#     "agesic-vocabulario-de-organismo",
#     "agesic-vocabulario-de-persona",
#     "aliviaderos",
#     "ambiente-dinagua-aprovechamientos-de-los-recursos-hidricos-vigentes-2019",
#     "ambiente-dinagua-mediciones-de-nivel-2017",
#     "ambiente-dinagua-mediciones-de-nivel-2018",
#     "ambiente-dinagua-mediciones-de-nivel-2019",
#     "ambiente_ingei",
#     "ambiente-medidas-cdn",
#     "ancap-autoridades",
#     "ancap-cantidad-ventas-combustibles",
#     "ancap-capacitaciones",
#     "ancap-compromiso-gestion",
#     "ancap-comunicacion-participacion",
#     "ancap-crudos-procesados",
#     "ancap-diario-sesiones",
#     "ancap-emisiones-atmosfericas-la-teja",
#     "ancap-emisiones-atmosfericas-minas",
#     "ancap-emisiones-gases-efecto-invernadero",
#     "ancap-evolucion",
#     "ancap-funcionarios-comision",
#     "ancap-humedad2020",
#     "ancap-humedad2021",
#     "ancap-humedad2022",
#     "ancap-humedad2023",
#     "ancap-humedad2024",
#     "ancap-humedad_relativa_2019v2",
#     "ancap-inventario-promedio-combustibles",
#     "ancap-inversion-publicidad",
#     "ancap-licitaciones-compras",
#     "ancap-llamados-concursos",
#     "ancap-marco-juridico",
#     "ancap-monitoreo-curso-tablada",
#     "ancap-organigrama",
#     "ancap-perfil-puestos",
#     "ancap-precio-combustible-ex-planta",
#     "ancap-precio-combustible-pe",
#     "ancap-presupuesto",
#     "ancap-produccion-combustibles",
#     "ancap-proyectos",
#     "ancap-residuos-valorizados",
#     "ancap-responsables-transparencia",
#     "ancap-temp-agua-en-superficie2020",
#     "ancap-temp-agua-en-superficie2021",
#     "ancap-temp-agua-en-superficie2022",
#     "ancap-temp-agua-en-superficie2023",
#     "ancap-temperatura2020",
#     "ancap-temperatura2021",
#     "ancap-temperatura2022",
#     "ancap-temperatura2023",
#     "ancap-temperatura2024",
#     "ancap-temperatura_agua_2019",
#     "ancap-tramites-servicios",
#     "ancap-velocidad_del_viento",
#     "ancap-vel-viento-2020",
#     "ancap-vel-viento-2021",
#     "ancap-vel-viento-2022",
#     "ancap-vel-viento-2023",
#     "ancap-vel-viento-2024",
#     "ancap-vel-viento-boya-2020",
#     "ancap-vel-viento-boya-2021",
#     "ancap-vel-viento-boya-2022",
#     "ancap-vel-viento-boya-2023",
#     "ancap-vel-viento-boya-2024",
#     "ancap-ventas-gas-natural-por-zona",
#     "ancap-viaticos-internacionales",
#     "ancap-viaticos-nacionales",
#     "anep-centros-anep",
#     "anep-http-sig-anep-edu-uy-siganep-formatos",
#     "antecedentes-de-nomenclatura-de-vias-de-transito-de-montevideo",
#     "anuario-estadistico-del-poder-judicial",
#     "app-a-tu-nombre-udelar",
#     "app-coronavirus-uy-app-store",
#     "app-coronavirus-uy-google-play",
#     "arce-datos-historicos-de-compras",
#     "arce-registro-unico-de-proveedores-del-estado-rupe-2024",
#     "areas-de-especial-consideracion",
#     "areas-liberadas",
#     "asentamientos-irregulares",
#     "a-tu-nombre",
#     "a-tu-nombre-udelar",
#     "a-tu-servicio",
#     "autores-y-obras-de-uruguay",
#     "autoridades_de_ursec",
#     "balance-de-ejecucion-presupuestal",
#     "banco-central-del-uruguay-auditorias_bcu",
#     "banco-central-del-uruguay-calendario_reuniones",
#     "banco-central-del-uruguay-capacitaciones",
#     "banco-central-del-uruguay-comisiones_exterior",
#     "banco-central-del-uruguay-compensacion_funcionario_comision",
#     "banco-central-del-uruguay-creacion_y_evolucion",
#     "banco-central-del-uruguay-diario_sesiones",
#     "banco_central_del_uruguay-informacion_del_sujeto_obligado",
#     "banco-central-del-uruguay-informacion_de_servicios_y_tramites",
#     "banco-central-del-uruguay-marco_juridico",
#     "banco-central-del-uruguay-organigrama",
#     "banco-central-del-uruguay-politica-de-seguridad-de-la-informacion",
#     "banco-central-del-uruguay-presupuesto_bcu",
#     "banco-central-del-uruguay-presupuesto_organismos_internacionales",
#     "banco-central-del-uruguay-programa_gestion_documental",
#     "banco-central-del-uruguay-proyectos",
#     "banco-central-del-uruguay-resoluciones",
#     "banco-central-del-uruguay-sistema-de-remuneraciones-de-los-funcionarios-del-bcu",
#     "banco-de-la-republica-oriental-del-uruguay-autoridades",
#     "banco-de-la-republica-oriental-del-uruguay-evolucion_del_organismo",
#     "banco-de-la-republica-oriental-del-uruguay-funcionarios_en_comision",
#     "banco-de-la-republica-oriental-del-uruguay-marco_juridico",
#     "banco-de-la-republica-oriental-del-uruguay-organigrama",
#     "banco-de-la-republica-oriental-del-uruguay-sucursales-y-puntos-de-atencion",
#     "base-anual-de-personas-lesionadas-en-siniestros-de-transito",
#     "base_autorizaciones",
#     "bcu_llamados-publicados-comprasycontrataciones",
#     "ben-importacion-de-gas-natural",
#     "ben-importacion-de-petroleo-y-carga-de-refineria",
#     "ben-importacion-y-exportacion-de-electricidad",
#     "biblotecas-municipalesss",
#     "bicicircuitos-bicicletarios",
#     "birrabot",
#     "bondibot",
#     "buscador-de-obras-del-acervo",
#     "calidad-del-aire-ozono-o3",
#     "cargasenarribo",
#     "cei-base-de-datos-que-utiliza-el-buscador-de-soluciones-portal-cei",
#     "censo-de-arbolado-2008",
#     "centro_ceibal-actividad-en-plataformas-educativas-docentes",
#     "centro_ceibal-actividad-en-plataformas-educativas-estudiantes",
#     "centro-ceibal-autoridades",
#     "centro-ceibal-calendario_de_reuniones",
#     "centro-ceibal-capacitaciones",
#     "centro-ceibal-comunicacion_y_participacion",
#     "centro-ceibal-evolucion",
#     "centro-ceibal-informacion_de_servicios_y_tramites",
#     "centro-ceibal-licitaciones_adjudicadas",
#     "centro-ceibal-llamados_y_concursos",
#     "centro-ceibal-marco_juridico",
#     "centro-ceibal-organigrama",
#     "centro-ceibal-perfil_de_los_puestos",
#     "centro-ceibal-presupuesto",
#     "centro-ceibal-presupuesto_y_financiamiento_externo",
#     "centro-ceibal-proyectos",
#     "centro-ceibal-remuneraciones",
#     "comentarios-realizados-en-la-plataforma-montevideo-decide",
#     "comisiones-especiales-permantentes-pot",
#     "como-ir",
#     "consultas-telefonicas",
#     "contenedores-de-residuos-domiciliarios-ubicacion-circuitos-y-frecuencia-de-recoleccion",
#     "contenedores-de-residuos-especiales-plasticos-latas-vidrios-y-pilas",
#     "contenedores-para-clasificacion-de-residuos-secos-domiciliarios",
#     "contenedores-para-depositar-material-reciclable",
#     "conteo-vehicular-en-las-principales-avenidas-de-montevideo",
#     "convenios",
#     "correo-",
#     "correo-actas_resoluciones_correo",
#     "correo-auditorias_correo",
#     "correo-autoridades_correo",
#     "correo-capacitaciones_correo",
#     "correo-codigo-postal",
#     "correo-comisionesservicioexterior-correo",
#     "correo-comunicacion_participacion_correo",
#     "correo-creacion_evolucionhistorica_correo",
#     "correo-destinoshabilitadosporproducto-correo",
#     "correo-expressinternacional-correo",
#     "correo-glosariodeterminos-correo",
#     "correo-grupodepaises_correo",
#     "correo-informacionestadistica_correo",
#     "correo-informacionreservada_correo",
#     "correo-la_fa_marconormativo_correo",
#     "correo-licitaciones_compras_correo_2021",
#     "correo-llamados_concursos_correo",
#     "correo-locales_atencionciudadana_correo",
#     "correo-marco_juridico_correo",
#     "correo-nomina_correo",
#     "correo-oficial_cumplimiento_correo",
#     "correo-organigrama_correo",
#     "correo-pep_correo",
#     "correo-perfil_puestos_correo",
#     "correo-planestrategico_correo",
#     "correo-planfilatelico-correo",
#     "correo-presupuesto_correo",
#     "correo-presupuesto_organismos_internacionales_correo",
#     "correo-productomisello-correo",
#     "correo-productosfilatelicos_correo",
#     "correo-proyectos_correo",
#     "correo-responsable_procedimiento_correo",
#     "correo-sellospostales-correo",
#     "correo-tarifas_filatelia_correo",
#     "correo-tarifas_firma_digital_correo",
#     "correo-tarifas_giros_correo",
#     "correo-tarifas_internacionales_correo",
#     "correo-tarifas_nacionales_correo",
#     "correo-tramites_productosservicios_correo",
#     "correo-viaticosinternacionales-correo",
#     "correo-viaticos-nacionales",
#     "correo-vinculos_funcionales_correo",
#     "corte-electoral-balotaje_2014",
#     "corte-electoral-balotaje_2019",
#     "corte-electoral-eleccion_caja_notarial_2016",
#     "corte-electoral-eleccion_conaprole_2016",
#     "corte-electoral-eleccionesdepartamentales2020",
#     "corte-electoral-elecciones_internas_2019",
#     "corte-electoral-elecciones_nacionales_2014",
#     "corte-electoral-elecciones-nacionales-2019",
#     "corte-electoral-referendum2022",
#     "corte-electoral-resultados_caja_profesionales_2017",
#     "covid-19-vacunas-uy",
#     "cruces-de-calle-de-montevideo",
#     "cuentas-claras",
#     "curvas-de-nivel-cada-2-metros-montevideo",
#     "data-cantidad-pedidos-ai-por-organismo",
#     "data-clasificacion-de-vias-de-montevideo-atunombre-uy",
#     "data-contenedores-para-la-recepcion-de-residuos-reciclables-donde-reciclo",
#     "data-diccionario-de-sinonimos-elijo-estudiar",
#     "data-ogpmontevideo",
#     "data-organismos_publicos",
#     "data-participantes-abrelatam-2013",
#     "data-participantes-conferencia-regional-de-datos-abiertos-2013",
#     "data-pedidos-de-informacion-publica",
#     "data-preguntas-derechos-de-estudiantes",
#     "data-rendicion-de-cuentas-conferencia-de-datos-abiertos-2013",
#     "data-reportes-y-totales-de-reclamos-en-por-mi-barrio",
#     "data-respuestas-de-formulario-en-cuarentena-uy",
#     "datos-covid-19",
#     "datos-de-accesibilidad-de-veredas",
#     "datos-del-fondo-capital-montevideo",
#     "datos-de-los-servicios-de-policlinicas",
#     "datos-de-temperatura-de-las-estaciones-de-la-red-de-montevideo",
#     "datos-estadisticos-de-regimenes-industriales",
#     "datos-preliminares-declaracion-jurada-de-existencias-dicose-snig-2022",
#     "debate-ideas-y-apoyos-de-montevideo-decide",
#     "declaraciones-al-sistema-de-informacion-de-precios-al-consumidor-2019",
#     "defensa-del-consumidor-sistema-de-informacion-de-precios-al-consumidor-2023",
#     "defensa-del-consumidor-sistema-de-informacion-de-precios-al-consumidor-2024",
#     "delitos-sexuales",
#     "derechos-de-estudiantes",
#     "dinacia-estadisticas-anuales-de-transporte-de-carga",
#     "dinacia-estadisticas-de-cabotaje-anuales-de-movimiento-de-pasajeros",
#     "dinacia-estadisticas-historicas-de-partidas-y-arribos-de-pasajeros",
#     "dinacia-estadisticas-mensuales-de-transporte-de-carga",
#     "dinacia-movimiento-mensual-de-pasajeros",
#     "dioxido-de-nitrogeno",
#     "direcciones-oficiales-de-montevideo",
#     "direccion-nacional-de-catastro-dxf-del-parcelario-urbano-y-rural",
#     "direccion-nacional-de-catastro-padrones-urbanos-y-rurales",
#     "direccion-nacional-de-catastro-shapes-del-parcelario-rural-y-urbano",
#     "dondereciclo",
#     "educacion-permanente-udelar-actividad-2015",
#     "educacion-permanente-udelar-actividades-2121",
#     "educacion-permanente-udelar-actividades-del-programa-de-educacion-permanente-2016",
#     "educacion-permanente-udelar-actividades-del-programa-de-educacion-permanente-2017",
#     "educacion-permanente-udelar-actividades-del-programa-de-educacion-permanente-2018",
#     "educacion-permanente-udelar-actividades-del-programa-de-educacion-permanente-2019",
#     "educacion-permanente-udelar-actividades-del-programa-de-educacion-permanente-2020",
#     "educacion-permanente-udelar-encuesta-a-docentes-2019",
#     "educacion-permanente-udelar-encuesta-a-participantes-de-educacion-permanente-2021",
#     "elencos-estables",
#     "elijo-estudiar",
#     "empresas-alimentarias",
#     "encuesta-a-docentes-de-educacion-permanente-2017",
#     "encuesta-a-participantes-de-actividades-de-educacion-permanente-2017",
#     "encuesta-de-cruceros",
#     "encuesta-de-turismo-receptivo",
#     "encuesta-origen-destino-montevideo",
#     "equipamiento-urbano-espacios-publicos",
#     "espacios-accesibles-de-montevideo",
#     "espacios-publicos-de-montevideo",
#     "estadisticas-de-uso-como-ir",
#     "estado-de-recoleccion-de-contenedores-de-residuos-domiciliarios",
#     "evacuacion-de-consultas-en-centro-de-informacion-turistica",
#     "exoneraciones",
#     "expedientes-electronicos-de-la-intendencia-de-montevideo",
#     "facultad-de-psicologia-1er-censo-nacional-de-psicologia-uruguay-2014",
#     "fiscalia-general-de-la-nacion-imputaciones-y-condenas-a-personas",
#     "fiscalia-general-de-la-nacion-microdatos-de-casos-formalizados-nuevo-cpp",
#     "fondo-nacional-de-recursos-evolucion-fondo-nacional-de-recursos",
#     "fondo-nacional-de-recursos-gasto-por-actos-medicos-fondo-nacional-de-recursos",
#     "fondo-nacional-de-recursos-gasto-por-tratamientos-fondo-nacional-de-recursos",
#     "fondo-nacional-de-recursos-marco_juridico_fondo-nacional-de-recursos",
#     "fondo-nacional-de-recursos-organigrama_fondo-nacional-de-recursos",
#     "fondo-nacional-de-recursos-remuneraciones_fondo-nacional-de-recursos",
#     "fondo-nacional-de-recursos-solicitudes-de-prestaciones-fondo-nacional-de-recursos",
#     "fondo-nacional-de-recursos-solicitudes-de-tramites-autorizados",
#     "funcionarios_comision",
#     "gastos-por-actos-medicos",
#     "gestion-administrativa-digital",
#     "guitur",
#     "habilitacion-registro-de-locales-y-empresas-alimentarias",
#     "habilitacion-y-registro-de-alimentos",
#     "habitabilidad-del-espacio-publico",
#     "historico-indice-uv",
#     "homicidios-a-mujeres",
#     "horarios-de-omnibus-urbanos-por-parada-stm",
#     "horarios-de-omnibus-urbanos-por-puntos-de-control-stm",
#     "ide-calles-por-localidad-y-departamento",
#     "ide-curvas-de-nivel",
#     "ide-direcciones-geograficas-del-uruguay",
#     "ide-limites-departamentales",
#     "ide-localidades-del-uruguay",
#     "ide-ortofotos-urbano",
#     "ide-ortoimagen-mdt-de-cobertura-nacional",
#     "idp-arbolado_paysandu",
#     "idp-autoridades_idp",
#     "idp-bienes-patrimoniales-de-la-ciudad-de-paysandu",
#     "idp-circuitos-y-recoleccion-en-paysandu",
#     "idp-datos_contacto_idp",
#     "idp-licitaciones_idp",
#     "idp-organigrama",
#     "idp-parque-automotor-de-paysandu",
#     "idp-recorridoyhorarios-omnibus-pay",
#     "idp-remuneraciones_idp",
#     "imputaciones-y-condenas-a-personas",
#     "inau-entidades",
#     "inau-motivos_atencion",
#     "inau-poblacion_y_proyectos",
#     "incautaciones",
#     "indicadores-de-gestion-de-los-canales-de-atencion-a-la-ciudadania",
#     "indicadores-de-la-declaracion-jurada-dicose-snig-2016",
#     "indicadores-de-la-declaracion-jurada-dicose-snig-2017",
#     "indicadores-de-la-declaracion-jurada-dicose-snig-2018",
#     "indicadores-de-la-declaracion-jurada-dicose-snig-2019",
#     "ine-autoridades_ine",
#     "ine-compensaciones_remuneraciones_por_concepto",
#     "ine-datos_contacto_ine",
#     "ine-ech2011",
#     "ine-encuesta-continua-de-hogares-2012",
#     "ine-encuesta-continua-de-hogares-ano-2013",
#     "ine-encuesta-continua-de-hogares-ano-2014",
#     "ine-encuesta-continua-de-hogares-ano-2015",
#     "ine-encuesta-continua-de-hogares-ano-2016",
#     "ine-encuesta-continua-de-hogares-ano-2017",
#     "ine-eutic",
#     "ine-marco_juridico_ine",
#     "ine-organigrama_ine",
#     "ine-presupuesto_ine",
#     "ine-remuneraciones_ine",
#     "informacion-de-productos-registrados",
#     "informacion-pluviometrica",
#     "inia-anr-por-grilla",
#     "inia-erosion-hidrica-del-suelo-estimada-para-99-cuencas-uruguayas",
#     "inia-ibh-por-grilla",
#     "inia-pad-por-grilla",
#     "inia-precipitacion-temps-extremas-lb",
#     "inia-precipitacion-temps-extremas-le",
#     "inia-precipitacion-temps-extremas-sg",
#     "inia-precipitacion-temps-extremas-tb",
#     "inia-precipitacion-temps-extremas-tyt",
#     "instituto-nacional-de-colonizacion-ofrecimientos-de-tierra",
#     "instituto-nacional-de-colonizacion-tierras-compradas",
#     "intendencia-de-canelones-autoridades",
#     "intendencia-de-canelones-funcionarios_en_comision",
#     "intendencia-de-canelones-llamados_y_concursos",
#     "intendencia-de-canelones-remuneraciones",
#     "intendencia-de-durazno-de-interes-para-el-turista",
#     "intendencia-de-durazno-padrones-urbanos-y-rurales-de-durazno",
#     "intendencia-de-durazno-rendicion-de-cuentas",
#     "intendencia-de-durazno-rendicion-de-cuentas-2018",
#     "intendencia-de-durazno-rendicion-de-cuentas-anio-2020",
#     "intendencia-de-durazno-rendicion-de-cuentas-de-2021",
#     "intendencia-de-durazno-rendicion-de-cuentas-de-2022",
#     "intendencia-de-durazno-rendicion-de-cuentas-v02",
#     "intendencia-de-florida-estructura-de-remuneraciones",
#     "intendencia-de-florida-organigrama",
#     "intendencia-de-rocha-alumbrado-publico",
#     "intendencia-de-rocha-ciclovias",
#     "intendencia-de-rocha-directrices-departamentales-departamento-de-rocha",
#     "intendencia-de-rocha-ejes-de-calles-departamento-de-rocha",
#     "intendencia-de-rocha-ordenanza-de-construccion",
#     "intendencia-de-rocha-parcelas-urbanas-departamento-de-rocha",
#     "intendencia-de-rocha-plan-local-de-ordenamiento-territorial-lagunas-costeras-departamento-de-rocha",
#     "intendencia-de-rocha-zonas-tributarias",
#     "intendencia-de-san-jose-mapa-social-de-san-jose",
#     "intendencia-de-san-jose-prestadores-de-servicios-turisticos",
#     "intendencia-durazno-rendicion-cuentas-2019",
#     "intendencia-montevideo-prod",
#     "intendencia-san-jose-arbolado-san-jose",
#     "interfaz-de-consulta-de-publicaciones-realizadas",
#     "inventario-de-datos",
#     "islas-de-calor-urbanas",
#     "jerarquizacion-vial-del-plan-de-ordenamiento-territorial",
#     "junta-departamental-de-florida-jdf_asistencias",
#     "junta-departamental-de-maldonado-decretos",
#     "junta-departamental-de-maldonado-funcionarios",
#     "junta-departamental-de-maldonado-indice-de-decretos-desde-4010-en-adelante",
#     "junta-departamental-de-maldonado-mof",
#     "junta-departamental-de-maldonado-sueldos",
#     "junta-departamental-de-maldonado-suplentes",
#     "junta-departamental-de-maldonado-titulares",
#     "km-de-fibra-optica-por-departamento",
#     "la-diaria-gestion-agua-uruguay",
#     "latu-acerca_latu",
#     "latu-capital_humano_latu",
#     "latu-informacion_estadistica_latu",
#     "latu-mecanismos_participacion_latu",
#     "latu-presupuesto_ejecucion_latu",
#     "limites-de-centros-comunales-zonales",
#     "limites-de-municipios-de-montevideo",
#     "limnigrafo-2022",
#     "lineas-de-omnibus-origen-y-destino",
#     "lineas-de-omnibus-variantes-no-maximales",
#     "llamados_concursos",
#     "locales-de-recarga-del-stm",
#     "manzanas",
#     "mapa-de-cobertura-de-suelo-urbano",
#     "marco-de-referencia-geodesico",
#     "mgap-bosque-nativo",
#     "mgap-bosques-plantados-forestacion",
#     "mgap-datos-2018-generados-en-base-a-la-declaracion-jurada-de-existencias-dicose-snig",
#     "mgap-datos-actualizados-de-la-declaracion-jurada-de-existencias-dicose-snig-2017",
#     "mgap-datos-actualizados-de-la-declaracion-jurada-de-existencias-dicose-snig-2023",
#     "mgap-datos-generados-en-base-a-la-declaracion-jurada-de-existencias-dicose-snig-2016",
#     "mgap-datos-preliminares-basados-en-la-declaracion-jurada-de-existencias-dicose-snig-2019",
#     "mgap-datos-preliminares-basados-en-la-declaracion-jurada-de-existencias-dicose-snig-2020",
#     "mgap-datos-preliminares-basados-en-la-declaracion-jurada-de-existencias-dicose-snig-2021",
#     "mgap-fae-sp-diciembre-2020",
#     "mgap-fae-sp-marzo-2020",
#     "mgap-serie-precio-de-la-tierra-arrendamientos",
#     "mgap-serie-precio-de-la-tierra-compraventas",
#     "mides-datos-de-panel-uruguay-integra",
#     "mides-encuesta-de-nutricion-desarrollo-infantil-y-salud-endis-cohorte-2013",
#     "mides-encuesta-de-nutricion-desarrollo-infantil-y-salud-endis-cohorte-2018",
#     "mides-indicador-10000",
#     "mides-indicador-10002",
#     "mides-indicador-10006",
#     "mides-indicador-10008",
#     "mides-indicador-10012",
#     "mides-indicador-10014",
#     "mides-indicador-10020",
#     "mides-indicador-10022",
#     "mides-indicador-10024",
#     "mides-indicador-10039",
#     "mides-indicador-10051",
#     "mides-indicador-10053",
#     "mides-indicador-10059",
#     "mides-indicador-10063",
#     "mides-indicador-10091",
#     "mides-indicador-10128",
#     "mides-indicador-10143",
#     "mides-indicador-10145",
#     "mides-indicador-10149",
#     "mides-indicador-10154",
#     "mides-indicador-10158",
#     "mides-indicador-10160",
#     "mides-indicador-10166",
#     "mides-indicador-10169",
#     "mides-indicador-10171",
#     "mides-indicador-10173",
#     "mides-indicador-10175",
#     "mides-indicador-10186",
#     "mides-indicador-10189",
#     "mides-indicador-10198",
#     "mides-indicador-10200",
#     "mides-indicador-10202",
#     "mides-indicador-10205",
#     "mides-indicador-10207",
#     "mides-indicador-10209",
#     "mides-indicador-10211",
#     "mides-indicador-10213",
#     "mides-indicador-10217",
#     "mides-indicador-10219",
#     "mides-indicador-10221",
#     "mides-indicador-10223",
#     "mides-indicador-10225",
#     "mides-indicador-10227",
#     "mides-indicador-10229",
#     "mides-indicador-10231",
#     "mides-indicador-10233",
#     "mides-indicador-10235",
#     "mides-indicador-10239",
#     "mides-indicador-10241",
#     "mides-indicador-10243",
#     "mides-indicador-10245",
#     "mides-indicador-10248",
#     "mides-indicador-10258",
#     "mides-indicador-10262",
#     "mides-indicador-10268",
#     "mides-indicador-10314",
#     "mides-indicador-10317",
#     "mides-indicador-10321",
#     "mides-indicador-10340",
#     "mides-indicador-10350",
#     "mides-indicador-10354",
#     "mides-indicador-10357",
#     "mides-indicador-10364",
#     "mides-indicador-10368",
#     "mides-indicador-10370",
#     "mides-indicador-10372",
#     "mides-indicador-10374",
#     "mides-indicador-10376",
#     "mides-indicador-10378",
#     "mides-indicador-10380",
#     "mides-indicador-10382",
#     "mides-indicador-10386",
#     "mides-indicador-10390",
#     "mides-indicador-10394",
#     "mides-indicador-10396",
#     "mides-indicador-10398",
#     "mides-indicador-10412",
#     "mides-indicador-10416",
#     "mides-indicador-10418",
#     "mides-indicador-10422",
#     "mides-indicador-10424",
#     "mides-indicador-10426",
#     "mides-indicador-10428",
#     "mides-indicador-10430",
#     "mides-indicador-10432",
#     "mides-indicador-10434",
#     "mides-indicador-10436",
#     "mides-indicador-10438",
#     "mides-indicador-10440",
#     "mides-indicador-10443",
#     "mides-indicador-10447",
#     "mides-indicador-10449",
#     "mides-indicador-10451",
#     "mides-indicador-10454",
#     "mides-indicador-10456",
#     "mides-indicador-10458",
#     "mides-indicador-10461",
#     "mides-indicador-10463",
#     "mides-indicador-10467",
#     "mides-indicador-10469",
#     "mides-indicador-10471",
#     "mides-indicador-10473",
#     "mides-indicador-10476",
#     "mides-indicador-10478",
#     "mides-indicador-10483",
#     "mides-indicador-10488",
#     "mides-indicador-10491",
#     "mides-indicador-10505",
#     "mides-indicador-10507",
#     "mides-indicador-10509",
#     "mides-indicador-10511",
#     "mides-indicador-10513",
#     "mides-indicador-10517",
#     "mides-indicador-10531",
#     "mides-indicador-10540",
#     "mides-indicador-10542",
#     "mides-indicador-10545",
#     "mides-indicador-10550",
#     "mides-indicador-10558",
#     "mides-indicador-10561",
#     "mides-indicador-10568",
#     "mides-indicador-10581",
#     "mides-indicador-10585",
#     "mides-indicador-10587",
#     "mides-indicador-10589",
#     "mides-indicador-10591",
#     "mides-indicador-10613",
#     "mides-indicador-10667",
#     "mides-indicador-10669",
#     "mides-indicador-10671",
#     "mides-indicador-10673",
#     "mides-indicador-10675",
#     "mides-indicador-10678",
#     "mides-indicador-10684",
#     "mides-indicador-10686",
#     "mides-indicador-10688",
#     "mides-indicador-10694",
#     "mides-indicador-10696",
#     "mides-indicador-10698",
#     "mides-indicador-10700",
#     "mides-indicador-10702",
#     "mides-indicador-10704",
#     "mides-indicador-10706",
#     "mides-indicador-10708",
#     "mides-indicador-10710",
#     "mides-indicador-10712",
#     "mides-indicador-10714",
#     "mides-indicador-10721",
#     "mides-indicador-10724",
#     "mides-indicador-10730",
#     "mides-indicador-10735",
#     "mides-indicador-10737",
#     "mides-indicador-10739",
#     "mides-indicador-10741",
#     "mides-indicador-10743",
#     "mides-indicador-10745",
#     "mides-indicador-10749",
#     "mides-indicador-10751",
#     "mides-indicador-10753",
#     "mides-indicador-10755",
#     "mides-indicador-10757",
#     "mides-indicador-10759",
#     "mides-indicador-10761",
#     "mides-indicador-10763",
#     "mides-indicador-10769",
#     "mides-indicador-10777",
#     "mides-indicador-10779",
#     "mides-indicador-10781",
#     "mides-indicador-10783",
#     "mides-indicador-10786",
#     "mides-indicador-10796",
#     "mides-indicador-10799",
#     "mides-indicador-10801",
#     "mides-indicador-10803",
#     "mides-indicador-10805",
#     "mides-indicador-10807",
#     "mides-indicador-10809",
#     "mides-indicador-10811",
#     "mides-indicador-10813",
#     "mides-indicador-10815",
#     "mides-indicador-10817",
#     "mides-indicador-10819",
#     "mides-indicador-10821",
#     "mides-indicador-10825",
#     "mides-indicador-10827",
#     "mides-indicador-10829",
#     "mides-indicador-10831",
#     "mides-indicador-10833",
#     "mides-indicador-10835",
#     "mides-indicador-10839",
#     "mides-indicador-10841",
#     "mides-indicador-10845",
#     "mides-indicador-10850",
#     "mides-indicador-10852",
#     "mides-indicador-10854",
#     "mides-indicador-10856",
#     "mides-indicador-10858",
#     "mides-indicador-10860",
#     "mides-indicador-10862",
#     "mides-indicador-10864",
#     "mides-indicador-10866",
#     "mides-indicador-10868",
#     "mides-indicador-10870",
#     "mides-indicador-10872",
#     "mides-indicador-10876",
#     "mides-indicador-10878",
#     "mides-indicador-10880",
#     "mides-indicador-10882",
#     "mides-indicador-10885",
#     "mides-indicador-10892",
#     "mides-indicador-10894",
#     "mides-indicador-10896",
#     "mides-indicador-10898",
#     "mides-indicador-10900",
#     "mides-indicador-10902",
#     "mides-indicador-10905",
#     "mides-indicador-10907",
#     "mides-indicador-10909",
#     "mides-indicador-10911",
#     "mides-indicador-10913",
#     "mides-indicador-10915",
#     "mides-indicador-10917",
#     "mides-indicador-10919",
#     "mides-indicador-10921",
#     "mides-indicador-10923",
#     "mides-indicador-10925",
#     "mides-indicador-10927",
#     "mides-indicador-10929",
#     "mides-indicador-10931",
#     "mides-indicador-10933",
#     "mides-indicador-10935",
#     "mides-indicador-10937",
#     "mides-indicador-10939",
#     "mides-indicador-10941",
#     "mides-indicador-10943",
#     "mides-indicador-10945",
#     "mides-indicador-10947",
#     "mides-indicador-10949",
#     "mides-indicador-10952",
#     "mides-indicador-10954",
#     "mides-indicador-10956",
#     "mides-indicador-10958",
#     "mides-indicador-10960",
#     "mides-indicador-10962",
#     "mides-indicador-10964",
#     "mides-indicador-10966",
#     "mides-indicador-10968",
#     "mides-indicador-10970",
#     "mides-indicador-10972",
#     "mides-indicador-10982",
#     "mides-indicador-10984",
#     "mides-indicador-10991",
#     "mides-indicador-10997",
#     "mides-indicador-10999",
#     "mides-indicador-11001",
#     "mides-indicador-11003",
#     "mides-indicador-11005",
#     "mides-indicador-11007",
#     "mides-indicador-11009",
#     "mides-indicador-11011",
#     "mides-indicador-11013",
#     "mides-indicador-11015",
#     "mides-indicador-11017",
#     "mides-indicador-11019",
#     "mides-indicador-11021",
#     "mides-indicador-11025",
#     "mides-indicador-11027",
#     "mides-indicador-11029",
#     "mides-indicador-11031",
#     "mides-indicador-11033",
#     "mides-indicador-11035",
#     "mides-indicador-11070",
#     "mides-indicador-11075",
#     "mides-indicador-11081",
#     "mides-indicador-11083",
#     "mides-indicador-11086",
#     "mides-indicador-11089",
#     "mides-indicador-11096",
#     "mides-indicador-11100",
#     "mides-indicador-11104",
#     "mides-indicador-11106",
#     "mides-indicador-11110",
#     "mides-indicador-11112",
#     "mides-indicador-11114",
#     "mides-indicador-11119",
#     "mides-indicador-11121",
#     "mides-indicador-11125",
#     "mides-indicador-11128",
#     "mides-indicador-11131",
#     "mides-indicador-11134",
#     "mides-indicador-11139",
#     "mides-indicador-11151",
#     "mides-indicador-11152",
#     "mides-indicador-11155",
#     "mides-indicador-11157",
#     "mides-indicador-11159",
#     "mides-indicador-11161",
#     "mides-indicador-11163",
#     "mides-indicador-11165",
#     "mides-indicador-11167",
#     "mides-indicador-11169",
#     "mides-indicador-11172",
#     "mides-indicador-11175",
#     "mides-indicador-11177",
#     "mides-indicador-11179",
#     "mides-indicador-11181",
#     "mides-indicador-11183",
#     "mides-indicador-11185",
#     "mides-indicador-11187",
#     "mides-indicador-11189",
#     "mides-indicador-11191",
#     "mides-indicador-11193",
#     "mides-indicador-11195",
#     "mides-indicador-11197",
#     "mides-indicador-11199",
#     "mides-indicador-11201",
#     "mides-indicador-11203",
#     "mides-indicador-11205",
#     "mides-indicador-11207",
#     "mides-indicador-11209",
#     "mides-indicador-11211",
#     "mides-indicador-11213",
#     "mides-indicador-11215",
#     "mides-indicador-11217",
#     "mides-indicador-11219",
#     "mides-indicador-11220",
#     "mides-indicador-11224",
#     "mides-indicador-11226",
#     "mides-indicador-11229",
#     "mides-indicador-11231",
#     "mides-indicador-11232",
#     "mides-indicador-11234",
#     "mides-indicador-11237",
#     "mides-indicador-11239",
#     "mides-indicador-11241",
#     "mides-indicador-11243",
#     "mides-indicador-11244",
#     "mides-indicador-11247",
#     "mides-indicador-11249",
#     "mides-indicador-11251",
#     "mides-indicador-11253",
#     "mides-indicador-11255",
#     "mides-indicador-11257",
#     "mides-indicador-11259",
#     "mides-indicador-11261",
#     "mides-indicador-11263",
#     "mides-indicador-11265",
#     "mides-indicador-11267",
#     "mides-indicador-11269",
#     "mides-indicador-11271",
#     "mides-indicador-11277",
#     "mides-indicador-11279",
#     "mides-indicador-11281",
#     "mides-indicador-11283",
#     "mides-indicador-11285",
#     "mides-indicador-11287",
#     "mides-indicador-11289",
#     "mides-indicador-11291",
#     "mides-indicador-11293",
#     "mides-indicador-11295",
#     "mides-indicador-11297",
#     "mides-indicador-11300",
#     "mides-indicador-11302",
#     "mides-indicador-11305",
#     "mides-indicador-11307",
#     "mides-indicador-11309",
#     "mides-indicador-11311",
#     "mides-indicador-11318",
#     "mides-indicador-11324",
#     "mides-indicador-11328",
#     "mides-indicador-11332",
#     "mides-indicador-11335",
#     "mides-indicador-11341",
#     "mides-indicador-11350",
#     "mides-indicador-11353",
#     "mides-indicador-11359",
#     "mides-indicador-11361",
#     "mides-indicador-11363",
#     "mides-indicador-11369",
#     "mides-indicador-11400",
#     "mides-indicador-11407",
#     "mides-indicador-11409",
#     "mides-indicador-11411",
#     "mides-indicador-11413",
#     "mides-indicador-11415",
#     "mides-indicador-11417",
#     "mides-indicador-11419",
#     "mides-indicador-11421",
#     "mides-indicador-11424",
#     "mides-indicador-11429",
#     "mides-indicador-11430",
#     "mides-indicador-11432",
#     "mides-indicador-11435",
#     "mides-indicador-11437",
#     "mides-indicador-11439",
#     "mides-indicador-11440",
#     "mides-indicador-11443",
#     "mides-indicador-11445",
#     "mides-indicador-11449",
#     "mides-indicador-11451",
#     "mides-indicador-11454",
#     "mides-indicador-11460",
#     "mides-indicador-11463",
#     "mides-indicador-11465",
#     "mides-indicador-11467",
#     "mides-indicador-11469",
#     "mides-indicador-11472",
#     "mides-indicador-11474",
#     "mides-indicador-11476",
#     "mides-indicador-11478",
#     "mides-indicador-11480",
#     "mides-indicador-11482",
#     "mides-indicador-11484",
#     "mides-indicador-11486",
#     "mides-indicador-11488",
#     "mides-indicador-11494",
#     "mides-indicador-11498",
#     "mides-indicador-11500",
#     "mides-indicador-11502",
#     "mides-indicador-11504",
#     "mides-indicador-11508",
#     "mides-indicador-11513",
#     "mides-indicador-11518",
#     "mides-indicador-11520",
#     "mides-indicador-11522",
#     "mides-indicador-11524",
#     "mides-indicador-11527",
#     "mides-indicador-11529",
#     "mides-indicador-11531",
#     "mides-indicador-11536",
#     "mides-indicador-11538",
#     "mides-indicador-11540",
#     "mides-indicador-11542",
#     "mides-indicador-11544",
#     "mides-indicador-11546",
#     "mides-indicador-11548",
#     "mides-indicador-11550",
#     "mides-indicador-11552",
#     "mides-indicador-11554",
#     "mides-indicador-11558",
#     "mides-indicador-11562",
#     "mides-indicador-11567",
#     "mides-indicador-11568",
#     "mides-indicador-11578",
#     "mides-indicador-11580",
#     "mides-indicador-11582",
#     "mides-indicador-11587",
#     "mides-indicador-11589",
#     "mides-indicador-11593",
#     "mides-indicador-11600",
#     "mides-indicador-11604",
#     "mides-indicador-11608",
#     "mides-indicador-11614",
#     "mides-indicador-11616",
#     "mides-indicador-11617",
#     "mides-indicador-11620",
#     "mides-indicador-11622",
#     "mides-indicador-11626",
#     "mides-indicador-11627",
#     "mides-indicador-11630",
#     "mides-indicador-11633",
#     "mides-indicador-11637",
#     "mides-indicador-11639",
#     "mides-indicador-11643",
#     "mides-indicador-11645",
#     "mides-indicador-11647",
#     "mides-indicador-11648",
#     "mides-indicador-11653",
#     "mides-indicador-11655",
#     "mides-indicador-11658",
#     "mides-indicador-11661",
#     "mides-indicador-11662",
#     "mides-indicador-11663",
#     "mides-indicador-11667",
#     "mides-indicador-11669",
#     "mides-indicador-11671",
#     "mides-indicador-11673",
#     "mides-indicador-11675",
#     "mides-indicador-11677",
#     "mides-indicador-11681",
#     "mides-indicador-11683",
#     "mides-indicador-11685",
#     "mides-indicador-11687",
#     "mides-indicador-11689",
#     "mides-indicador-11691",
#     "mides-indicador-11693",
#     "mides-indicador-11695",
#     "mides-indicador-11697",
#     "mides-indicador-11699",
#     "mides-indicador-11701",
#     "mides-indicador-11703",
#     "mides-indicador-11705",
#     "mides-indicador-11707",
#     "mides-indicador-11709",
#     "mides-indicador-11711",
#     "mides-indicador-11713",
#     "mides-indicador-11715",
#     "mides-indicador-11718",
#     "mides-indicador-11720",
#     "mides-indicador-11724",
#     "mides-indicador-11737",
#     "mides-indicador-11751",
#     "mides-indicador-11765",
#     "mides-indicador-11768",
#     "mides-indicador-11780",
#     "mides-indicador-11789",
#     "mides-indicador-11790",
#     "mides-indicador-11793",
#     "mides-indicador-11795",
#     "mides-indicador-11797",
#     "mides-indicador-11806",
#     "mides-indicador-11807",
#     "mides-indicador-11820",
#     "mides-indicador-11822",
#     "mides-indicador-11824",
#     "mides-indicador-11826",
#     "mides-indicador-11828",
#     "mides-indicador-11830",
#     "mides-indicador-11838",
#     "mides-indicador-11840",
#     "mides-indicador-11850",
#     "mides-indicador-11852",
#     "mides-indicador-11854",
#     "mides-indicador-11857",
#     "mides-indicador-11859",
#     "mides-indicador-11861",
#     "mides-indicador-11863",
#     "mides-indicador-11865",
#     "mides-indicador-11867",
#     "mides-indicador-11870",
#     "mides-indicador-11909",
#     "mides-indicador-11911",
#     "mides-indicador-11913",
#     "mides-indicador-11915",
#     "mides-indicador-11917",
#     "mides-indicador-11920",
#     "mides-indicador-11922",
#     "mides-indicador-11924",
#     "mides-indicador-11926",
#     "mides-indicador-11928",
#     "mides-indicador-11930",
#     "mides-indicador-11932",
#     "mides-indicador-11934",
#     "mides-indicador-11936",
#     "mides-indicador-11938",
#     "mides-indicador-11939",
#     "mides-indicador-11949",
#     "mides-indicador-11953",
#     "mides-indicador-11955",
#     "mides-indicador-11957",
#     "mides-indicador-11963",
#     "mides-indicador-11967",
#     "mides-indicador-11993",
#     "mides-indicador-12027",
#     "mides-indicador-12031",
#     "mides-indicador-12043",
#     "mides-indicador-12047",
#     "mides-indicador-12057",
#     "mides-indicador-12064",
#     "mides-indicador-12066",
#     "mides-indicador-12068",
#     "mides-indicador-12070",
#     "mides-indicador-12072",
#     "mides-indicador-12074",
#     "mides-indicador-12076",
#     "mides-indicador-12078",
#     "mides-indicador-12080",
#     "mides-indicador-12084",
#     "mides-indicador-12088",
#     "mides-indicador-12090",
#     "mides-indicador-12092",
#     "mides-indicador-12094",
#     "mides-indicador-12096",
#     "mides-indicador-12098",
#     "mides-indicador-12100",
#     "mides-indicador-12102",
#     "mides-indicador-12433",
#     "mides-indicador-12435",
#     "mides-indicador-12438",
#     "mides-indicador-12441",
#     "mides-indicador-12443",
#     "mides-indicador-12447",
#     "mides-indicador-12449",
#     "mides-indicador-12455",
#     "mides-indicador-12458",
#     "mides-indicador-12460",
#     "mides-indicador-12461",
#     "mides-indicador-12464",
#     "mides-indicador-12466",
#     "mides-indicador-12468",
#     "mides-indicador-12471",
#     "mides-indicador-12474",
#     "mides-indicador-12478",
#     "mides-indicador-12480",
#     "mides-indicador-12482",
#     "mides-indicador-12483",
#     "mides-indicador-12486",
#     "mides-indicador-12488",
#     "mides-indicador-12490",
#     "mides-indicador-12493",
#     "mides-indicador-12499",
#     "mides-indicador-12502",
#     "mides-indicador-12504",
#     "mides-indicador-12508",
#     "mides-indicador-12510",
#     "mides-indicador-12512",
#     "mides-indicador-12514",
#     "mides-indicador-12516",
#     "mides-indicador-12519",
#     "mides-indicador-12521",
#     "mides-indicador-12524",
#     "mides-indicador-12526",
#     "mides-indicador-12529",
#     "mides-indicador-12533",
#     "mides-indicador-12535",
#     "mides-indicador-12539",
#     "mides-indicador-12541",
#     "mides-indicador-12543",
#     "mides-indicador-12545",
#     "mides-indicador-12547",
#     "mides-indicador-12550",
#     "mides-indicador-12552",
#     "mides-indicador-12555",
#     "mides-indicador-12559",
#     "mides-indicador-12561",
#     "mides-indicador-12563",
#     "mides-indicador-12565",
#     "mides-indicador-12569",
#     "mides-indicador-12571",
#     "mides-indicador-12572",
#     "mides-indicador-12575",
#     "mides-indicador-12581",
#     "mides-indicador-12583",
#     "mides-indicador-12610",
#     "mides-indicador-12613",
#     "mides-indicador-12617",
#     "mides-indicador-12619",
#     "mides-indicador-12621",
#     "mides-indicador-12623",
#     "mides-indicador-12625",
#     "mides-indicador-12628",
#     "mides-indicador-12630",
#     "mides-indicador-12632",
#     "mides-indicador-12634",
#     "mides-indicador-12636",
#     "mides-indicador-12638",
#     "mides-indicador-12640",
#     "mides-indicador-12642",
#     "mides-indicador-12644",
#     "mides-indicador-12646",
#     "mides-indicador-12648",
#     "mides-indicador-12650",
#     "mides-indicador-12652",
#     "mides-indicador-12654",
#     "mides-indicador-12656",
#     "mides-indicador-12658",
#     "mides-indicador-12660",
#     "mides-indicador-12662",
#     "mides-indicador-12664",
#     "mides-indicador-12666",
#     "mides-indicador-12668",
#     "mides-indicador-12670",
#     "mides-indicador-12672",
#     "mides-indicador-12674",
#     "mides-indicador-12676",
#     "mides-indicador-12678",
#     "mides-indicador-12680",
#     "mides-indicador-12682",
#     "mides-indicador-12684",
#     "mides-indicador-12686",
#     "mides-indicador-12688",
#     "mides-indicador-12690",
#     "mides-indicador-12692",
#     "mides-indicador-12694",
#     "mides-indicador-12696",
#     "mides-indicador-12698",
#     "mides-indicador-12700",
#     "mides-indicador-12702",
#     "mides-indicador-12704",
#     "mides-indicador-12706",
#     "mides-indicador-12709",
#     "mides-indicador-12711",
#     "mides-indicador-12713",
#     "mides-indicador-12715",
#     "mides-indicador-12717",
#     "mides-indicador-12719",
#     "mides-indicador-12721",
#     "mides-indicador-12723",
#     "mides-indicador-12725",
#     "mides-indicador-12727",
#     "mides-indicador-12729",
#     "mides-indicador-12731",
#     "mides-indicador-12733",
#     "mides-indicador-12735",
#     "mides-indicador-12737",
#     "mides-indicador-12739",
#     "mides-indicador-12741",
#     "mides-indicador-12743",
#     "mides-indicador-12745",
#     "mides-indicador-12747",
#     "mides-indicador-12749",
#     "mides-indicador-12751",
#     "mides-indicador-12753",
#     "mides-indicador-12755",
#     "mides-indicador-12757",
#     "mides-indicador-12759",
#     "mides-indicador-12761",
#     "mides-indicador-12763",
#     "mides-indicador-12765",
#     "mides-indicador-12767",
#     "mides-indicador-12770",
#     "mides-indicador-12772",
#     "mides-indicador-12774",
#     "mides-indicador-12776",
#     "mides-indicador-12778",
#     "mides-indicador-12780",
#     "mides-indicador-12782",
#     "mides-indicador-12784",
#     "mides-indicador-12786",
#     "mides-indicador-12788",
#     "mides-indicador-12790",
#     "mides-indicador-12792",
#     "mides-indicador-12801",
#     "mides-indicador-12803",
#     "mides-indicador-12805",
#     "mides-indicador-12807",
#     "mides-indicador-12811",
#     "mides-indicador-12814",
#     "mides-indicador-12816",
#     "mides-indicador-12818",
#     "mides-indicador-12820",
#     "mides-indicador-12822",
#     "mides-indicador-12825",
#     "mides-indicador-12826",
#     "mides-indicador-12829",
#     "mides-indicador-12831",
#     "mides-indicador-12833",
#     "mides-indicador-12835",
#     "mides-indicador-12837",
#     "mides-indicador-12839",
#     "mides-indicador-12841",
#     "mides-indicador-12843",
#     "mides-indicador-12845",
#     "mides-indicador-12847",
#     "mides-indicador-12849",
#     "mides-indicador-12851",
#     "mides-indicador-12853",
#     "mides-indicador-12855",
#     "mides-indicador-12857",
#     "mides-indicador-12859",
#     "mides-indicador-12860",
#     "mides-indicador-12863",
#     "mides-indicador-12864",
#     "mides-indicador-12867",
#     "mides-indicador-12869",
#     "mides-indicador-12871",
#     "mides-indicador-12875",
#     "mides-indicador-12877",
#     "mides-indicador-12879",
#     "mides-indicador-12881",
#     "mides-indicador-12883",
#     "mides-indicador-12885",
#     "mides-indicador-12887",
#     "mides-indicador-12889",
#     "mides-indicador-12891",
#     "mides-indicador-12897",
#     "mides-indicador-12898",
#     "mides-indicador-12901",
#     "mides-indicador-12903",
#     "mides-indicador-12905",
#     "mides-indicador-12907",
#     "mides-indicador-12909",
#     "mides-indicador-12911",
#     "mides-indicador-12913",
#     "mides-indicador-12916",
#     "mides-indicador-12919",
#     "mides-indicador-12921",
#     "mides-indicador-12923",
#     "mides-indicador-12925",
#     "mides-indicador-12927",
#     "mides-indicador-12929",
#     "mides-indicador-12931",
#     "mides-indicador-12933",
#     "mides-indicador-12936",
#     "mides-indicador-12938",
#     "mides-indicador-12940",
#     "mides-indicador-12941",
#     "mides-indicador-12944",
#     "mides-indicador-12946",
#     "mides-indicador-12948",
#     "mides-indicador-12950",
#     "mides-indicador-12952",
#     "mides-indicador-12956",
#     "mides-indicador-12957",
#     "mides-indicador-12960",
#     "mides-indicador-12964",
#     "mides-indicador-12966",
#     "mides-indicador-12968",
#     "mides-indicador-12970",
#     "mides-indicador-12972",
#     "mides-indicador-12974",
#     "mides-indicador-12976",
#     "mides-indicador-12978",
#     "mides-indicador-12980",
#     "mides-indicador-12984",
#     "mides-indicador-12986",
#     "mides-indicador-12988",
#     "mides-indicador-12990",
#     "mides-indicador-12992",
#     "mides-indicador-12995",
#     "mides-indicador-12997",
#     "mides-indicador-12999",
#     "mides-indicador-13001",
#     "mides-indicador-13003",
#     "mides-indicador-13005",
#     "mides-indicador-13009",
#     "mides-indicador-13011",
#     "mides-indicador-13013",
#     "mides-indicador-13015",
#     "mides-indicador-13017",
#     "mides-indicador-13019",
#     "mides-indicador-13021",
#     "mides-indicador-13023",
#     "mides-indicador-13026",
#     "mides-indicador-13028",
#     "mides-indicador-13029",
#     "mides-indicador-13032",
#     "mides-indicador-13034",
#     "mides-indicador-13036",
#     "mides-indicador-13037",
#     "mides-indicador-13038",
#     "mides-indicador-13039",
#     "mides-indicador-13044",
#     "mides-indicador-13046",
#     "mides-indicador-13048",
#     "mides-indicador-13049",
#     "mides-indicador-13050",
#     "mides-indicador-13052",
#     "mides-indicador-13056",
#     "mides-indicador-13058",
#     "mides-indicador-13060",
#     "mides-indicador-13062",
#     "mides-indicador-13064",
#     "mides-indicador-13066",
#     "mides-indicador-13067",
#     "mides-indicador-13070",
#     "mides-indicador-13072",
#     "mides-indicador-13074",
#     "mides-indicador-13075",
#     "mides-indicador-13078",
#     "mides-indicador-13080",
#     "mides-indicador-13082",
#     "mides-indicador-13084",
#     "mides-indicador-13088",
#     "mides-indicador-13089",
#     "mides-indicador-13092",
#     "mides-indicador-13094",
#     "mides-indicador-13096",
#     "mides-indicador-13098",
#     "mides-indicador-13100",
#     "mides-indicador-13102",
#     "mides-indicador-13104",
#     "mides-indicador-13105",
#     "mides-indicador-13109",
#     "mides-indicador-13111",
#     "mides-indicador-13113",
#     "mides-indicador-13115",
#     "mides-indicador-13117",
#     "mides-indicador-13120",
#     "mides-indicador-13124",
#     "mides-indicador-13125",
#     "mides-indicador-13126",
#     "mides-indicador-13130",
#     "mides-indicador-13131",
#     "mides-indicador-13134",
#     "mides-indicador-13136",
#     "mides-indicador-13138",
#     "mides-indicador-13140",
#     "mides-indicador-13142",
#     "mides-indicador-13144",
#     "mides-indicador-13146",
#     "mides-indicador-13148",
#     "mides-indicador-13150",
#     "mides-indicador-13152",
#     "mides-indicador-13154",
#     "mides-indicador-13156",
#     "mides-indicador-13158",
#     "mides-indicador-13177",
#     "mides-indicador-13198",
#     "mides-indicador-13201",
#     "mides-indicador-13203",
#     "mides-indicador-13231",
#     "mides-indicador-13236",
#     "mides-indicador-13242",
#     "mides-indicador-13246",
#     "mides-indicador-13252",
#     "mides-indicador-13254",
#     "mides-indicador-13256",
#     "mides-indicador-13258",
#     "mides-indicador-13271",
#     "mides-indicador-13283",
#     "mides-indicador-13284",
#     "mides-indicador-13295",
#     "mides-indicador-13308",
#     "mides-indicador-13310",
#     "mides-indicador-13312",
#     "mides-indicador-13314",
#     "mides-indicador-13316",
#     "mides-indicador-13318",
#     "mides-indicador-13320",
#     "mides-indicador-13322",
#     "mides-indicador-13324",
#     "mides-indicador-13338",
#     "mides-indicador-13340",
#     "mides-indicador-13342",
#     "mides-indicador-13344",
#     "mides-indicador-13346",
#     "mides-indicador-13349",
#     "mides-indicador-13351",
#     "mides-indicador-13353",
#     "mides-indicador-13355",
#     "mides-indicador-13357",
#     "mides-indicador-13359",
#     "mides-indicador-13365",
# ...
#     "mides-indicador-9475",
#     "mides-indicador-9479",
#     "mides-indicador-9490",
#     "mides-indicador-9492",
#     "mides-indicador-9498",
#     "mides-indicador-9500",
#     "mides-indicador-9524",
#     "mides-indicador-9526",
#     "mides-indicador-9528",
#     "mides-indicador-9541",
#     "mides-indicador-9545",
#     "mides-indicador-9549",
#     "mides-indicador-9551",
#     "mides-indicador-9553",
#     "mides-indicador-9555",
#     "mides-indicador-9562",
#     "mides-indicador-9564",
#     "mides-indicador-9566",
#     "mides-indicador-9568",
#     "mides-indicador-9578",
#     "mides-indicador-9590",
#     "mides-indicador-9592",
#     "mides-indicador-9596",
#     "mides-indicador-9598",
#     "mides-indicador-9600",
#     "mides-indicador-9602",
#     "mides-indicador-9604",
#     "mides-indicador-9607",
#     "mides-indicador-9609",
#     "mides-indicador-9613",
#     "mides-indicador-9617",
#     "mides-indicador-9619",
#     "mides-indicador-9622",
#     "mides-indicador-9624",
#     "mides-indicador-9632",
#     "mides-indicador-9634",
#     "mides-indicador-9636",
#     "mides-indicador-9638",
#     "mides-indicador-9640",
#     "mides-indicador-9642",
#     "mides-indicador-9644",
#     "mides-indicador-9646",
#     "mides-indicador-9648",
#     "mides-indicador-9650",
#     "mides-indicador-9655",
#     "mides-indicador-9657",
#     "mides-indicador-9661",
#     "mides-indicador-9663",
#     "mides-indicador-9665",
#     "mides-indicador-9667",
#     "mides-indicador-9669",
#     "mides-indicador-9671",
#     "mides-indicador-9675",
#     "mides-indicador-9679",
#     "mides-indicador-9681",
#     "mides-indicador-9683",
#     "mides-indicador-9685",
#     "mides-indicador-9687",
#     "mides-indicador-9689",
#     "mides-indicador-9692",
#     "mides-indicador-9710",
#     "mides-indicador-9712",
#     "mides-indicador-9714",
#     "mides-indicador-9716",
#     "mides-indicador-9718",
#     "mides-indicador-9722",
#     "mides-indicador-9725",
#     "mides-indicador-9727",
#     "mides-indicador-9729",
#     "mides-indicador-9731",
#     "mides-indicador-9733",
#     "mides-indicador-9735",
#     "mides-indicador-9737",
#     "mides-indicador-9739",
#     "mides-indicador-9747",
#     "mides-indicador-9749",
#     "mides-indicador-9751",
#     "mides-indicador-9753",
#     "mides-indicador-9755",
#     "mides-indicador-9758",
#     "mides-indicador-9760",
#     "mides-indicador-9763",
#     "mides-indicador-9765",
#     "mides-indicador-9767",
#     "mides-indicador-9769",
#     "mides-indicador-9773",
#     "mides-indicador-9777",
#     "mides-indicador-9779",
#     "mides-indicador-9781",
#     "mides-indicador-9787",
#     "mides-indicador-9789",
#     "mides-indicador-9791",
#     "mides-indicador-9793",
#     "mides-indicador-9795",
#     "mides-indicador-9800",
#     "mides-indicador-9808",
#     "mides-indicador-9810",
#     "mides-indicador-9812",
#     "mides-indicador-9814",
#     "mides-indicador-9816",
#     "mides-indicador-9819",
#     "mides-indicador-9821",
#     "mides-indicador-9823",
#     "mides-indicador-9825",
#     "mides-indicador-9827",
#     "mides-indicador-9829",
#     "mides-indicador-9831",
#     "mides-indicador-9834",
#     "mides-indicador-9838",
#     "mides-indicador-9840",
#     "mides-indicador-9842",
#     "mides-indicador-9844",
#     "mides-indicador-9846",
#     "mides-indicador-9848",
#     "mides-indicador-9850",
#     "mides-indicador-9852",
#     "mides-indicador-9860",
#     "mides-indicador-9891",
#     "mides-indicador-9899",
#     "mides-indicador-9918",
#     "mides-indicador-9924",
#     "mides-indicador-9932",
#     "mides-indicador-9938",
#     "mides-indicador-9951",
#     "mides-indicador-9981",
#     "mides-indicador-9984",
#     "mides-indicador-9986",
#     "mides-indicador-9994",
#     "mides-indicador-9996",
#     "mides-indicador-9998",
#     "mides-paneluruguaytrabaja2009",
#     "miem-abastecimiento-de-energia-por-fuente",
#     "miem-autoridades",
#     "miem-ben-factor-de-emision-de-co2-del-sin",
#     "miem-consumo-final-energetico-por-fuente",
#     "miem-consumo-final-energetico-por-sector",
#     "miem-dei",
#     "miem-emisiones-de-co2-por-sector",
#     "miem-encuestas-consumos-energia-industrial",
#     "miem-evolucion",
#     "miem-generacion-de-electricidad-por-fuente",
#     "miem-indicadores-de-eficiencia-energetica-por-sector",
#     "miem-instrumentos-de-apoyo-del-miem",
#     "miem-listados-de-empresas-e-instaladores-gasistas-habilitados",
#     "miem-organigrama",
#     "miem-potencia-instalada-por-fuente",
#     "miem-remuneraciones",
#     "miem-servicios_tramites",
#     "ministerio-del-interior-delitos_denunciados_en_el_uruguay",
#     "ministerio-de-transporte-y-obras-publicas-convenios",
#     "ministerio-de-transporte-y-obras-publicas-funcionarios_comision",
#     "ministerio-de-transporte-y-obras-publicas-horarios-de-omnibus-en-lineas-interdepartamentales",
#     "ministerio-de-transporte-y-obras-publicas-lidar-vergara",
#     "ministerio-de-transporte-y-obras-publicas-modelo",
#     "ministerio-de-transporte-y-obras-publicas-modelo-digital-de-superficie-de-piriapolis",
#     "ministerio-de-transporte-y-obras-publicas-recorridos-omnibus-suburbanos",
#     "ministerio-de-transporte-y-obras-publicas-remuneraciones_compensaciones_concepto",
#     "ministerio-de-transporte-y-obras-publicas-rutas-y-puntos-de-calibracion1",
#     "ministerio-de-turismo-registro-de-operadores",
#     "ministerio-de-turismo-registro-de-operadores-turisticos-para-actividades-deportivas",
#     "ministerio-de-turismo-registro-de-operadores-turisticos-para-agencias-de-transporte",
#     "ministerio-de-turismo-registro-de-operadores-turisticos-para-agencias-viaje-activos",
#     "ministerio-de-turismo-registro-de-operadores-turisticos-para-alojamientos",
#     "ministerio-de-turismo-registro-de-operadores-turisticos-para-avistamiento",
#     "ministerio-de-turismo-registro-de-operadores-turisticos-para-bodegas-turisticas-activos",
#     "ministerio-de-turismo-registro-de-operadores-turisticos-para-corredores",
#     "ministerio-de-turismo-registro-de-operadores-turisticos-para-establecimientos",
#     "ministerio-de-turismo-registro-de-operadores-turisticos-para-guias",
#     "ministerio-de-turismo-registro-de-operadores-turisticos-para-inmobiliarias-activos",
#     "ministerio-de-turismo-registro-de-operadores-turisticos-para-organizadores",
#     "ministerio-de-turismo-registro-de-operadores-turisticos-para-rentadoras-de-autos-activos",
#     "ministerio-de-turismo-registro-de-operadores-turisticos-para-salas",
#     "ministerio-de-turismo-registro-de-operadores-turisticos-para-turismo-aventura-activos",
#     "ministerio-de-turismo-turismo-cruceros",
#     "ministerio-de-turismo-turismo-emisivo",
#     "ministerio-de-turismo-turismo-receptivo",
#     "mirador-energetico",
#     "monitor-de-avances-de-vacunacion-por-covid-19-en-uruguay",
#     "monitor-de-datos-de-vacunacion-covid-19",
#     "monitoreo-de-efluentes-industriales",
#     "monitoreo-de-polen-y-esporas-fungicas-en-el-aire-de-montevideo",
#     "montevideo-bicis",
#     "montevideo-en-bici",
#     "montevideo-lbs",
#     "monumentos-historicos-y-bienes-de-interes-municipal",
#     "morosidad",
#     "morosidad-de-convenios",
#     "msp-a-tu-servicio",
#     "msp-objetivos-sanitarios-nacionales-2020",
#     "msp-tasa-de-enfermedades-y-eventos-de-notificaci-n-obligatoria",
#     "multas-de-transito",
#     "museo-nacional-de-artes-visuales-obras-del-acervo",
#     "mvd-bike-montevideo-en-bicicleta",
#     "nextbus-montevideo",
#     "nivel-de-tanques",
#     "nomenclator-de-calles",
#     "nomenclator-de-calles-de-montevideo-y-area-metropolitana",
#     "obras-del-presupuesto-participativo-montevideo-periodo-2006-2013",
#     "observatorio-afrodescendiente",
#     "observatorio-homicidios-y-denuncias-de-otros-delitos",
#     "oficinas-de-centros-comunales-zonales",
#     "oficinas-de-municipios",
#     "ollas-y-merenderos-apoyadas-por-el-plan-abc",
#     "omnibus-interior",
#     "onsc-encuesta_capacidades_fp",
#     "onsc-ingreso-de-personas-afrodescendientes-al-estado-por-organismo",
#     "onsc-ingreso_personas_con_discapacidad_al_estado",
#     "onsc-ingreso_personas_trans",
#     "onsc-vinculoslaborales",
#     "onsc-vinculos_laborales_sociedades_anonimas_2",
#     "opp-cantidad-de-rrhh-en-eepp",
#     "opp-clasificacion-funcional-del-presupuesto-con-indicadores",
#     "opp-compromisos-de-gestion-de-eepp",
#     "opp-credito-presupuestal-detallado-a-partir-de-2011",
#     "opp-evaluaciones-de-intervenciones-publicas",
#     "opp-historico-de-credito-presupuestal-ejecutado",
#     "opp-historico-de-credito-y-ejecucion-presupuestal-por-ue",
#     "opp-indicadores-financieros-de-eepp",
#     "opp-ingresos-y-egresos-de-los-gobiernos-departamentales-y-egresos-de-los-gobiernos-municipales",
#     "opp-listado-de-empresas-publicas",
#     "opp-listado-de-personas-publicas-no-estatales",
#     "opp-monto-ejecutado-en-proyectos-de-inversi-n",
#     "opp-objetivos-de-desarrollo-sostenible-y-sus-metas",
#     "opp-organismos-del-presupuesto-nacional",
#     "opp-planificacion-estrategica-de-organismos-y-ues",
#     "opp-presupuestos-quinquenales",
#     "opp-productos-de-las-unidades-ejecutoras",
#     "opp-sociedades-anonimas-en-que-participan-eepp",
#     "opp-vinculo-entre-ods-y-planificacion",
#     "organigrama",
#     "panel-de-indicadores-demograficos-de-funcionarios-del-estado",
#     "panel-de-indicadores-de-vinculos-con-el-estado",
#     "parcelas-catastrales",
#     "parcelas-catastrales-con-datos-del-plan-de-ordenamiento-territorial",
#     "parlamento-del-uruguay-actividades-del-senado",
#     "parlamento-del-uruguay-asistencias-a-la-camara-de-senadores",
#     "parlamento-del-uruguay-comisiones-de-la-camara-de-senadores",
#     "parlamento-del-uruguay-leyes-promulgadas-del-poder-ejecutivo",
#     "parlamento-del-uruguay-pedidos-de-informes-de-la-camara-de-senadores",
#     "parlamento-del-uruguay-proyectos-entrados-al-parlamento",
#     "parlamento-del-uruguay-repartidos-de-la-camara-de-senadores",
#     "parlamento-uruguayo-caso-piloto-1-caducidad",
#     "parlamento-uruguayo-caso-piloto-2-embarcaciones-deportivas",
#     "parlamento-uruguayo-caso-piloto-3-panes",
#     "parque-automotor-de-montevideo",
#     "partidas-de-registro-civil-de-montevideo",
#     "permisos-de-construccion-aprobados",
#     "pitanga",
#     "plan-abc-en-union-malvin-norte",
#     "planificacion-de-gobierno-en-portal-de-transparencia-presupuestaria",
#     "pluviometos",
#     "poblacion-por-zona-censal-en-montevideo",
#     "preciosgub",
#     "preciosuy",
#     "procesamiento-paralelo-de-registros-de-accidentes-y-multas-en-la-ciudad-de-montevideo",
#     "proximidad-para-la-vida-cotidiana",
#     "puntos-de-entrega-voluntaria-para-materiales-reciclables",
#     "puntos-interes",
#     "rampitauy",
#     "recaudacion",
#     "reclamos-de-arbolado-registrados-en-el-sistema-unico-de-reclamos",
#     "reclamos-registrados-en-el-sistema-unico-de-reclamos-de-la-intendencia-de-montevideo",
#     "red_correo",
#     "red-de-monitoreo-de-la-calidad-del-aire-de-montevideo",
#     "regimen-de-circulacion-de-vehiculos-de-carga",
#     "registro-unico-de-proveedores-del-estado-rupe-2023",
#     "remuneraciones",
#     "representatividad-en-calles",
#     "representatividad-en-espacios-publicos1",
#     "rodala",
#     "rss-de-publicaciones-realizadas",
#     "sinae01-areas-quemadas-de-incendios-forestales",
#     "sinae01-focos-de-incendios-registrados-en-el-sistema-mira",
#     "sistema-habitacional",
#     "solicitudes-en-espera-de-agenda-por-vacunacion-covid-19",
#     "stm-montevideo",
#     "suprema-corte-de-justicia-adolescentes-montevideo-2016",
#     "suprema-corte-de-justicia-anuario-estadistico-2016",
#     "suprema-corte-de-justicia-anuario-estadistico-2017",
#     "suprema-corte-de-justicia-anuario-estadistico-2018",
#     "suprema-corte-de-justicia-anuario-estadistico-2019",
#     "suprema-corte-de-justicia-anuario-estadistico-poder-judicial",
#     "suprema-corte-de-justicia-faltas-2017-procesos-concluidos-por-ley-n-19-120",
#     "suprema-corte-de-justicia-faltas-poder-judicial",
#     "suprema-corte-de-justicia-informacion-del-nuevo-codigo-de-proceso-penal",
#     "suprema-corte-de-justicia-penal-montevideo-2016",
#     "suprema-corte-de-justicia-penal-montevideo-2017",
#     "suprema-corte-de-justicia-presos",
#     "suprema-corte-de-justicia-remates-judiciales",
#     "susceptibilidad-de-erosion-de-los-suelos-de-uruguay",
#     "suscriptores-de-tv-abonados",
#     "tic-ministerio-del-interior-comisarias-uruguay",
#     "tic-ministerio-del-interior-destacamentos-d-n-b",
#     "tic-ministerio-del-interior-jefaturas",
#     "tic-ministerio-del-interior-seccionales-policiales",
#     "tic-ministerio-del-interior-uevdg",
#     "transporte-colectivo-paradas-puntos-de-control-y-recorridos-de-omnibus",
#     "uaip-auditorias-ta",
#     "uaip-autoridades_uaip",
#     "uaip-diario_sesiones_uaip",
#     "uaip-dictamenes",
#     "uaip-evolucion_uaip",
#     "uaip-indice-nacional-de-transparencia",
#     "uaip-indice-nacional-de-transparencia-y-acceso-a-la-informacion-intai-2022",
#     "uaip-informacion-reservada",
#     "uaip-marco_juridico_uaip",
#     "uaip-mecanismos_participacion_ciudadana_uaip",
#     "uaip-organigrama_uaip",
#     "uaip-resoluciones_uaip",
#     "uaip-responsables_transparencia_uaip",
#     "uaip-servicios_tramites",
#     "uaip-solicitud-informacion",
#     "ubicacion-de-policlinicas",
#     "ubicacion-de-sensores-de-medicion-de-conteo-vehiculos",
#     "ubicaciones-notables-monumentos-de-montevideo",
#     "udelar-actividades-del-programa-de-educacion-permanente-2022",
#     "unasev-fallecidos_siniestros_transito",
#     "unasev-serie-de-personas-fallecidas-en-siniestros-de-tr-nsito-en-el-a-o-2012-en-uruguay",
#     "unasev-siniestros-de-tr-nsito-en-uruguay-en-el-a-o-2011",
#     "urcdp-responsables_urcdp",
#     "ursea-autorizaciones-rspebt",
#     "ursea-ppi_vs_pe_v2",
#     "ursea-productos-electricos-autorizados-rspebt-2019",
#     "ursea-productos-electricos-autorizados-rspebt-2020",
#     "ursea-productos-electricos-autorizados-rspebt-2021",
#     "ursea-productos-electricos-autorizados-rspebt-2022",
#     "ursea-ursea_basesanciones2019",
#     "ursec-comisiones_exterior",
#     "ursec-datos_contacto",
#     "ursec-envios-postales",
#     "ursec-evolucion",
#     "ursec-llamados_concursos",
#     "ursec-marco_juridico",
#     "ursec-organigrama",
#     "ursec-perfil_puestos",
#     "ursec-presupuesto-ejecucion-presupuestal",
#     "ursec-remuneraciones",
#     "ursec-resoluciones-ursec",
#     "ursec-suscriptores-mensuales-por-servicios-de-telecomunicaciones-fijas",
#     "ursec-suscriptores-mensuales-por-servicios-moviles",
#     "ursec-suscriptores-mensuales-por-servicios-moviles-pospago",
#     "ursec-suscriptores-mensuales-por-servicios-moviles-prepago",
#     "ursec-telefonia_fija_comercial",
#     "ursec-telefonia_fija_residencial",
#     "ursec-telefonos_publicos",
#     "ursec-trafico-de-servicios-de-telecomunicaciones-fijas-y-moviles",
#     "ursec-viaticos",
#     "uruguay-atp-datos-basicos-de-las-19-juntas-departamentales",
#     "uruguay-atp-estado-de-situacion-juntas-uy",
#     "uruguay-atp-listado-de-comisiones-en-las-juntas-departamenteles-de-todo-el-pais",
#     "uruguay-atp-listado-de-ediles-de-todo-el-pais",
#     "usos-del-suelo-por-sector-de-actividad-ciiu-4",
#     "usos-en-suelo-rural",
#     "vacunacion-gripe-covid-19",
#     "vacunacion-por-covid-19",
#     "velocidad-promedio-vehicular-en-las-principales-avenidas-de-montevideo",
#     "viajeros",
#     "viajes-de-recoleccion-de-residuos-y-peso-asociado",
#     "viajes-realizados-en-los-omnibus-del-sistema-de-transporte-metropolitano-stm",
#     "vias-de-montevideo-con-cabezales-de-numeracion-significado-tipo-y-titulo",
#     "vias-de-transito",
#     "violencia-domestica-y-asociados",
#     "visualizador-de-ambitos-de-participacion-ciudadana",
#     "visualizador-de-avances-de-planes-de-accion-nacional-de-gobierno-abierto",
#     "visualizador-de-datos-de-violencia-domestica-y-genero",
#     "visualizador-de-emisiones-y-remociones-de-gases-de-efecto-invernadero",
#     "visualizador-del-balance-energetico-nacional",
#     "visualizador-del-indice-nacional-de-transparencia-y-acceso-a-la-informacion-intai",
#     "visualizador-de-objetivos-y-medidas-de-mitigacion-y-adaptacion-ante-el-cambio-climatico",
#     "visualizador-de-violencia-domestica-y-violencia-basada-en-genero",
#     "web-service-de-actualizaciones-al-catalogo",
#     "zonas-riparias-de-uruguay"
#   ]
# }

# %%
# Current Package List With Resources
#
# Es muy parecido al package search pero no se pueden hacer queries
# te trae los datasets ordenados por momento de utlima modificiación.
endpoint_suffix = 'current_package_list_with_resources'
url = build_url(endpoint_suffix)

pretty_print_json(do_get_request(url))
# Out:
# {
#   "help": "https://catalogodatos.gub.uy/es/api/3/action/help_show?name=current_package_list_with_resources",
#   "success": true,
#   "result": [
#     {
#       "author": "Investigación y Estadísticas Turísticas",
#       "author_email": "gardil@mintur.gub.uy",
#       "creator_user_id": "aa2189c9-4d61-41fd-9bd2-bf58e1ef4a79",
#       "id": "1c1d75d0-b3c9-4ea4-a519-8c6b1468e589",
#       "isopen": true,
#       "license_id": "odc-uy",
#       "license_title": "Licencia de DAG de Uruguay",
#       "license_url": "https://www.gub.uy/agencia-gobierno-electronico-sociedad-informacion-conocimiento/sites/agencia-gobierno-electronico-sociedad-informacion-conocimiento/files/documentos/publicaciones/licencia_de_datos_abiertos_0.pdf",
#       "maintainer": "Francisco Gardil",
#       "maintainer_email": "gardil@mintur.gub.uy",
#       "metadata_created": "2021-02-26T14:00:53.131099",
#       "metadata_modified": "2024-06-27T19:09:53.785622",
#       "name": "ministerio-de-turismo-turismo-emisivo",
#       "notes": "Conjunto referente a los datos de Turismo Emisivo, obtenidos a través de la encuesta de Turismo Receptivo, este conjunto contiene la información desagregada de los residentes de Uruguay que viajan fuera del país y el gasto de los mismos según destino principal del viaje. Datos obtenidos en cada trimestre desde el año 2016. La información que se encuentra publicada detalla los siguientes puntos: transporte internacional de salida, fecha de salida y fecha de entrada, nacionalidad, departamento de residencia, motivo de viaje, ocupación del viajante, nivel de estudios, destino, tipo de alojamiento, lugar de salida, transporte internacional de ingreso, transporte local, estadía, gasto total: en alojamiento, en transporte, en alimentación, en transporte local, en cultura, en tours, en compras etc.\r\n\r\nEsta información nos permite medir el flujo de los viajes al extranjero de los Uruguayos y  determinar las principales características de sus viajes,  así como también estimar el gasto que realizan durante el mismo.",
#       "num_resources": 4,
#       "num_tags": 5,
#       "organization": {
#         "id": "ae9728c8-8f10-42d4-9da2-3589c1cff788",
#         "name": "ministerio-de-turismo",
#         "title": "Ministerio de Turismo",
#         "type": "organization",
#         "description": "Ministerio de Turismo del Uruguay",
#         "image_url": "2020-08-04-132627.410343LOGO-MinTURISMO.png",
#         "created": "2012-11-13T15:09:54.163919",
#         "is_organization": true,
#         "approval_status": "approved",
#         "state": "active"
#       },
#       "owner_org": "ae9728c8-8f10-42d4-9da2-3589c1cff788",
#       "private": false,
#       "state": "active",
#       "title": "Turismo Emisivo",
#       "type": "dataset",
#       "update_frequency": "365",
#       "url": "https://www.gub.uy/ministerio-turismo/datos-y-estadisticas/estadisticas",
#       "version": "1.0",
#       "groups": [
#         {
#           "description": " ",
#           "display_name": "Turismo",
#           "id": "25e8c196-8fe5-4d07-baa3-288dbf0bd79d",
#           "image_display_url": "https://catalogodatos.gub.uy/uploads/group/2019-08-22-234046.841825turismo.png",
#           "name": "turismo",
#           "title": "Turismo"
#         }
#       ],
#       "resources": [
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2021-02-26T15:21:25.593822",
#           "datastore_active": true,
#           "description": "El recurso cuenta con los datos desagregados obtenidos en la Encuesta de turismo Emisivo sobre el flujo de los residentes de Uruguay que viajan fuera del país y el gasto de los mismos según destino principal del viaje.",
#           "format": "XLSX",
#           "hash": "",
#           "id": "39c37072-9f85-4cfd-b2ad-26819b02e3aa",
#           "last_modified": "2024-06-27T19:09:43.791200",
#           "licence": "Licencia de DAG de Uruguay",
#           "metadata_modified": "2024-06-27T19:09:47.628177",
#           "mimetype": "application/vnd.openxmlformats-officedocument.spreadsheetml.sheet",
#           "mimetype_inner": null,
#           "name": "Datos de Turismo Emisivo",
#           "package_id": "1c1d75d0-b3c9-4ea4-a519-8c6b1468e589",
#           "position": 0,
#           "qa": {
#             "resource_timestamp": null,
#             "archival_timestamp": "2022-05-31T11:15:35.658629",
#             "openness_score": 2,
#             "openness_score_reason": "Content of file appeared to be format \"XLS\" which receives openness score: 2.",
#             "format": "XLS",
#             "created": "2021-02-27T10:45:12.914177",
#             "updated": "2022-05-31T12:40:36.608834"
#           },
#           "resource_type": null,
#           "size": 5010204,
#           "spatial_coverage": "Uruguay",
#           "state": "active",
#           "temporal_coverage": "2016/12 - 2024/05",
#           "update_frequency": "30",
#           "url": "https://catalogodatos.gub.uy/dataset/1c1d75d0-b3c9-4ea4-a519-8c6b1468e589/resource/39c37072-9f85-4cfd-b2ad-26819b02e3aa/download/emisivo.xlsx",
#           "url_type": "upload"
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2021-02-26T15:21:29.253062",
#           "datastore_active": false,
#           "description": "El recurso cuenta con los datos desagregados obtenidos en la Encuesta de turismo Emisivo sobre el flujo de los residentes de Uruguay que viajan fuera del país y el gasto de los mismos según destino principal del viaje.",
#           "format": "CSV",
#           "hash": "",
#           "id": "922f23e1-296c-490a-a3df-61e03e122d17",
#           "last_modified": "2024-06-27T19:09:47.602200",
#           "licence": "Licencia de DAG de Uruguay",
#           "metadata_modified": "2024-06-27T19:09:52.798935",
#           "mimetype": "text/csv",
#           "mimetype_inner": null,
#           "name": "Datos de Turismo Emisivo",
#           "package_id": "1c1d75d0-b3c9-4ea4-a519-8c6b1468e589",
#           "position": 1,
#           "qa": {
#             "resource_timestamp": null,
#             "archival_timestamp": "2022-05-31T11:15:36.433797",
#             "openness_score": 3,
#             "openness_score_reason": "Content of file appeared to be format \"CSV\" which receives openness score: 3.",
#             "format": "CSV",
#             "created": "2021-02-27T10:45:12.945808",
#             "updated": "2022-05-31T12:40:36.676830"
#           },
#           "resource_type": null,
#           "size": 8800517,
#           "spatial_coverage": "Uruguay",
#           "state": "active",
#           "temporal_coverage": "2016/12 - 2024/05",
#           "update_frequency": "30",
#           "url": "https://catalogodatos.gub.uy/dataset/1c1d75d0-b3c9-4ea4-a519-8c6b1468e589/resource/922f23e1-296c-490a-a3df-61e03e122d17/download/emisivo.csv",
#           "url_type": "upload"
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2021-02-26T15:21:40.793599",
#           "datastore_active": false,
#           "description": "El recurso cuenta con los datos desagregados obtenidos en la Encuesta de turismo Emisivo sobre el flujo de los residentes de Uruguay que viajan fuera del país y el gasto de los mismos según destino principal del viaje.",
#           "format": "XML",
#           "hash": "",
#           "id": "db4a8328-8bd4-4df9-8c8a-77d6730091e7",
#           "last_modified": "2024-06-27T19:09:52.774063",
#           "licence": "Licencia de DAG de Uruguay",
#           "metadata_modified": "2024-06-27T19:09:53.797935",
#           "mimetype": "application/xml",
#           "mimetype_inner": null,
#           "name": "Datos de Turismo Emisivo",
#           "package_id": "1c1d75d0-b3c9-4ea4-a519-8c6b1468e589",
#           "position": 2,
#           "qa": {
#             "resource_timestamp": null,
#             "archival_timestamp": "2022-05-31T11:15:37.285178",
#             "openness_score": 3,
#             "openness_score_reason": "Content of file appeared to be format \"XML\" which receives openness score: 3.",
#             "format": "XML",
#             "created": "2021-02-27T10:45:12.966418",
#             "updated": "2022-05-31T12:40:36.690378"
#           },
#           "resource_type": null,
#           "size": 41349665,
#           "spatial_coverage": "Uruguay",
#           "state": "active",
#           "temporal_coverage": "2016/12 - 2024/05",
#           "update_frequency": "30",
#           "url": "https://catalogodatos.gub.uy/dataset/1c1d75d0-b3c9-4ea4-a519-8c6b1468e589/resource/db4a8328-8bd4-4df9-8c8a-77d6730091e7/download/emisivo.xml",
#           "url_type": "upload"
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2021-02-26T15:21:41.836035",
#           "datastore_active": false,
#           "description": "El recurso cuenta con los datos descriptivos del recurso de datos de turismo Emisivo.",
#           "format": "JSON",
#           "hash": "",
#           "id": "983ce95a-0c87-467d-8b87-46d3229d0e8a",
#           "last_modified": "2024-06-27T19:09:53.770315",
#           "licence": "Licencia de DAG de Uruguay",
#           "metadata_modified": "2024-06-27T19:09:53.798058",
#           "mimetype": "application/json",
#           "mimetype_inner": null,
#           "name": "Metadatos de Turismo emisivo",
#           "package_id": "1c1d75d0-b3c9-4ea4-a519-8c6b1468e589",
#           "position": 3,
#           "qa": {
#             "resource_timestamp": null,
#             "archival_timestamp": "2022-05-31T11:15:38.043418",
#             "openness_score": 3,
#             "openness_score_reason": "Content of file appeared to be format \"CSV\" which receives openness score: 3.",
#             "format": "CSV",
#             "created": "2021-02-27T10:45:13.159015",
#             "updated": "2022-05-31T12:40:36.827688"
#           },
#           "resource_type": null,
#           "size": 10724,
#           "spatial_coverage": "Uruguay",
#           "state": "active",
#           "temporal_coverage": "2016/12 - 2024/05",
#           "update_frequency": "30",
#           "url": "https://catalogodatos.gub.uy/dataset/1c1d75d0-b3c9-4ea4-a519-8c6b1468e589/resource/983ce95a-0c87-467d-8b87-46d3229d0e8a/download/metadatos_emisivo.json",
#           "url_type": "upload"
#         }
#       ],
#       "tags": [
#         {
#           "display_name": "Encuesta",
#           "id": "c141564a-5eed-4542-8140-ed23e3454197",
#           "name": "Encuesta",
#           "state": "active",
#           "vocabulary_id": null
#         },
#         {
#           "display_name": "Encuesta de turismo emisivo",
#           "id": "f0341887-6100-481b-a604-88d914af6cf2",
#           "name": "Encuesta de turismo emisivo",
#           "state": "active",
#           "vocabulary_id": null
#         },
#         {
#           "display_name": "Ministerio de Turismo",
#           "id": "aef90173-1979-40fd-9680-caf513697f17",
#           "name": "Ministerio de Turismo",
#           "state": "active",
#           "vocabulary_id": null
#         },
#         {
#           "display_name": "Turismo",
#           "id": "e4cfd528-2997-47dd-910f-717d245f9a43",
#           "name": "Turismo",
#           "state": "active",
#           "vocabulary_id": null
#         },
#         {
#           "display_name": "Turismo emisivo",
#           "id": "d405bae7-367b-4345-aa01-7d3633a86ff8",
#           "name": "Turismo emisivo",
#           "state": "active",
#           "vocabulary_id": null
#         }
#       ],
#       "relationships_as_subject": [],
#       "relationships_as_object": []
#     },
#     {
#       "author": "Área Gobierno Electrónico",
#       "author_email": "agedatoscovid@msp.gub.uy",
#       "creator_user_id": "30e0c393-dec0-482c-b0fb-ad6a0a9cab3d",
#       "id": "e766fbf7-0cc5-4b9a-a093-b56e91e88133",
#       "isopen": true,
#       "license_id": "odc-uy",
#       "license_title": "Licencia de DAG de Uruguay",
#       "license_url": "https://www.gub.uy/agencia-gobierno-electronico-sociedad-informacion-conocimiento/sites/agencia-gobierno-electronico-sociedad-informacion-conocimiento/files/documentos/publicaciones/licencia_de_datos_abiertos_0.pdf",
#       "maintainer": "Área Gobierno Electrónico",
#       "maintainer_email": "agedatoscovid@msp.gub.uy",
#       "metadata_created": "2021-05-28T18:27:41.852926",
#       "metadata_modified": "2024-06-27T19:02:40.460522",
#       "name": "vacunacion-por-covid-19",
#       "notes": "Este conjunto de datos presenta diferentes recursos vinculados a la evolución del plan de vacunación Covid 19.\r\nContiene actos vacunales detallados y acumulados diarios de actos vacunales realizados, cantidad de agendados y en espera de agenda.\r\n\r\nSe agregan datos de la nueva franja etaria de 5 a 11 años a los datos del Histórico de actos vacunales.\r\n\r\nSe agregan datos de dosis 3 y 4 presentando totales diarios por tipo de vacuna, dosis, departamentos y rango etario en el Histórico de actos vacunales.",
#       "num_resources": 8,
#       "num_tags": 4,
#       "organization": {
#         "id": "8a74eecc-8fbb-47a1-b808-bb668b96db29",
#         "name": "msp",
#         "title": "Ministerio de Salud Publica",
#         "type": "organization",
#         "description": "Ministerio de Salud Pública.",
#         "image_url": "2020-08-04-132255.866985LOGO-MinSALUD.png",
#         "created": "2012-11-13T15:14:04.125121",
#         "is_organization": true,
#         "approval_status": "approved",
#         "state": "active"
#       },
#       "owner_org": "8a74eecc-8fbb-47a1-b808-bb668b96db29",
#       "private": false,
#       "state": "active",
#       "title": "Vacunación por Covid-19",
#       "type": "dataset",
#       "update_frequency": "1",
#       "url": "https://monitor.uruguaysevacuna.gub.uy/",
#       "version": "4.0",
#       "groups": [
#         {
#           "description": " ",
#           "display_name": "Salud",
#           "id": "bacb6a54-e593-4bcc-ba2e-8e50c5cbd611",
#           "image_display_url": "https://catalogodatos.gub.uy/uploads/group/2019-08-22-233845.717947salud.png",
#           "name": "salud",
#           "title": "Salud"
#         }
#       ],
#       "resources": [
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2021-05-28T18:46:03.790463",
#           "datastore_active": true,
#           "description": "Datos acumulados por día de los actos vacunales. Se presentan totales diarios por tipo de vacuna, dosis, departamentos y rango etario.",
#           "format": "XLSX",
#           "hash": "",
#           "id": "0bc949c5-aa3a-4af4-b66f-aadb8ead58d8",
#           "last_modified": "2024-06-27T19:02:34.386818",
#           "licence": "Licencia de DAG de Uruguay",
#           "metadata_modified": "2024-06-27T19:02:35.523424",
#           "mimetype": "application/vnd.openxmlformats-officedocument.spreadsheetml.sheet",
#           "mimetype_inner": null,
#           "name": "Historico de actos vacunales",
#           "package_id": "e766fbf7-0cc5-4b9a-a093-b56e91e88133",
#           "position": 0,
#           "qa": {
#             "resource_timestamp": null,
#             "archival_timestamp": "2022-05-31T11:26:49.400737",
#             "openness_score": 2,
#             "openness_score_reason": "Content of file appeared to be format \"XLS\" which receives openness score: 2.",
#             "format": "XLS",
#             "created": "2021-05-29T11:55:19.092319",
#             "updated": "2022-05-31T12:45:51.326554"
#           },
#           "resource_type": null,
#           "size": 697468,
#           "spatial_coverage": "Uruguay",
#           "state": "active",
#           "temporal_coverage": "Desde el 27/02/2021",
#           "update_frecuency": "1",
#           "url": "https://catalogodatos.gub.uy/dataset/e766fbf7-0cc5-4b9a-a093-b56e91e88133/resource/0bc949c5-aa3a-4af4-b66f-aadb8ead58d8/download/actos_vacunales.xlsx",
#           "url_type": "upload"
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2021-05-28T18:46:05.968306",
#           "datastore_active": false,
#           "description": "Datos acumulados por día de los actos vacunales. Se presentan totales diarios por tipo de vacuna, dosis, departamentos y rango etario.",
#           "format": "CSV",
#           "hash": "",
#           "id": "5c549ba0-126b-45e0-b43f-b0eea72cf2cf",
#           "last_modified": "2024-06-27T19:02:35.465663",
#           "licence": "Licencia de DAG de Uruguay",
#           "metadata_modified": "2024-06-27T19:02:39.506131",
#           "mimetype": "text/csv",
#           "mimetype_inner": null,
#           "name": "Historico de actos vacunales",
#           "package_id": "e766fbf7-0cc5-4b9a-a093-b56e91e88133",
#           "position": 1,
#           "qa": {
#             "resource_timestamp": null,
#             "archival_timestamp": "2022-05-31T11:26:50.161161",
#             "openness_score": 3,
#             "openness_score_reason": "Content of file appeared to be format \"CSV\" which receives openness score: 3.",
#             "format": "CSV",
#             "created": "2021-05-29T11:55:19.157013",
#             "updated": "2022-05-31T12:45:51.371210"
#           },
#           "resource_type": null,
#           "size": 483536,
#           "spatial_coverage": "Uruguay",
#           "state": "active",
#           "temporal_coverage": "Desde el 27/02/2021",
#           "update_frecuency": "1",
#           "url": "https://catalogodatos.gub.uy/dataset/e766fbf7-0cc5-4b9a-a093-b56e91e88133/resource/5c549ba0-126b-45e0-b43f-b0eea72cf2cf/download/actos_vacunales.csv",
#           "url_type": "upload"
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2021-05-28T18:46:08.303283",
#           "datastore_active": false,
#           "description": "Datos acumulados por día de los actos vacunales. Se presentan totales diarios por tipo de vacuna, dosis, departamentos y rango etario.",
#           "format": "XML",
#           "hash": "",
#           "id": "6906c06f-135c-4c64-b983-b9fbb42bf6ac",
#           "last_modified": "2024-06-27T19:02:39.477525",
#           "licence": "Licencia de DAG de Uruguay",
#           "metadata_modified": "2024-06-27T19:02:40.470601",
#           "mimetype": "application/xml",
#           "mimetype_inner": null,
#           "name": "Historico de actos vacunales",
#           "package_id": "e766fbf7-0cc5-4b9a-a093-b56e91e88133",
#           "position": 2,
#           "qa": {
#             "resource_timestamp": null,
#             "archival_timestamp": "2022-05-31T11:26:50.926425",
#             "openness_score": 3,
#             "openness_score_reason": "Content of file appeared to be format \"XML\" which receives openness score: 3.",
#             "format": "XML",
#             "created": "2021-05-29T11:55:19.172950",
#             "updated": "2022-05-31T12:45:51.384888"
#           },
#           "resource_type": null,
#           "size": 8422725,
#           "spatial_coverage": "Uruguay",
#           "state": "active",
#           "temporal_coverage": "Desde el 27/02/2021",
#           "update_frecuency": "1",
#           "url": "https://catalogodatos.gub.uy/dataset/e766fbf7-0cc5-4b9a-a093-b56e91e88133/resource/6906c06f-135c-4c64-b983-b9fbb42bf6ac/download/actos_vacunales.xml",
#           "url_type": "upload"
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2021-05-28T18:46:09.586758",
#           "datastore_active": true,
#           "description": "Metadatos de los actos vacunales",
#           "format": "JSON",
#           "hash": "",
#           "id": "e26f0e2e-7435-404a-b890-1301e325b838",
#           "last_modified": "2024-06-27T19:02:40.444004",
#           "licence": "Licencia de DAG de Uruguay",
#           "metadata_modified": "2024-06-27T19:02:40.470686",
#           "mimetype": "application/json",
#           "mimetype_inner": null,
#           "name": "Metadatos de historico de actos vacunales",
#           "package_id": "e766fbf7-0cc5-4b9a-a093-b56e91e88133",
#           "position": 3,
#           "qa": {
#             "resource_timestamp": null,
#             "archival_timestamp": "2022-05-31T11:26:51.742052",
#             "openness_score": 3,
#             "openness_score_reason": "Content of file appeared to be format \"CSV\" which receives openness score: 3.",
#             "format": "CSV",
#             "created": "2021-05-29T11:55:19.304870",
#             "updated": "2022-05-31T12:45:51.478676"
#           },
#           "resource_type": null,
#           "size": 45530,
#           "spatial_coverage": "Uruguay",
#           "state": "active",
#           "temporal_coverage": "Desde el 27/02/2021",
#           "update_frecuency": "1",
#           "url": "https://catalogodatos.gub.uy/dataset/e766fbf7-0cc5-4b9a-a093-b56e91e88133/resource/e26f0e2e-7435-404a-b890-1301e325b838/download/metadatos_actos_vacunales.json",
#           "url_type": "upload"
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2021-05-28T18:51:24.259883",
#           "datastore_active": true,
#           "description": "Histórico de cantidad de personas agendadas para dosis 1, dosis 2 y dosis de refuerzo por día. Este recurso incluye también datos de agendados a futuro y en espera a partir de la fecha de publicación.",
#           "format": "XLSX",
#           "hash": "",
#           "id": "d12a44e4-743c-4141-9897-4a3eccc84879",
#           "last_modified": "2024-05-14T16:05:13.913349",
#           "licence": "Licencia de DAG de Uruguay",
#           "metadata_modified": "2024-05-14T16:05:14.773499",
#           "mimetype": "application/vnd.openxmlformats-officedocument.spreadsheetml.sheet",
#           "mimetype_inner": null,
#           "name": "Agenda de vacunas",
#           "package_id": "e766fbf7-0cc5-4b9a-a093-b56e91e88133",
#           "position": 4,
#           "qa": {
#             "resource_timestamp": null,
#             "archival_timestamp": "2022-05-31T11:26:52.496352",
#             "openness_score": 2,
#             "openness_score_reason": "Content of file appeared to be format \"XLS\" which receives openness score: 2.",
#             "format": "XLS",
#             "created": "2021-05-29T11:55:19.327613",
#             "updated": "2022-05-31T12:45:51.559973"
#           },
#           "resource_type": null,
#           "size": 28521,
#           "spatial_coverage": "Uruguay",
#           "state": "active",
#           "temporal_coverage": "Desde 27/05/2021",
#           "update_frecuency": "1",
#           "url": "https://catalogodatos.gub.uy/dataset/e766fbf7-0cc5-4b9a-a093-b56e91e88133/resource/d12a44e4-743c-4141-9897-4a3eccc84879/download/datos_agenda.xlsx",
#           "url_type": "upload"
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2021-05-28T18:51:27.349739",
#           "datastore_active": true,
#           "description": "Histórico de cantidad de personas agendadas para dosis 1, dosis 2 y dosis de refuerzo por día. Este recurso incluye también datos de agendados a futuro y en espera a partir de la fecha de publicación.",
#           "format": "CSV",
#           "hash": "",
#           "id": "ab715989-7b62-4097-a3c1-2ee912705d97",
#           "last_modified": "2024-05-14T16:05:14.746811",
#           "licence": "Licencia de DAG de Uruguay",
#           "metadata_modified": "2024-05-14T16:05:15.874595",
#           "mimetype": "text/csv",
#           "mimetype_inner": null,
#           "name": "Agenda de vacunas",
#           "package_id": "e766fbf7-0cc5-4b9a-a093-b56e91e88133",
#           "position": 5,
#           "qa": {
#             "resource_timestamp": null,
#             "archival_timestamp": "2022-05-31T11:26:53.320737",
#             "openness_score": 3,
#             "openness_score_reason": "Content of file appeared to be format \"CSV\" which receives openness score: 3.",
#             "format": "CSV",
#             "created": "2021-05-29T11:55:19.352404",
#             "updated": "2022-05-31T12:45:51.612537"
#           },
#           "resource_type": null,
#           "size": 18437,
#           "spatial_coverage": "Uruguay",
#           "state": "active",
#           "temporal_coverage": "Desde 27/05/2021",
#           "update_frecuency": "1",
#           "url": "https://catalogodatos.gub.uy/dataset/e766fbf7-0cc5-4b9a-a093-b56e91e88133/resource/ab715989-7b62-4097-a3c1-2ee912705d97/download/datos_agenda.csv",
#           "url_type": "upload"
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2021-05-28T18:51:30.236945",
#           "datastore_active": false,
#           "description": "Histórico de cantidad de personas agendadas para dosis 1, dosis 2 y dosis de refuerzo por día. Este recurso incluye también datos de agendados a futuro y en espera a partir de la fecha de publicación.",
#           "format": "XML",
#           "hash": "",
#           "id": "109062fd-77bd-4a94-95c2-c8471f664aca",
#           "last_modified": "2024-05-14T16:05:15.844118",
#           "licence": "Licencia de DAG de Uruguay",
#           "metadata_modified": "2024-05-14T16:05:16.934517",
#           "mimetype": "application/xml",
#           "mimetype_inner": null,
#           "name": "Agenda de vacunas",
#           "package_id": "e766fbf7-0cc5-4b9a-a093-b56e91e88133",
#           "position": 6,
#           "qa": {
#             "resource_timestamp": null,
#             "archival_timestamp": "2022-05-31T11:26:54.105666",
#             "openness_score": 3,
#             "openness_score_reason": "Content of file appeared to be format \"XML\" which receives openness score: 3.",
#             "format": "XML",
#             "created": "2021-05-29T11:55:19.368551",
#             "updated": "2022-05-31T12:45:51.623605"
#           },
#           "resource_type": null,
#           "size": 218102,
#           "spatial_coverage": "Uruguay",
#           "state": "active",
#           "temporal_coverage": "Desde 27/05/2021",
#           "update_frecuency": "1",
#           "url": "https://catalogodatos.gub.uy/dataset/e766fbf7-0cc5-4b9a-a093-b56e91e88133/resource/109062fd-77bd-4a94-95c2-c8471f664aca/download/datos_agenda.xml",
#           "url_type": "upload"
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2021-05-28T18:51:31.508560",
#           "datastore_active": true,
#           "description": "Metadatos de agenda de vacunas.",
#           "format": "JSON",
#           "hash": "",
#           "id": "af73efe5-3804-4dfa-b6c4-ee5c8143eec0",
#           "last_modified": "2024-05-14T16:05:16.908406",
#           "licence": "Licencia de DAG de Uruguay",
#           "metadata_modified": "2024-05-14T17:02:39.393864",
#           "mimetype": "application/json",
#           "mimetype_inner": null,
#           "name": "Metadatos de agenda de vacunas",
#           "package_id": "e766fbf7-0cc5-4b9a-a093-b56e91e88133",
#           "position": 7,
#           "qa": {
#             "resource_timestamp": null,
#             "archival_timestamp": "2022-05-31T11:26:54.860939",
#             "openness_score": 3,
#             "openness_score_reason": "Content of file appeared to be format \"CSV\" which receives openness score: 3.",
#             "format": "CSV",
#             "created": "2021-05-29T11:55:19.448714",
#             "updated": "2022-05-31T12:45:51.662023"
#           },
#           "resource_type": null,
#           "size": 2248,
#           "spatial_coverage": "Uruguay",
#           "state": "active",
#           "temporal_coverage": "Desde 27/05/2021",
#           "update_frecuency": "1",
#           "url": "https://catalogodatos.gub.uy/dataset/e766fbf7-0cc5-4b9a-a093-b56e91e88133/resource/af73efe5-3804-4dfa-b6c4-ee5c8143eec0/download/metadatos_datos_agenda.json",
#           "url_type": "upload"
#         }
#       ],
#       "tags": [
#         {
#           "display_name": "Covid",
#           "id": "ddba937b-36df-4012-be2b-40e61110574c",
#           "name": "Covid",
#           "state": "active",
#           "vocabulary_id": null
#         },
#         {
#           "display_name": "Covid-19",
#           "id": "d84d72dd-778e-4f36-8866-19c6546b8bb0",
#           "name": "Covid-19",
#           "state": "active",
#           "vocabulary_id": null
#         },
#         {
#           "display_name": "SARS-CoV-2",
#           "id": "132aff02-02d3-41a1-af75-bf2b28c264ac",
#           "name": "SARS-CoV-2",
#           "state": "active",
#           "vocabulary_id": null
#         },
#         {
#           "display_name": "Vacunas",
#           "id": "2834cff5-375e-4a45-b65d-1f82a9e32e22",
#           "name": "Vacunas",
#           "state": "active",
#           "vocabulary_id": null
#         }
#       ],
#       "relationships_as_subject": [],
#       "relationships_as_object": []
#     },
#     {
#       "author": "Ministerio de Turismo del Uruguay - Registro de Operadores Turísticos",
#       "author_email": "registro@mintur.gub.uy",
#       "creator_user_id": "aa2189c9-4d61-41fd-9bd2-bf58e1ef4a79",
#       "id": "eb614f27-36d8-4a34-8bbf-ed5c40473df0",
#       "isopen": true,
#       "license_id": "odc-uy",
#       "license_title": "Licencia de DAG de Uruguay",
#       "license_url": "https://www.gub.uy/agencia-gobierno-electronico-sociedad-informacion-conocimiento/sites/agencia-gobierno-electronico-sociedad-informacion-conocimiento/files/documentos/publicaciones/licencia_de_datos_abiertos_0.pdf",
#       "maintainer": "Francisco Gardil",
#       "maintainer_email": "gardil@mintur.gub.uy",
#       "metadata_created": "2021-11-16T15:20:26.318377",
#       "metadata_modified": "2024-06-27T14:03:20.376904",
#       "name": "ministerio-de-turismo-registro-de-operadores",
#       "notes": "Este conjunto de datos es la lista de datos públicos del Registro de Operadores Turísticos del Ministerio de Turismo del Uruguay.",
#       "num_resources": 4,
#       "num_tags": 4,
#       "organization": {
#         "id": "ae9728c8-8f10-42d4-9da2-3589c1cff788",
#         "name": "ministerio-de-turismo",
#         "title": "Ministerio de Turismo",
#         "type": "organization",
#         "description": "Ministerio de Turismo del Uruguay",
#         "image_url": "2020-08-04-132627.410343LOGO-MinTURISMO.png",
#         "created": "2012-11-13T15:09:54.163919",
#         "is_organization": true,
#         "approval_status": "approved",
#         "state": "active"
#       },
#       "owner_org": "ae9728c8-8f10-42d4-9da2-3589c1cff788",
#       "private": false,
#       "state": "active",
#       "title": "Registro de Operadores Turísticos",
#       "type": "dataset",
#       "update_frequency": "1",
#       "url": "",
#       "version": "1.0",
#       "groups": [
#         {
#           "description": " ",
#           "display_name": "Turismo",
#           "id": "25e8c196-8fe5-4d07-baa3-288dbf0bd79d",
#           "image_display_url": "https://catalogodatos.gub.uy/uploads/group/2019-08-22-234046.841825turismo.png",
#           "name": "turismo",
#           "title": "Turismo"
#         }
#       ],
#       "resources": [
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2021-11-16T15:29:43.148468",
#           "datastore_active": true,
#           "description": "Este conjunto de datos es la lista de datos públicos del Registro de Operadores Turísticos. Los mismos corresponden a los Operadores en estado ACTIVO al momento de la consulta, con todos los datos disponibles de cada Operador brindados en carácter de Declaración Jurada.",
#           "format": "XLSX",
#           "hash": "",
#           "id": "65df8141-f444-49bb-a66a-51c1c3b387df",
#           "last_modified": "2024-06-27T14:03:16.226269",
#           "licence": "Licencia de DAG de Uruguay",
#           "metadata_modified": "2024-06-27T14:03:17.559102",
#           "mimetype": "application/vnd.openxmlformats-officedocument.spreadsheetml.sheet",
#           "mimetype_inner": null,
#           "name": "Datos de Turismo Operadores",
#           "package_id": "eb614f27-36d8-4a34-8bbf-ed5c40473df0",
#           "position": 0,
#           "qa": {
#             "resource_timestamp": null,
#             "archival_timestamp": "2022-05-31T11:14:39.104473",
#             "openness_score": 2,
#             "openness_score_reason": "Content of file appeared to be format \"XLS\" which receives openness score: 2.",
#             "format": "XLS",
#             "created": "2021-12-03T13:48:21.880523",
#             "updated": "2022-05-31T12:39:50.464576"
#           },
#           "resource_type": null,
#           "size": 245275,
#           "spatial_coverage": "Uruguay",
#           "state": "active",
#           "temporal_coverage": "2016/01 - 2024/05",
#           "update_frequency": "1",
#           "url": "https://catalogodatos.gub.uy/dataset/eb614f27-36d8-4a34-8bbf-ed5c40473df0/resource/65df8141-f444-49bb-a66a-51c1c3b387df/download/operadores.xlsx",
#           "url_type": "upload"
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2021-11-16T15:29:46.386795",
#           "datastore_active": true,
#           "description": "Este conjunto de datos es la lista de datos públicos del Registro de Operadores Turísticos. Los mismos corresponden a los Operadores en estado ACTIVO al momento de la consulta, con todos los datos disponibles de cada Operador brindados en carácter de Declaración Jurada.",
#           "format": "CSV",
#           "hash": "",
#           "id": "884b79e9-503f-4f86-93ca-41009e57f891",
#           "last_modified": "2024-06-27T14:03:17.526976",
#           "licence": "Licencia de DAG de Uruguay",
#           "metadata_modified": "2024-06-27T14:03:19.520872",
#           "mimetype": "text/csv",
#           "mimetype_inner": null,
#           "name": "Datos de Turismo Operadores",
#           "package_id": "eb614f27-36d8-4a34-8bbf-ed5c40473df0",
#           "position": 1,
#           "qa": {
#             "resource_timestamp": null,
#             "archival_timestamp": "2022-05-31T11:14:39.848920",
#             "openness_score": 3,
#             "openness_score_reason": "Content of file appeared to be format \"CSV\" which receives openness score: 3.",
#             "format": "CSV",
#             "created": "2021-12-03T13:48:21.925528",
#             "updated": "2022-05-31T12:39:50.503957"
#           },
#           "resource_type": null,
#           "size": 554064,
#           "spatial_coverage": "Uruguay",
#           "state": "active",
#           "temporal_coverage": "2016/01 - 2024/05",
#           "update_frequency": "1",
#           "url": "https://catalogodatos.gub.uy/dataset/eb614f27-36d8-4a34-8bbf-ed5c40473df0/resource/884b79e9-503f-4f86-93ca-41009e57f891/download/operadores.csv",
#           "url_type": "upload"
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2021-11-16T15:29:50.629424",
#           "datastore_active": false,
#           "description": "Este conjunto de datos es la lista de datos públicos del Registro de Operadores Turísticos. Los mismos corresponden a los Operadores en estado ACTIVO al momento de la consulta, con todos los datos disponibles de cada Operador brindados en carácter de Declaración Jurada.",
#           "format": "XML",
#           "hash": "",
#           "id": "f062235f-c824-4165-9775-42d286381b99",
#           "last_modified": "2024-06-27T14:03:19.491149",
#           "licence": "Licencia de DAG de Uruguay",
#           "metadata_modified": "2024-06-27T14:03:20.395070",
#           "mimetype": "application/xml",
#           "mimetype_inner": null,
#           "name": "Datos de Turismo Operadores",
#           "package_id": "eb614f27-36d8-4a34-8bbf-ed5c40473df0",
#           "position": 2,
#           "qa": {
#             "resource_timestamp": null,
#             "archival_timestamp": "2022-05-31T11:14:40.612114",
#             "openness_score": 3,
#             "openness_score_reason": "Content of file appeared to be format \"XML\" which receives openness score: 3.",
#             "format": "XML",
#             "created": "2021-12-03T13:48:21.942389",
#             "updated": "2022-05-31T12:39:50.515565"
#           },
#           "resource_type": null,
#           "size": 1238294,
#           "spatial_coverage": "Uruguay",
#           "state": "active",
#           "temporal_coverage": "2016/01 - 2024/05",
#           "update_frequency": "1",
#           "url": "https://catalogodatos.gub.uy/dataset/eb614f27-36d8-4a34-8bbf-ed5c40473df0/resource/f062235f-c824-4165-9775-42d286381b99/download/operadores.xml",
#           "url_type": "upload"
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2021-11-16T15:29:52.070664",
#           "datastore_active": false,
#           "description": "El recurso cuenta con los datos descriptivos del recurso de turismo Operadores.",
#           "format": "JSON",
#           "hash": "",
#           "id": "be3c0e5e-3512-4a1c-9ebb-bcb0684f2bb0",
#           "last_modified": "2024-06-27T14:03:20.360979",
#           "licence": "Licencia de DAG de Uruguay",
#           "metadata_modified": "2024-06-27T14:03:20.395164",
#           "mimetype": "application/json",
#           "mimetype_inner": null,
#           "name": "Metadatos de Turismo operadores",
#           "package_id": "eb614f27-36d8-4a34-8bbf-ed5c40473df0",
#           "position": 3,
#           "qa": {
#             "resource_timestamp": null,
#             "archival_timestamp": "2022-05-31T11:14:41.370561",
#             "openness_score": 3,
#             "openness_score_reason": "Content of file appeared to be format \"CSV\" which receives openness score: 3.",
#             "format": "CSV",
#             "created": "2021-12-03T13:48:22.014223",
#             "updated": "2022-05-31T12:39:50.581274"
#           },
#           "resource_type": null,
#           "size": 2977,
#           "spatial_coverage": "Uruguay",
#           "state": "active",
#           "temporal_coverage": "2016/01 - 2024/05",
#           "update_frequency": "1",
#           "url": "https://catalogodatos.gub.uy/dataset/eb614f27-36d8-4a34-8bbf-ed5c40473df0/resource/be3c0e5e-3512-4a1c-9ebb-bcb0684f2bb0/download/metadatos_operadores.json",
#           "url_type": "upload"
#         }
#       ],
#       "tags": [
#         {
#           "display_name": "Ministerio de Turismo",
#           "id": "aef90173-1979-40fd-9680-caf513697f17",
#           "name": "Ministerio de Turismo",
#           "state": "active",
#           "vocabulary_id": null
#         },
#         {
#           "display_name": "Operadores turísticos",
#           "id": "2fc585de-038d-4abe-86e9-95124d8388f0",
#           "name": "Operadores turísticos",
#           "state": "active",
#           "vocabulary_id": null
#         },
#         {
#           "display_name": "Registros",
#           "id": "bf8d5e2d-1c83-4280-9b7d-3f7e816c427c",
#           "name": "Registros",
#           "state": "active",
#           "vocabulary_id": null
#         },
#         {
#           "display_name": "Turismo",
#           "id": "e4cfd528-2997-47dd-910f-717d245f9a43",
#           "name": "Turismo",
#           "state": "active",
#           "vocabulary_id": null
#         }
#       ],
#       "relationships_as_subject": [],
#       "relationships_as_object": []
#     },
#     {
#       "author": "INUMET",
#       "author_email": "contacto@inumet.gub.uy",
#       "creator_user_id": "a8abec88-90b0-4780-8ad4-f89ebbb6341c",
#       "id": "ecd6cb6f-67c4-4f2f-8dd7-9155fa10b2f9",
#       "isopen": true,
#       "license_id": "odc-uy",
#       "license_title": "Licencia de DAG de Uruguay",
#       "license_url": "https://www.gub.uy/agencia-gobierno-electronico-sociedad-informacion-conocimiento/sites/agencia-gobierno-electronico-sociedad-informacion-conocimiento/files/documentos/publicaciones/licencia_de_datos_abiertos_0.pdf",
#       "maintainer": "Área de Informática",
#       "maintainer_email": "informatica.direccion@inumet.gub.uy",
#       "metadata_created": "2024-02-28T16:12:16.992613",
#       "metadata_modified": "2024-06-27T08:02:32.031599",
#       "name": "agesic-observaciones-meteorologicas",
#       "notes": "El siguiente conjunto presenta la información sobre las observaciones meteorológicas llevadas a cabo por observadores certificados en estaciones meteorológicas del Instituto Uruguayo de Meteorología (INUMET).\r\n\r\nEstas observaciones se realizan en intervalos horarios utilizando instrumental meteorológico y siguiendo metodologías que cumplen con los estándares y directrices reglamentarias establecidas por la Organización Mundial de Meteorología.",
#       "num_resources": 14,
#       "num_tags": 5,
#       "organization": {
#         "id": "77de4efa-c5ab-4505-89b8-010bcedc9ee6",
#         "name": "inumet",
#         "title": "INUMET",
#         "type": "organization",
#         "description": "El Instituto Uruguayo de Meteorología (Inumet) se crea el 25 de octubre de 2013. Es la autoridad meteorológica de la República Oriental del Uruguay y la autoridad meteorológica aeronáutica, en aplicación de la Convención de Aviación Civil Internacional (OACI).\r\n\r\nInumet tiene como ﬁnalidad prestar los servicios públicos meteorológicos y climatológicos, consistentes en observar, registrar y predecir el tiempo y el clima en el territorio nacional y zonas oceánicas adyacentes, y otros espacios de interés, de acuerdo a los convenios aplicables.\r\n\r\nSu objetivo es contribuir a la seguridad de las personas y bienes y al desarrollo sostenible de la sociedad. A su vez, debe coordinar las actividades meteorológicas de cualquier naturaleza en el país, representar a la República Oriental del Uruguay ante los organismos internacionales en materia de meteorología, así como cumplir con las obligaciones asumidas por el país ante los mismos.",
#         "image_url": "2024-02-28-175550.732650InumetImagotipohorizontalnegativo.jpg",
#         "created": "2024-02-28T14:37:37.652768",
#         "is_organization": true,
#         "approval_status": "approved",
#         "state": "active"
#       },
#       "owner_org": "77de4efa-c5ab-4505-89b8-010bcedc9ee6",
#       "private": false,
#       "state": "active",
#       "title": "Observaciones meteorológicas",
#       "type": "dataset",
#       "update_frequency": "1",
#       "url": "",
#       "version": "1.0",
#       "groups": [
#         {
#           "description": " ",
#           "display_name": "Medio Ambiente",
#           "id": "302c5679-3bff-4757-aaec-c873e9c85602",
#           "image_display_url": "https://catalogodatos.gub.uy/uploads/group/2019-08-22-233824.150522medioAmbiente.png",
#           "name": "medio-ambiente",
#           "title": "Medio Ambiente"
#         }
#       ],
#       "resources": [
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2024-02-28T16:18:04.488120",
#           "datastore_active": true,
#           "description": "Datos sobre la humedad relavita, la cual es la relación entre la tensión de vapor, expresada en %, y la máxima que puede existir a una temperatura dada. El aire esta saturado cuando la humedad relativa es del 100%. Estas mediciones son realzadas de forma instantanea en cada hora en punto. Los horarios operativos de las estaciones pueden variar.",
#           "format": "CSV",
#           "hash": "",
#           "id": "9efc2e5b-7185-41aa-b77f-53a833b9d5a1",
#           "last_modified": "2024-06-27T08:02:29.258984",
#           "licence": "Licencia de DAG de Uruguay",
#           "metadata_modified": "2024-06-27T08:02:29.287520",
#           "mimetype": "text/csv",
#           "mimetype_inner": null,
#           "name": "Humedad relativa - 2024",
#           "package_id": "ecd6cb6f-67c4-4f2f-8dd7-9155fa10b2f9",
#           "position": 0,
#           "resource_type": null,
#           "size": 423049,
#           "spatial_coverage": "Uruguay",
#           "state": "active",
#           "temporal_coverage": "2024",
#           "update_frequency": "1",
#           "url": "https://catalogodatos.gub.uy/dataset/ecd6cb6f-67c4-4f2f-8dd7-9155fa10b2f9/resource/9efc2e5b-7185-41aa-b77f-53a833b9d5a1/download/inumet_humedad-relativa.csv",
#           "url_type": "upload"
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2024-02-28T16:14:28.924821",
#           "datastore_active": true,
#           "description": "Datos sobre la temperatura señalada en un termómetro expuesto al aire, al abrigo de la radiación solar directa. Estas mediciones son realizadas de forma instantánea en cada hora en punto. Los horarios operativos de las estaciones pueden variar.",
#           "format": "CSV",
#           "hash": "",
#           "id": "bb0fe305-ecda-4f5c-8535-8752031534b5",
#           "last_modified": "2024-06-27T08:02:30.398727",
#           "licence": "Licencia de DAG de Uruguay",
#           "metadata_modified": "2024-06-27T08:02:30.439242",
#           "mimetype": "text/csv",
#           "mimetype_inner": null,
#           "name": "Temperatura del aire - 2024",
#           "package_id": "ecd6cb6f-67c4-4f2f-8dd7-9155fa10b2f9",
#           "position": 1,
#           "resource_type": null,
#           "size": 437066,
#           "spatial_coverage": "Uruguay",
#           "state": "active",
#           "temporal_coverage": "2024",
#           "update_frequency": "1",
#           "url": "https://catalogodatos.gub.uy/dataset/ecd6cb6f-67c4-4f2f-8dd7-9155fa10b2f9/resource/bb0fe305-ecda-4f5c-8535-8752031534b5/download/inumet_temperatura-del-aire.csv",
#           "url_type": "upload"
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2024-02-28T21:29:44.921454",
#           "datastore_active": true,
#           "description": "Datos sobre la humedad relativa, la cual es la relación entre la tensión de vapor, expresada en %, y la máxima que puede existir a una temperatura dada. El aire esta saturado cuando la humedad relativa es del 100%. Estas mediciones son realzadas de forma instantánea en cada hora en punto. Los horarios operativos de las estaciones pueden variar.",
#           "format": "CSV",
#           "hash": "",
#           "id": "67679ecb-3241-4f52-b4d9-fc2111f65d60",
#           "last_modified": "2024-03-06T19:13:07.335873",
#           "metadata_modified": "2024-03-06T19:13:07.368136",
#           "mimetype": "text/csv",
#           "mimetype_inner": null,
#           "name": "Humedad relativa – 2023",
#           "package_id": "ecd6cb6f-67c4-4f2f-8dd7-9155fa10b2f9",
#           "position": 2,
#           "resource_type": null,
#           "size": 744791,
#           "spatial_coverage": "Montevideo, Canelones",
#           "spatial_ref_system": "",
#           "state": "active",
#           "temporal_coverage": "2023",
#           "update_frequency": "-1",
#           "url": "https://catalogodatos.gub.uy/dataset/ecd6cb6f-67c4-4f2f-8dd7-9155fa10b2f9/resource/67679ecb-3241-4f52-b4d9-fc2111f65d60/download/inumet_humedad-relativa-2023.csv",
#           "url_type": "upload"
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2024-02-28T21:28:40.272009",
#           "datastore_active": true,
#           "description": "Datos sobre la temperatura señalada en un termómetro expuesto al aire, al abrigo de la radiación solar directa. Estas mediciones son realizadas de forma instantánea en cada hora en punto. Los horarios operativos de las estaciones pueden variar.",
#           "format": "CSV",
#           "hash": "",
#           "id": "1813b9e8-9e32-482f-ac8f-500439f8cab9",
#           "last_modified": "2024-03-06T19:12:38.135023",
#           "metadata_modified": "2024-03-06T19:12:38.278657",
#           "mimetype": "text/csv",
#           "mimetype_inner": null,
#           "name": "Temperatura del aire – 2023",
#           "package_id": "ecd6cb6f-67c4-4f2f-8dd7-9155fa10b2f9",
#           "position": 3,
#           "resource_type": null,
#           "size": 772879,
#           "spatial_coverage": "Montevideo, Canelones",
#           "spatial_ref_system": "",
#           "state": "active",
#           "temporal_coverage": "2023",
#           "update_frequency": "-1",
#           "url": "https://catalogodatos.gub.uy/dataset/ecd6cb6f-67c4-4f2f-8dd7-9155fa10b2f9/resource/1813b9e8-9e32-482f-ac8f-500439f8cab9/download/inumet_temperatura-del-aire-2023.csv",
#           "url_type": "upload"
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2024-02-28T21:27:08.298631",
#           "datastore_active": true,
#           "description": "Datos sobre la humedad relativa, la cual es la relación entre la tensión de vapor, expresada en %, y la máxima que puede existir a una temperatura dada. El aire esta saturado cuando la humedad relativa es del 100%. Estas mediciones son realzadas de forma instantánea en cada hora en punto. Los horarios operativos de las estaciones pueden variar.",
#           "format": "CSV",
#           "hash": "",
#           "id": "5cc8df98-b90c-446f-9e32-083b57fa1c02",
#           "last_modified": "2024-03-06T19:11:50.340749",
# ...
#           "size": null,
#           "spatial_coverage": "Uruguay",
#           "spatial_ref_system": "",
#           "state": "active",
#           "temporal_coverage": "2005-02-15 - 2010-02-14",
#           "update_frequency": "0",
#           "url": "https://parlamento.gub.uy/camarasycomisiones/senadores/plenario/datos-abiertos/pedidos-informe/por-organismo/json?Lgl_Nro=46&page&_format=json",
#           "url_type": null
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2024-06-18T18:53:11.302674",
#           "datastore_active": true,
#           "description": "Datos sobre los pedidos de informes a la Cámara de Senadores en la Legislatura 47 que comprende desde: 2010-02-15 al 2015-02-14.",
#           "format": "CSV",
#           "hash": "",
#           "id": "a5cf239a-98a8-4c4c-927c-651caaa8a1a9",
#           "last_modified": null,
#           "metadata_modified": "2024-06-18T18:53:11.274968",
#           "mimetype": null,
#           "mimetype_inner": null,
#           "name": "Pedidos de Informes al Senado - Legislatura 47",
#           "package_id": "dc2e14a8-a749-4159-a105-ec113068e030",
#           "position": 15,
#           "resource_type": null,
#           "size": null,
#           "spatial_coverage": "Uruguay",
#           "spatial_ref_system": "",
#           "state": "active",
#           "temporal_coverage": "2010-02-15 - 2015-02-14",
#           "update_frequency": "0",
#           "url": "https://parlamento.gub.uy/camarasycomisiones/senadores/transparencia/datos-abiertos/pedidos-informe/por-organismo/csv?Lgl_Nro=47&page&_format=csv",
#           "url_type": null
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2024-06-18T18:53:51.637839",
#           "datastore_active": false,
#           "description": "Datos sobre los pedidos de informes a la Cámara de Senadores en la Legislatura 47 que comprende desde: 2010-02-15 al 2015-02-14.",
#           "format": "JSON",
#           "hash": "",
#           "id": "4c096a70-f54f-41c4-9298-5f27a42520ff",
#           "last_modified": null,
#           "metadata_modified": "2024-06-18T18:59:18.889699",
#           "mimetype": null,
#           "mimetype_inner": null,
#           "name": "Pedidos de Informes al Senado - Legislatura 47",
#           "package_id": "dc2e14a8-a749-4159-a105-ec113068e030",
#           "position": 16,
#           "resource_type": null,
#           "size": null,
#           "spatial_coverage": "Uruguay",
#           "spatial_ref_system": "",
#           "state": "active",
#           "temporal_coverage": "2010-02-15 - 2015-02-14",
#           "update_frequency": "0",
#           "url": "https://parlamento.gub.uy/camarasycomisiones/senadores/plenario/datos-abiertos/pedidos-informe/por-organismo/json?Lgl_Nro=47&page&_format=json",
#           "url_type": null
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2024-06-18T18:59:18.913281",
#           "datastore_active": true,
#           "description": "Datos sobre los pedidos de informes a la Cámara de Senadores en la Legislatura 48 que comprende desde: 2015-02-15 al 2020-02-14.",
#           "format": "CSV",
#           "hash": "",
#           "id": "ce96130f-f987-4118-9099-0077a0da386f",
#           "last_modified": null,
#           "metadata_modified": "2024-06-18T18:59:18.889852",
#           "mimetype": null,
#           "mimetype_inner": null,
#           "name": "Pedidos de Informes al Senado - Legislatura 48",
#           "package_id": "dc2e14a8-a749-4159-a105-ec113068e030",
#           "position": 17,
#           "resource_type": null,
#           "size": null,
#           "spatial_coverage": "Uruguay",
#           "spatial_ref_system": "",
#           "state": "active",
#           "temporal_coverage": "2015-02-15 - 2020-02-14",
#           "update_frequency": "0",
#           "url": "https://parlamento.gub.uy/camarasycomisiones/senadores/transparencia/datos-abiertos/pedidos-informe/por-organismo/csv?Lgl_Nro=49&page&_format=csv",
#           "url_type": null
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2024-06-18T18:59:55.453010",
#           "datastore_active": false,
#           "description": "Datos sobre los pedidos de informes a la Cámara de Senadores en la Legislatura 48 que comprende desde: 2015-02-15 al 2020-02-14.",
#           "format": "JSON",
#           "hash": "",
#           "id": "0d284f9a-da73-4e2f-b173-6d33c203c002",
#           "last_modified": null,
#           "metadata_modified": "2024-06-18T19:00:42.721085",
#           "mimetype": null,
#           "mimetype_inner": null,
#           "name": "Pedidos de Informes al Senado - Legislatura 48",
#           "package_id": "dc2e14a8-a749-4159-a105-ec113068e030",
#           "position": 18,
#           "resource_type": null,
#           "size": null,
#           "spatial_coverage": "Uruguay",
#           "spatial_ref_system": "",
#           "state": "active",
#           "temporal_coverage": "2015-02-15 - 2020-02-14",
#           "update_frequency": "0",
#           "url": "https://parlamento.gub.uy/camarasycomisiones/senadores/plenario/datos-abiertos/pedidos-informe/por-organismo/json?Lgl_Nro=48&page&_format=json",
#           "url_type": null
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2024-06-18T19:00:42.767452",
#           "datastore_active": true,
#           "description": "Datos sobre los pedidos de informes a la Cámara de Senadores en la Legislatura 49 que comprende desde: 2020-02-15 al 2025-02-14.",
#           "format": "CSV",
#           "hash": "",
#           "id": "5a4db190-fbd2-4bff-9de7-2313b8c913ac",
#           "last_modified": null,
#           "metadata_modified": "2024-06-18T19:00:42.721316",
#           "mimetype": null,
#           "mimetype_inner": null,
#           "name": "Pedidos de Informes al Senado - Legislatura 49",
#           "package_id": "dc2e14a8-a749-4159-a105-ec113068e030",
#           "position": 19,
#           "resource_type": null,
#           "size": null,
#           "spatial_coverage": "Uruguay",
#           "spatial_ref_system": "",
#           "state": "active",
#           "temporal_coverage": "2020-02-15 - 2025-02-14",
#           "update_frequency": "0",
#           "url": "https://parlamento.gub.uy/camarasycomisiones/senadores/transparencia/datos-abiertos/pedidos-informe/por-organismo/csv?Lgl_Nro=49&page&_format=csv",
#           "url_type": null
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2024-06-18T19:01:33.915040",
#           "datastore_active": false,
#           "description": "Datos sobre los pedidos de informes a la Cámara de Senadores en la Legislatura 49 que comprende desde: 2020-02-15 al 2025-02-14.",
#           "format": "JSON",
#           "hash": "",
#           "id": "0fe8a240-c57f-4a5b-a502-c99251b46266",
#           "last_modified": null,
#           "metadata_modified": "2024-06-18T19:04:01.833969",
#           "mimetype": null,
#           "mimetype_inner": null,
#           "name": "Pedidos de Informes al Senado - Legislatura 49",
#           "package_id": "dc2e14a8-a749-4159-a105-ec113068e030",
#           "position": 20,
#           "resource_type": null,
#           "size": null,
#           "spatial_coverage": "Uruguay",
#           "spatial_ref_system": "",
#           "state": "active",
#           "temporal_coverage": "2020-02-15 - 2025-02-14",
#           "update_frequency": "0",
#           "url": "https://parlamento.gub.uy/camarasycomisiones/senadores/plenario/datos-abiertos/pedidos-informe/por-organismo/json?Lgl_Nro=49&page&_format=json",
#           "url_type": null
#         }
#       ],
#       "tags": [
#         {
#           "display_name": "Artículo n118",
#           "id": "60e61a7e-1e16-4526-a8d9-db599978e7a8",
#           "name": "Artículo n118",
#           "state": "active",
#           "vocabulary_id": null
#         },
#         {
#           "display_name": "Cámara de Senadores",
#           "id": "ef8969c4-79b6-4e4d-94f8-6a859fa0a97f",
#           "name": "Cámara de Senadores",
#           "state": "active",
#           "vocabulary_id": null
#         },
#         {
#           "display_name": "Ley 17.673",
#           "id": "1d677b4f-f602-4911-b23d-6c6c53ed7897",
#           "name": "Ley 17.673",
#           "state": "active",
#           "vocabulary_id": null
#         },
#         {
#           "display_name": "Parlamento Uruguayo",
#           "id": "c6754e0c-5fd9-42ae-9023-4fa6ebb2adf9",
#           "name": "Parlamento Uruguayo",
#           "state": "active",
#           "vocabulary_id": null
#         },
#         {
#           "display_name": "Pedidos de Informes",
#           "id": "6a4219c3-abc2-44f6-b6a8-c8afe47ab4aa",
#           "name": "Pedidos de Informes",
#           "state": "active",
#           "vocabulary_id": null
#         },
#         {
#           "display_name": "Transparencia activa",
#           "id": "7cd56379-e4bb-44e4-9a3e-7ea87fda3d2f",
#           "name": "Transparencia activa",
#           "state": "active",
#           "vocabulary_id": null
#         }
#       ],
#       "relationships_as_subject": [],
#       "relationships_as_object": []
#     },
#     {
#       "author": "Cámara de Senadores",
#       "author_email": "cdisalvatore@parlamento.gub.uy",
#       "creator_user_id": "ecee534f-a475-4f7a-8bfd-86e422a8d0b1",
#       "id": "56e5551f-6653-494e-b076-83fba339047e",
#       "isopen": true,
#       "license_id": "odc-uy",
#       "license_title": "Licencia de DAG de Uruguay",
#       "license_url": "https://www.gub.uy/agencia-gobierno-electronico-sociedad-informacion-conocimiento/sites/agencia-gobierno-electronico-sociedad-informacion-conocimiento/files/documentos/publicaciones/licencia_de_datos_abiertos_0.pdf",
#       "maintainer": "Cámara de Senadores",
#       "maintainer_email": "cdisalvatore@parlamento.gub.uy",
#       "metadata_created": "2024-06-18T15:26:42.973703",
#       "metadata_modified": "2024-06-26T17:33:09.839698",
#       "name": "parlamento-del-uruguay-comisiones-de-la-camara-de-senadores",
#       "notes": "Este conjunto de datos contiene la información sobre todas las comisiones permanentes, especiales e investigadoras creadas en el Parlamento.\r\n\r\nLas Comisiones asesoran al Plenario, esto es al Senado. Están integradas por algunos Senadores, distribuidas por materias, mayoritariamente en espejo a los Ministerios del Poder Ejecutivo, para informar al Senado sobre proyectos de ley,  controlar,  investigar, etc.\r\nSe intenta que su integración sea proporcional a la representación política, interactúan con la sociedad civil y elevan proyectos de ley al Senado para su eventual aprobación.\r\n\r\nSe presentan los datos desde 1985 al presente.\r\n\r\nLa publicación de estos datos se enmarca en un compromiso de la Cámara de Senadores en el Quinto Plan de Acción de Gobierno Abierto, compromiso 4.2, fortalecer la política de acceso a la información pública y apertura de datos del Parlamento.",
#       "num_resources": 3,
#       "num_tags": 3,
#       "organization": {
#         "id": "2968e6a9-9274-4a76-941a-fdfdb7c1d180",
#         "name": "parlamento-uruguayo",
#         "title": "Parlamento del Uruguay",
#         "type": "organization",
#         "description": "Parlamento Uruguayo",
#         "image_url": "2024-06-18-151826.897689logoredes.jpeg",
#         "created": "2014-12-22T13:56:07.090753",
#         "is_organization": true,
#         "approval_status": "approved",
#         "state": "active"
#       },
#       "owner_org": "2968e6a9-9274-4a76-941a-fdfdb7c1d180",
#       "private": false,
#       "state": "active",
#       "title": "Comisiones de la Cámara de Senadores",
#       "type": "dataset",
#       "update_frequency": "0",
#       "url": "https://parlamento.gub.uy/camarasycomisiones/senadores/transparencia/datos-abiertos/",
#       "version": "1.0",
#       "groups": [
#         {
#           "description": "",
#           "display_name": "Transparencia",
#           "id": "8552e8e2-e342-43fe-ab27-4e3c50564f9b",
#           "image_display_url": "https://catalogodatos.gub.uy/uploads/group/2019-08-22-234010.387437transparencia.png",
#           "name": "transparencia",
#           "title": "Transparencia"
#         }
#       ],
#       "resources": [
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2024-06-18T15:27:34.950992",
#           "datastore_active": true,
#           "description": "Datos de las comisiones de la Cámara de Senadores.",
#           "format": "CSV",
#           "hash": "",
#           "id": "bdcd140f-7dac-4ad8-aed0-fdf856393893",
#           "last_modified": null,
#           "metadata_modified": "2024-06-18T17:17:21.673203",
#           "mimetype": null,
#           "mimetype_inner": null,
#           "name": "Comisiones del Senado",
#           "package_id": "56e5551f-6653-494e-b076-83fba339047e",
#           "position": 0,
#           "resource_type": null,
#           "size": null,
#           "spatial_coverage": "Uruguay",
#           "spatial_ref_system": "",
#           "state": "active",
#           "temporal_coverage": "1985 - 2024",
#           "update_frequency": "0",
#           "url": "https://parlamento.gub.uy/camarasycomisiones/comisiones/general/csv?Cms_Cpo_Codigo=S",
#           "url_type": null
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2024-06-18T15:28:15.531681",
#           "datastore_active": false,
#           "description": "Datos de las comisiones de la Cámara de Senadores.",
#           "format": "JSON",
#           "hash": "",
#           "id": "43a7cb02-dd88-42e2-b1e3-6c82a4ca52ed",
#           "last_modified": null,
#           "metadata_modified": "2024-06-18T17:17:36.025208",
#           "mimetype": null,
#           "mimetype_inner": null,
#           "name": "Comisiones del Senado",
#           "package_id": "56e5551f-6653-494e-b076-83fba339047e",
#           "position": 1,
#           "resource_type": null,
#           "size": null,
#           "spatial_coverage": "Uruguay",
#           "spatial_ref_system": "",
#           "state": "active",
#           "temporal_coverage": "1985 - 2024",
#           "update_frequency": "0",
#           "url": "https://parlamento.gub.uy/camarasycomisiones/comisiones/general/csv?Cms_Cpo_Codigo=S",
#           "url_type": null
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2024-06-18T15:28:55.042704",
#           "datastore_active": true,
#           "description": "Datos descriptivos sobre las comisiones de la Cámara de Senadores.",
#           "format": "CSV",
#           "hash": "",
#           "id": "a4c315bc-7325-4c17-9a9b-42a3f736c56f",
#           "last_modified": null,
#           "metadata_modified": "2024-06-18T17:17:49.988961",
#           "mimetype": "text/csv",
#           "mimetype_inner": null,
#           "name": "Metadatos de Comisiones del Senado",
#           "package_id": "56e5551f-6653-494e-b076-83fba339047e",
#           "position": 2,
#           "resource_type": null,
#           "size": null,
#           "spatial_coverage": "Uruguay",
#           "spatial_ref_system": "",
#           "state": "active",
#           "temporal_coverage": "",
#           "update_frequency": "0",
#           "url": "https://infolegislativa.parlamento.gub.uy/PL/Datos_abiertos/Metadatos_Comisiones.csv",
#           "url_type": null
#         }
#       ],
#       "tags": [
#         {
#           "display_name": "Comisiones parlamentarias",
#           "id": "9b30099b-cb92-49d1-bbdd-caedcaf81554",
#           "name": "Comisiones parlamentarias",
#           "state": "active",
#           "vocabulary_id": null
#         },
#         {
#           "display_name": "Cámara de Senadores",
#           "id": "ef8969c4-79b6-4e4d-94f8-6a859fa0a97f",
#           "name": "Cámara de Senadores",
#           "state": "active",
#           "vocabulary_id": null
#         },
#         {
#           "display_name": "Transparencia activa",
#           "id": "7cd56379-e4bb-44e4-9a3e-7ea87fda3d2f",
#           "name": "Transparencia activa",
#           "state": "active",
#           "vocabulary_id": null
#         }
#       ],
#       "relationships_as_subject": [],
#       "relationships_as_object": []
#     }
#   ]
# }

# %%
# Package Show
#
# Muestra toda la info del package dando el ID, incluye sus recursos
endpoint_suffix = 'package_show?id=ancap-proyectos'
url = build_url(endpoint_suffix)

pretty_print_json(do_get_request(url))
# Out:
# {
#   "help": "https://catalogodatos.gub.uy/es/api/3/action/help_show?name=package_show",
#   "success": true,
#   "result": {
#     "author": "ANCAP",
#     "author_email": "mmtorres@ancap.com.uy",
#     "creator_user_id": "069122d1-f756-41fe-acbe-70c3552c17b1",
#     "id": "e6ecc291-2ace-4efe-8412-62e2ace3199b",
#     "isopen": true,
#     "license_id": "odc-uy",
#     "license_title": "Licencia de DAG de Uruguay",
#     "license_url": "https://www.gub.uy/agencia-gobierno-electronico-sociedad-informacion-conocimiento/sites/agencia-gobierno-electronico-sociedad-informacion-conocimiento/files/documentos/publicaciones/licencia_de_datos_abiertos_0.pdf",
#     "maintainer": "ANCAP",
#     "maintainer_email": "mmtorres@ancap.com.uy",
#     "metadata_created": "2020-08-07T19:31:13.563955",
#     "metadata_modified": "2022-06-17T16:32:34.859116",
#     "name": "ancap-proyectos",
#     "notes": "Programas operativos de largo y corto plazo y mecanismos que permitan visualizar metas y cumplimiento",
#     "num_resources": 4,
#     "num_tags": 3,
#     "organization": {
#       "id": "92b81830-356c-4fb0-b25f-1581619c8821",
#       "name": "ancap",
#       "title": "ANCAP",
#       "type": "organization",
#       "description": "ANCAP fue creada el 15 de octubre de 1931, en el marco de lo dispuesto  por la Ley  Nº 8764 que estableció en su artículo 1º: “Créase un Ente Industrial del Estado, que se denominará Administración Nacional de Combustibles Alcohol y Pórtland con el cometido de explotar y administrar el monopolio del alcohol y carburante nacional y de importar, rectificar y vender petróleo y sus derivados, y de fabricar pórtland.”\r\n\r\nMás información: https://www.ancap.com.uy/innovaportal/v/93/1/innova.front/resena-historica.html",
#       "image_url": "2020-07-09-190009.061577Logotipo-ANCAPvertical.jpg",
#       "created": "2019-12-02T16:04:54.400286",
#       "is_organization": true,
#       "approval_status": "approved",
#       "state": "active"
#     },
#     "owner_org": "92b81830-356c-4fb0-b25f-1581619c8821",
#     "private": false,
#     "state": "active",
#     "title": "Proyectos",
#     "type": "dataset",
#     "update_frequency": "365",
#     "url": "",
#     "version": "1.0",
#     "groups": [
#       {
#         "description": "",
#         "display_name": "Transparencia",
#         "id": "8552e8e2-e342-43fe-ab27-4e3c50564f9b",
#         "image_display_url": "https://catalogodatos.gub.uy/uploads/group/2019-08-22-234010.387437transparencia.png",
#         "name": "transparencia",
#         "title": "Transparencia"
#       }
#     ],
#     "resources": [
#       {
#         "cache_last_updated": null,
#         "cache_url": null,
#         "created": "2020-08-07T19:34:13.969014",
#         "datastore_active": false,
#         "description": "Este recurso contiene los metadatos de los proyectos del organismo",
#         "format": "JSON",
#         "hash": "",
#         "id": "92b023f8-78e9-4888-a16c-e30af2d9d8f4",
#         "last_modified": "2020-08-07T19:34:13.808254",
#         "metadata_modified": "2020-08-07T19:34:13.969014",
#         "mimetype": "application/json",
#         "mimetype_inner": null,
#         "name": "Metadatos de los proyectos",
#         "package_id": "e6ecc291-2ace-4efe-8412-62e2ace3199b",
#         "position": 0,
#         "qa": {
#           "resource_timestamp": null,
#           "archival_timestamp": "2022-05-31T07:39:09.616687",
#           "openness_score": 3,
#           "openness_score_reason": "Content of file appeared to be format \"CSV\" which receives openness score: 3.",
#           "format": "CSV",
#           "created": "2020-08-08T17:55:45.805328",
#           "updated": "2022-05-31T11:29:34.319583"
#         },
#         "resource_type": null,
#         "size": 2753,
#         "state": "active",
#         "url": "https://catalogodatos.gub.uy/dataset/e6ecc291-2ace-4efe-8412-62e2ace3199b/resource/92b023f8-78e9-4888-a16c-e30af2d9d8f4/download/metadatos-de-los-proyectos.json",
#         "url_type": "upload"
#       },
#       {
#         "cache_last_updated": null,
#         "cache_url": null,
#         "created": "2020-08-07T19:34:29.908306",
#         "datastore_active": true,
#         "description": "Este recurso contiene los datos de los proyectos del organismo",
#         "format": "CSV",
#         "hash": "",
#         "id": "29a6168b-0a18-4b26-8453-19031ae7a74a",
#         "last_modified": "2020-08-07T19:34:29.493003",
#         "metadata_modified": "2020-08-07T19:34:29.908306",
#         "mimetype": "text/csv",
#         "mimetype_inner": null,
#         "name": "Proyectos del organismo",
#         "package_id": "e6ecc291-2ace-4efe-8412-62e2ace3199b",
#         "position": 1,
#         "qa": {
#           "resource_timestamp": null,
#           "archival_timestamp": "2022-05-31T07:39:10.446353",
#           "openness_score": 3,
#           "openness_score_reason": "Content of file appeared to be format \"CSV\" which receives openness score: 3.",
#           "format": "CSV",
#           "created": "2020-08-08T17:55:45.857804",
#           "updated": "2022-05-31T11:29:34.348250"
#         },
#         "resource_type": null,
#         "size": 1351,
#         "state": "active",
#         "url": "https://catalogodatos.gub.uy/dataset/e6ecc291-2ace-4efe-8412-62e2ace3199b/resource/29a6168b-0a18-4b26-8453-19031ae7a74a/download/proyectos-del-organismo.csv",
#         "url_type": "upload"
#       },
#       {
#         "cache_last_updated": null,
#         "cache_url": null,
#         "created": "2020-08-07T19:34:46.475663",
#         "datastore_active": false,
#         "description": "Este recurso contiene los datos de los proyectos del organismo",
#         "format": "JSON",
#         "hash": "",
#         "id": "0002522a-0089-4ee3-ab3d-43b726d0efd6",
#         "last_modified": "2020-08-07T19:34:46.332479",
#         "metadata_modified": "2020-08-07T19:34:46.475663",
#         "mimetype": "application/json",
#         "mimetype_inner": null,
#         "name": "Proyectos del organismo",
#         "package_id": "e6ecc291-2ace-4efe-8412-62e2ace3199b",
#         "position": 2,
#         "qa": {
#           "resource_timestamp": null,
#           "archival_timestamp": "2022-05-31T07:39:11.264616",
#           "openness_score": 3,
#           "openness_score_reason": "Content of file appeared to be format \"CSV\" which receives openness score: 3.",
#           "format": "CSV",
#           "created": "2020-08-08T17:55:45.946582",
#           "updated": "2022-05-31T11:29:34.387290"
#         },
#         "resource_type": null,
#         "size": 2325,
#         "state": "active",
#         "url": "https://catalogodatos.gub.uy/dataset/e6ecc291-2ace-4efe-8412-62e2ace3199b/resource/0002522a-0089-4ee3-ab3d-43b726d0efd6/download/proyectos-del-organismo.json",
#         "url_type": "upload"
#       },
#       {
#         "cache_last_updated": null,
#         "cache_url": null,
#         "created": "2020-08-07T19:34:58.687499",
#         "datastore_active": false,
#         "description": "Este recurso contiene los datos de los proyectos del organismo",
#         "format": "XML",
#         "hash": "",
#         "id": "9c39d240-0fe6-4a83-a512-7e93cd893a8a",
#         "last_modified": "2020-08-07T19:34:58.563746",
#         "metadata_modified": "2020-08-07T19:34:58.687499",
#         "mimetype": "application/xml",
#         "mimetype_inner": null,
#         "name": "Proyectos del organismo",
#         "package_id": "e6ecc291-2ace-4efe-8412-62e2ace3199b",
#         "position": 3,
#         "qa": {
#           "resource_timestamp": null,
#           "archival_timestamp": "2022-05-31T07:39:12.092115",
#           "openness_score": 3,
#           "openness_score_reason": "Content of file appeared to be format \"XML\" which receives openness score: 3.",
#           "format": "XML",
#           "created": "2020-08-08T17:55:45.968148",
#           "updated": "2022-05-31T11:29:34.398568"
#         },
#         "resource_type": null,
#         "size": 1937,
#         "state": "active",
#         "url": "https://catalogodatos.gub.uy/dataset/e6ecc291-2ace-4efe-8412-62e2ace3199b/resource/9c39d240-0fe6-4a83-a512-7e93cd893a8a/download/proyectos-del-organismo.xml",
#         "url_type": "upload"
#       }
#     ],
#     "tags": [
#       {
#         "display_name": "Proyectos",
#         "id": "c6d2666c-a3a7-4285-ae6e-3b7e6560beac",
#         "name": "Proyectos",
#         "state": "active",
#         "vocabulary_id": null
#       },
#       {
#         "display_name": "Transparencia Activa",
#         "id": "cf0d9496-ebd1-4e84-bded-8d8082c56e6a",
#         "name": "Transparencia Activa",
#         "state": "active",
#         "vocabulary_id": null
#       },
#       {
#         "display_name": "ancap",
#         "id": "19943ef9-5a83-4db2-9910-8fe662da2139",
#         "name": "ancap",
#         "state": "active",
#         "vocabulary_id": null
#       }
#     ],
#     "relationships_as_subject": [],
#     "relationships_as_object": [],
#     "qa": {
#       "openness_score": 3,
#       "openness_score_reason": "Content of file appeared to be format \"CSV\" which receives openness score: 3.",
#       "updated": "2022-05-31T11:29:34.398568"
#     }
#   }
# }

# %%
# Package Relationships List
#
# Dados dos ID de datasets, busca relaciones entre ellos si es que las hay.
# No parecen estarlo usando los del catalogo de datos de gub.uy.
endpoint_suffix = 'package_relationships_list?id=ursea-productos-electricos-autorizados-rspebt-2019&id2=ursea-productos-electricos-autorizados-rspebt-2020'
url = build_url(endpoint_suffix)

pretty_print_json(do_get_request(url))
# Out:
# {
#   "help": "https://catalogodatos.gub.uy/es/api/3/action/help_show?name=package_relationships_list",
#   "success": true,
#   "result": []
# }

# %%
# Tag List
#
# Los tags son palabras clave o términos que se asignan a los datasets (packages)
# para describir y categorizar el contenido de los mismos. Vemos que el catalogo
# de datos de gub.uy tiene etiquetas que usa en sus recursos.
# Este endpoint lista los disponibles del catalogo de datos. Hay endpoints adicionales
# que permiten hacer queries (los tag_search).
# Se puede tambien usar "tag_show" pasando como parametro "include_datasets" en true y
# obtenemos todos los datasets que tengan el tag asignado.
endpoint_suffix = 'tag_list'
url = build_url(endpoint_suffix)

pretty_print_json(do_get_request(url))
# Out:
# {
#   "help": "https://catalogodatos.gub.uy/es/api/3/action/help_show?name=tag_list",
#   "success": true,
#   "result": [
#     "Catálogo de trámites",
#     "DEA",
#     "diseño",
#     "Bienes patrimoniales",
#     "iot",
#     "servicios",
#     "Nivel sub-nacional",
#     "Economía",
#     "Ley",
#     "Directorio de Empresas",
#     "Geodesia de Montevideo",
#     "adquisiciones",
#     "Biodiversidad",
#     "pymes industriales",
#     "Montevideo",
#     "Recorridos omnibus",
#     "Sueldos",
#     "Denuncias de hurtos",
#     "Contratados",
#     "formación artística",
#     "BROU",
#     "Resultados",
#     "Personas en situación de calle",
#     "Habitabilidad - Espacio habitable",
#     "Combustibles",
#     "Acceso a la información",
#     "Violencia Basada en Género",
#     "Tránsito de Montevideo",
#     "Volumenes Crudos",
#     "Empresas públicas",
#     "Consumo",
#     "Denuncias",
#     "Cuidados remunerados",
#     "Trámites en línea",
#     "Puntos de interés",
#     "Caja de Profesionales 2017",
#     "Planta La Teja",
#     "Aceras",
#     "Insolación",
#     "Cambio climático",
#     "Participación e interacción",
#     "Impotación",
#     "Presión",
#     "Carga Global de Trabajo",
#     "Elecciones internas",
#     "estadisticas",
#     "EIG",
#     "Vinculos societarios",
#     "Natalidad y Fecundidad",
#     "Empresas",
#     "Firma digital",
#     "Planta Minas",
#     "agua envasada",
#     "Poder Judicial",
#     "energia",
#     "Intendencia de Montevideo",
#     "Ambiente",
#     "Encuestas de uso TIC",
#     "Equidad",
#     "Cabezales de numeración",
#     "Usuarios",
#     "habilitación",
#     "Proceso penal",
#     "Pedidos",
#     "Heliofania",
#     "Precipitaciones",
#     "Actividades y cursos",
#     "ANCAP",
#     "Mutualistas",
#     "Comisión Honoraria",
#     "Fallecidos",
#     "Turismo receptivo",
#     "PIAS",
#     "Turismo",
#     "Índice",
#     "Impactos ambientales",
#     "Homicidios dolosos consumados",
#     "Compraventas",
#     "Contacto",
#     "Publicidad",
#     "Niños",
#     "Marco Jurídico",
#     "Condenas",
#     "Prestaciones medicas",
#     "Fiscalía",
#     "Entorno Social",
#     "Seguridad Social",
#     "Udelar",
#     "PAD",
#     "Evolución del organismo",
#     "Recarga",
#     "Servicio civil",
#     "Emisión",
#     "AIP",
#     "Tráfico",
#     "Suicidios de PPL",
#     "Servicios públicos",
#     "vocabularios",
#     "Trabajo Otros",
#     "Oferta turística",
#     "Destinos internacionales",
#     "Área Verde",
#     "Intensidad de viento",
#     "Movilidad",
#     "Áreas quemadas",
#     "vehículos",
#     "Suspensiones condicionales del proceso",
#     "Información de Transparencia",
#     "Formación",
#     "FNR",
#     "Geográficos",
#     "Cambio Climático",
#     "Petróleo",
#     "Educación Permanente",
#     "Parcelas",
#     "Teatro",
#     "Tablada",
#     "Mercado",
#     "Infraestructura",
#     "Infancia",
#     "Móvil",
#     "declaración jurada",
#     "residuos sólidos",
#     "base de datos",
#     "Abonados",
#     "cine",
#     "gobierno abierto",
#     "destacamentos",
#     "Seguridad pública",
#     "Contenedores",
#     "Situación Conyugal Y Nupcialidad",
#     "Latitud",
#     "Asentamientos",
#     "Registos",
#     "metadatos",
#     "Reuniones",
#     "Rentas",
#     "Anuario",
#     "Gobierno abierto",
#     "Visualizador de Accesibilidad Digital",
#     "jovenes",
#     "Remates judiciales",
#     "Viáticos",
#     "Plan de acción Nacional de Gobierno Abierto",
#     "Fondo Nacional de Recursos",
#     "Compras",
#     "Subsidios",
#     "Precios",
#     "Empresas y servicios de salud",
#     "Elección Conaprole 2016",
#     "Ley 18.360",
#     "redes sociales",
#     "Documentos relacionados",
#     "compras estatales",
#     "Documentos",
#     "Totales de Reclamos",
#     "Estructura",
#     "Energía",
#     "Diputados",
#     "DEI",
#     "ENDIS",
#     "Naciones Unidas",
#     "Omnibus Interdepartamentales",
#     "Enfermedades transmisibles",
#     "Focos",
#     "Funcionarios en comisión",
#     "Florida",
#     "Transferencias Contributivas",
#     "Trámites",
#     "CO2",
#     "Áreas urbanas",
#     "Información reservada",
#     "Bases de datos personales",
#     "Teléfonos públicos",
#     "maldonado",
#     "Estado de salud en la vejez",
#     "Gasto Público Social",
#     "Generadores de vapor",
#     "Terreno hidrologicamente consistente",
#     "datos referenciales",
#     "fondos",
#     "TXT",
#     "Sociedades anónimas",
#     "Auditoria",
#     "Teléfonos",
#     "Viviendas",
#     "Meteorología",
#     "Entornos",
#     "Seguridad Económica",
#     "Características de los ocupados",
#     "Filatélica",
#     "Impacto",
#     "Promoción de empleo",
#     "Telecomunicaciones",
#     "Indicadores demográficos",
#     "Desarrollo social",
#     "urbanos",
#     "prueba",
#     "Finanzas",
#     "Observatorio",
#     "Solicitud de información",
#     "Ejecución",
#     "Fecundidad adolescente",
#     "Ingresos",
#     "Parque Automotor",
#     "audiovisual",
#     "Residuos secos",
#     "parámetros",
#     "Situación laboral de los referentes",
#     "Vivienda y hábitat",
#     "Orquesta Filarmónica de Montevideo",
#     "ECH",
#     "Gastos",
#     "Sistema de salud",
#     "Polígonos",
#     "Guardado de archivos",
#     "Medicina",
#     "multas",
#     "meta",
#     "Proyectos de ley",
#     "Nivel y composición",
#     "GRAS",
#     "Prestadores",
#     "Tecnologías de la Información",
#     "Organismos",
#     "Referéndum 2022",
#     "SNIS",
#     "plataformas",
#     "Imagen",
#     "Concejos Vecinales",
#     "PPnoE",
#     "Seguridad eléctrica",
#     "Entornos físicos",
#     "Salud adulto mayor",
#     "Transporte Aéreo",
#     "Sociodemográfico",
#     "Refinería",
#     "Potencia instalada",
#     "coliformes",
#     "Censo",
#     "seguridad electrica",
#     "Comisión",
#     "Personal de salud",
#     "Recorridos suburbanos",
#     "Trabajo no remunerado",
#     "escala remuneraciones",
#     "Unidad ejecutora",
#     "Remunerado - Actividad",
#     "Atención en salud",
#     "juntas departamentales",
#     "Establecimientos",
#     "bloqueo",
#     "Telefonía residencial",
#     "Marco legal",
#     "obras",
#     "Salud",
#     "NDC",
#     "Educación Permamente",
#     "Programa presupuestal",
#     "Nivel educativo",
#     "Asistencias",
#     "partidas",
#     "Normativa",
#     "Indicadores",
#     "Multas",
#     "Centros comunales",
#     "Consejos vecinales",
#     "Fugas",
#     "calidad",
#     "Parcelario",
#     "Catálogo",
#     "Solar termica",
#     "arbolado urbano",
#     "empresa",
#     "Ursea",
#     "Reclamos",
#     "Antilavado",
#     "Insuficiencia de ingresos",
#     "Política industrial",
#     "Desempleo",
#     "Pluviómetros",
#     "Contexto Sociodemográfico",
#     "Financiero",
#     "Tarifas",
#     "PPL por edad",
#     "compensaciones funcionarios en comision",
#     "Catastro",
#     "Decretos",
#     "Referencia geográfica",
#     "Repartidos",
#     "Establecimientos de cuidados permanentes",
#     "EUTIC",
#     "Arboles",
#     "Calidad del agua dulce",
#     "Modelo 3D",
#     "Actividades parlamentarias",
#     "Secretaría General",
#     "Factores de riesgo y limitaciones",
#     "Gub.uy",
#     "Infraestructura urbana",
#     "Servicios turísticos",
#     "UDELAR",
#     "Importación",
#     "Denuncias de violencia doméstica",
#     "Adolescentes",
#     "Adjudicaciones",
#     "Emergencias",
#     "Condatos",
#     "Concursos",
#     "Inciso",
#     "Parlamento del Uruguay",
#     "Encuesta de turismo receptivo",
#     "contratacion",
#     "organismos",
#     "suministros",
#     "Declaración jurada",
#     "Cuidados no remunerados",
#     "Ingresos laborales",
#     "Accesibilidad digital",
#     "Presupuesto",
#     "Delitos contra la persona",
#     "Autoridades",
#     "Ley 19.973",
#     "Educación Pública",
#     "Inau",
#     "Datos",
#     "Debate",
#     "funcionarios",
#     "Incendios forestales",
#     "Actas",
#     "Horarios",
#     "Balotaje",
#     "Trabajo de cuidados",
#     "NO2",
#     "Expedientes",
#     "ATUSERVICIO",
#     "Rendición de cuentas",
#     "Balance hídrico",
#     "Citaciones",
#     "Exterior",
#     "Cambio climatico",
#     "Accesibilidad Económica",
#     "Horarios de Ómnibus",
#     "MEDIO AMBIENTE",
#     "Radiación Solar",
#     "Vehículos",
#     "productos electricos",
#     "Fuentes",
#     "actividades",
#     "exposicion",
#     "Pasivo",
#     "IDE",
#     "Balance Energético Nacional",
#     "Prácticas de Crianza",
#     "Gasistas",
#     "Gestión digital",
#     "Audiovisual",
#     "Acceso a alimentos",
#     "Cuencas",
#     "Áreas de protección",
#     "Agencia",
#     "Establecimientos adulto mayor",
#     "Cultura y Deporte",
#     "poder judicial",
#     "Sociedad civil",
#     "Covid-19",
#     "Soluciones digitales",
#     "penal",
#     "Encuesta de turismo de cruceros",
#     "DICOSE",
#     "Compraventa de inmuebles rurales",
#     "decretos",
#     "Intendencia",
#     "Ministerio de Turismo",
#     "crisis hidríca",
#     "concursos",
#     "PPL",
#     "Sustancias",
#     "Leyes",
#     "Presión atmosférica",
#     "formación",
#     "Visualizador",
#     "Tramites en línea",
#     "Comisiones en el exterior",
#     "Comisarias",
#     "Proyectos ingresados",
#     "Organismos públicos",
#     "proyectos",
#     "Poder judicial",
#     "Plataformas",
#     "recaudacion",
#     "Instrumentos de apoyo",
#     "Vivienda y Medio Ambiente",
#     "Pases en comisión",
#     "Licitaciones",
#     "RSPEBT",
#     "Marco jurídico",
#     "Inventario Promedio",
#     "Arbolado urbano",
#     "Calendario",
#     "Resoluciones",
#     "Resultados de convocatorias",
#     "Vinculos laborales",
#     "proveedores",
#     "Mapa",
#     "Estado nutricional",
#     "Foto",
#     "Cumplimiento de solicitudes",
#     "Tránsito",
#     "Áreas y programas de salud",
#     "Marco de referencia",
#     "Leyes promulgadas",
#     "Partidas presupuestales",
#     "Residuos Generados",
#     "Transparencia",
#     "Políticas Sociales",
#     "Medio Ambiente",
#     "Clima",
#     "Ministerio de Ambiente",
#     "Gestión documental",
#     "Actualizacion",
#     "Coronavirus",
#     "Observatorio de Accesibilidad Digital",
#     "Desfribilador",
#     "Quinto Plan de Acción Nacional de Gobierno Abierto",
#     "Poder Ejecutivo",
#     "Encuesta de Hogares",
#     "Características de los hogares",
#     "Imputaciones",
#     "mutualista",
#     "Consumo de energía",
#     "Cargos",
#     "Rocha",
#     "Homicidios a mujeres",
#     "ANEP",
#     "Regímenes industriales",
#     "Accidentes de tránsito",
#     "Remunerado - Empleo",
#     "Consumo familiar",
#     "localidades",
#     "Documentos de proyectos",
#     "Resultado operativo",
#     "Salud y bienestar",
#     "Inclusión productiva",
#     "Otros organismos",
#     "UyMap",
#     "Intervenciones policiales",
#     "Residuos Valorizados",
#     "Pospago",
#     "Nomenclatura",
#     "Derechos",
#     "Fecundidad y Mortalidad",
#     "Aerofotogrametría",
#     "ArqdeDatos",
#     "eventos",
#     "Seguridad Ciudadana",
#     "Sensores pluviales",
#     "Materiales reciclables",
#     "No remunerado - Componentes",
#     "Población activa",
#     "Paysandu",
#     "educacion",
#     "trámites",
#     "FE",
#     "Correo Uruguayo",
#     "Egresos",
#     "Desarrollo Sostenible",
#     "compras",
#     "Encuestas",
#     "Puntos de atención",
#     "Plenario",
#     "Delitos contra la propiedad",
#     "Anuario estadistico",
#     "direcciones",
#     "Seccionales policiales declaradas",
#     "Control de calidad",
#     "Alimentación",
#     "Violencia",
#     "Ganadería",
#     "ancap",
#     "Violencia domestica",
#     "UV",
#     "Parque automotor",
#     "Transparencia activa",
#     "Glosario",
#     "Montevideo decide",
#     "Recursos Pobreza monetaria- Multi y NBI",
#     "Sistema carcelario",
#     "Vías de transito",
#     "llamados",
#     "Policlínicas",
#     "Registros Diarios",
#     "Espacios publicos",
#     "Geodesia",
#     "Observatorio de la sociedad de la información",
#     "Icendios forestales",
#     "Corralito",
#     "Segunda vuelta 2019",
#     "Fondos públicos",
#     "Erodabilidad",
#     "Consultas",
#     "Gripe",
#     "Padrones urbanos y rurales",
#     "Calidad del Aire",
#     "Cuarentena",
#     "Herramientas con fines sociales",
#     "Volúmenes",
#     "transparencia",
#     "Energía eléctrica",
#     "Homicidios",
#     "Salud sexual y reproductiva",
#     "Serie precio de la tierra arrendamientos",
#     "google",
#     "precios",
#     "Caso Piloto",
#     "Funcionarios en ANCAP",
#     "Documentos parlamentarios",
#     "CDN",
#     "Seguridad  electrica",
#     "Transporte público",
#     "Denuncias de lesiones",
#     "Ancap",
#     "Desigualdad",
#     "Servicios del estado",
#     "Familia",
#     "Plan integral de atención a la salud",
#     "Elecciones municipales 2020",
#     "Aire",
#     "dea",
#     "apertura de empresas",
#     "Procesos",
#     "Producción",
#     "Paquetes",
#     "padrones",
#     "Funcionarios en BCU",
#     "Elepem",
#     "Forestación",
#     "Sellos postales",
#     "musica",
#     "Tramites y servicios",
#     "Asignación jerárquica",
#     "Estadísticas agropecuarias",
#     "Ley 19.889",
#     "Denuncias de rapiña",
#     "Líneas telefónicas",
#     "Movilidad regulada",
#     "ejecución",
#     "Saneamiento",
#     "publicación",
#     "Correo",
#     "Coeficientes de erodabilidad",
#     "elecciones",
#     "sector energético",
#     "Combustibles Líquidos",
#     "Fuente",
#     "CFE",
#     "Niñas",
#     "Transito",
#     "INE",
#     "EEPP",
#     "Delitos",
#     "Seguridad Pública",
#     "Circulación de cargas",
#     "Inversión",
#     "Situación conyugal y nupcialidad",
#     "Exposición a la violencia",
#     "Población privada de libertad",
#     "adolescentes",
#     "Acceso a la información pública",
#     "contenidos",
#     "Suelo",
#     "Parques",
#     "Estado",
#     "Inclusión laboral",
#     "NCPP",
#     "Prisión domiciliaria",
#     "Financieras",
#     "Destino de envíos",
#     "FAE",
#     "Denuncias ambientales",
#     "morbilidad",
#     "Estructura de población",
#     "movilidad",
#     "vinculación con la academia",
#     "Hola",
#     "Capital humano",
#     "Igualdad",
#     "Juntas departamentales",
#     "Pobreza",
#     "Delitos sexuales",
#     "Actividad económica",
#     "DIRECCIONES",
#     "Estado uruguayo",
#     "Tobilleras",
#     "Canevas",
#     "Pedidos de Informes",
#     "Ascendencia racial",
#     "Monitoreo",
#     "Habitabilidad - Servicios",
#     "Maldonado",
#     "Viático",
#     "Transporte",
#     "Servicios postales",
#     "entradas emitidas",
#     "salud",
#     "bicicletas",
#     "Comunicación",
#     "Productos autorizados",
#     "Cuidados",
#     "Llamados y concursos",
#     "INGEI",
#     "Arbolado",
#     "Red de drenaje de aguas",
#     "Declarción Jurada",
#     "Rendiciones de Cuenta",
#     "Elecciones nacionales",
#     "Migración",
#     "OSC",
#     "Fondo por Más",
#     "Uso de tierra",
#     "Transferencias no contributivas",
#     "Dióxido de carbono",
#     "Diario",
#     "Series",
#     "Área programatica",
#     "Banco Central",
#     "Erosión",
#     "ZIP",
#     "Fondo",
#     "Covid19",
#     "autorizaciones RSPEBT",
#     "Arquitectura de Datos",
#     "Balotaje 2019",
#     "Violencia basada en género",
#     "Relaciones Afectivas y Sexuales",
#     "RUPE",
#     "Curvas de nivel",
#     "Abastecimiento",
#     "Archivo",
#     "TIC",
#     "Maltrato Infantil",
#     "Mercado Laboral",
#     "Bandas salariales",
#     "Tratamiendos médicos",
#     "did",
#     "Rentas agropecuario",
#     "Cursantes",
#     "Cámara de Representantes",
#     "Participación",
#     "libros",
#     "Tareas comunitarias",
#     "Cobertura",
#     "Elección Caja Notarial 2016",
#     "DGEIP",
#     "LUC",
#     "Uso del Tiempo",
#     "estadísticas oficiales",
#     "Envíos certificados",
#     "Funiconarios",
#     "cuerpos de agua",
#     "Patrimonio",
#     "Cautelares",
#     "desarrollo de audiencias",
#     "ANR",
#     "Arrendamiento agropecuario",
#     "Constitución del hogar",
#     "Cine",
#     "empresas",
#     "Estadísticas Oficiales",
#     "presupuesto",
#     "Organismos internacionales",
#     "Transferencias contributivas",
#     "Ministerio de Salud",
#     "ACCE",
#     "shadowban",
#     "Planificación estratégica",
#     "Entornos sociales",
#     "Privacidad",
#     "CIIU",
#     "Factor K",
#     "Funcionarios",
#     "IMM",
#     "licitaciones",
#     "Morbilidad y factores de riesgo",
#     "Línea de producto",
#     "Formación en Eduación",
#     "Nómina",
#     "Modelo digital de terreno",
#     "Foto aerea",
#     "Faltas",
#     "Baja tensión",
#     "Asfaltos",
#     "Epidemiología",
#     "Construcción",
#     "Nutrición",
#     "Por funciones",
#     "Componentes del trabajo no remuneado",
#     "impacto",
#     "SHP",
#     "Justicia",
#     "Municipios",
#     "Docentes universitarios",
#     "PreciosUy",
#     "Clima educativo del hogar",
#     "datos geográficos",
#     "Arrestos domiciliarios",
#     "Horarios de omnibus",
#     "Erosión de suelos",
#     "Tierras",
#     "Vigentes",
#     "Remuneraciones",
#     "Ciclovía",
#     "Estadísticas oficiales",
#     "Compras públicas",
#     "No remunerado - En el hogar",
#     "Ministerio de Salud Pública",
#     "Reciclaje",
#     "Participación ciudadana",
#     "Formularios",
#     "bicicletario",
#     "Actividad",
#     "Metas",
#     "vivienda",
#     "Bienes y servicios",
#     "Pobreza de ingresos",
#     "takedown",
#     "Nivel nacional",
#     "Desfribiladores externos automáticos",
#     "Regulados",
#     "Educación",
#     "twitter",
#     "Locales",
#     "Indicadores Sociodemográficos",
#     "Productos postales",
#     "NBI",
#     "ejecución presupuestal",
#     "Abrelatam",
#     "moderación",
#     "IG",
#     "educación",
#     "Afrodescendientes",
#     "Carga global de trabajo",
#     "Registros administrativos",
#     "Objetivos",
#     "Gobierno Abierto",
#     "Electricidad",
#     "Violencia doméstica",
#     "Defensa al consumidor",
#     "Vínculos laborales",
#     "Tiempo libre e Intereses",
#     "Parlamento Uruguayo",
#     "Parlamento",
#     "OGP",
#     "Autorizaciones RSPEBT",
#     "Registros diarios",
#     "Actos médicos",
#     "Vías de tránsito",
#     "IDEuy",
#     "ambiente",
#     "Ámbito laboral",
#     "Zonas ribereñas",
#     "Obras uruguay",
#     "Actividad Física",
#     "Conferencia",
#     "Productos",
#     "Códigos",
#     "Fecundidad",
#     "Ventas",
#     "Contrataciones",
#     "Estadisticas",
#     "Tasas",
#     "instagram",
#     "Crianza y socialización",
#     "SARS-Cov2",
#     "Emisiones",
#     "Efluentes",
#     "Modelo digital de superficie",
#     "registro civil",
#     "Residuos",
#     "Prácticas de alimentación",
#     "Humedad",
#     "Prevalencia de Violencia Basada en Género",
#     "Feminicidios",
#     "Centros educativos",
#     "Precipitación",
#     "Lagunas",
#     "Recursos",
#     "5toPlanGA",
#     "ExPlanta",
#     "Comerciales e industriales",
#     "Cánevas",
#     "Cartas",
#     "gobierno",
#     "Elecciones Internas",
#     "Espacios públicos",
#     "San José",
#     "Atención",
#     "Hogar",
#     "Tanques",
#     "Estadísticas Agropecuarias",
#     "nacionales",
#     "censura",
#     "Fija",
#     "Femicidios",
#     "Convenios",
#     "Registro Civil",
#     "Actividades realizadas",
#     "Morbilidad",
#     "Prepago",
#     "contraprestación",
#     "Personas mayores dependientes",
#     "consumo",
#     "Características de la vivienda",
#     "Nuevo Código del Proceso Penal",
#     "Asistencia y Seguridad Social",
#     "Unidad especializada",
#     "playas",
#     "Subsistencia",
#     "Contenedores de residuos",
#     "Erosión hidrica",
#     "Harvest",
#     "registro",
#     "Accesibilidad web",
#     "PPL por nacionalidad",
#     "Foto aérea",
#     "Informes",
#     "elencos estables",
#     "UAIP",
#     "agua",
#     "Cometidos",
#     "evaluación",
#     "Denuncias de abigeatos",
#     "Uso",
#     "Drenaje de agua",
#     "estudiantes",
#     "PPL por Establecimientos Penitenciarios",
#     "Entidades",
#     "Género",
#     "Victimización",
#     "presos",
#     "Matific",
#     "COM",
#     "Bosques",
#     "Pobreza y Desigualdad",
#     "Vacunas",
#     "visualización",
#     "Emancipación",
#     "Compensaciones",
#     "Política nacional de cambio climático",
#     "Grilla",
#     "Tratamientos medicos",
#     "Aliviaderos",
#     "Vida subsistencia y desarrollo",
#     "Arreglos familiares",
#     "Plan filatélico",
#     "Velocidad",
#     "Educación Técnico Profesional",
#     "Contexto sociodemográfico",
#     "Remunerado - Desempleo",
#     "largometraje",
#     "Encuesta de turismo emisivo",
#     "Agenda digital",
#     "líneas de ómnibus",
#     "entradas",
#     "Metadatos",
#     "Reglamento",
#     "Monumentos históricos",
#     "Hipsografía",
#     "Diario de sesiones",
#     "O3",
#     "Servicios de salud",
#     "Prácticas de crianza",
#     "Nivel del mar",
#     "Discapacidad",
#     "Agua potable y saneamiento",
#     "Tenencia de la vivienda",
#     "Protección y Seguridad Social",
#     "Ciudadanía digital",
#     "Equipamiento urbano",
#     "Prevalencia de violencia basada en género",
#     "Regulación Alimentaria",
#     "Mortalidad",
#     "No remunerado - De cuidados",
#     "Recorridos Omnibus",
#     "Banco Central del Uruguay",
#     "ganadería",
#     "Contexto Económico",
#     "Empleo",
#     "Pedidos de informes",
#     "Ley de cuotas",
#     "Ministerio del Interior",
#     "Eficiencia energética",
#     "Nivel de agua",
#     "Organizaciones",
#     "sa",
#     "Balance",
#     "Remuneración",
#     "Cursos",
#     "Productos eléctricos",
#     "matrimonios",
#     "Comisiones",
#     "Libertades a prueba",
#     "codigueras",
#     "Consejo Consultivo",
#     "poblados",
#     "Nomenclator",
#     "Mujer",
#     "Organigrama",
#     "Cuadrícula",
#     "Censo Calle",
#     "MGAP",
#     "Estados consolidados",
#     "Acceso",
#     "Generación",
#     "Vias de tránsito",
#     "economía",
#     "Hisopados",
#     "Precios y salario",
#     "Disciplina Infantil",
#     "Paradas de ómnibus",
#     "montevideo audiovisual",
#     "Sistema de remuneraciones",
#     "Telefonía",
#     "Genero",
#     "Ejecución presupuestal",
#     "Licitiaciones",
#     "Atuservicio",
#     "intendencia",
#     "Opiniones",
#     "IOT",
#     "Domicilio",
#     "Fotos",
#     "Calles de Montevideo",
#     "Medios de comunicación",
#     "acceso a la cultura",
#     "tierras",
#     "contrataciones",
#     "Energía electrica",
#     "Tributos",
#     "Capacitaciones",
#     "alto precio",
#     "departamentos",
#     "Evolución",
#     "Oferta educativa",
#     "Veredas",
#     "Comercio exterior",
#     "Variables Agroclimáticas",
#     "Actividades",
#     "Estudio",
#     "Vivienda promovida",
#     "Cursos y actividades",
#     "Expedientes electrónicos",
#     "Género y diversidad en PPL",
#     "Transparencia pasiva",
#     "URSEA RSPEBT",
#     "Seguridad ciudadana",
#     "Financiamiento externo",
#     "Seguridad",
#     "DNA",
#     "Omisos",
#     "Crudos",
#     "CAP",
#     "Comisiones parlamentarias",
#     "Trabajo",
#     "ODS",
#     "Remunerado - Calidad del empleo",
#     "Servicios y tramites",
#     "radares",
#     "Mapa social",
#     "origen",
#     "resultado",
#     "Encuesta Nacional de Juventud",
#     "Banda Sinfónica de Montevideo",
#     "Servicios",
#     "Lluvia",
#     "Carga global de cuidados",
#     "Imputaciones y condenas",
#     "Economia",
#     "INTAI",
#     "Calles",
#     "Codigueras",
#     "Sucursales",
#     "Desarrollo infantil",
#     "Cultura",
#     "población",
#     "Activiades y cursos",
#     "Mercado interno",
#     "Compraventa de campos",
#     "Participación TICs y cultura",
#     "Alumbrado",
#     "Estudiantes",
#     "Violencia sexual",
#     "Llamados",
#     "Serie precio de la tierra compraventas",
#     "Precios al consumidor",
#     "A tu Servicio",
#     "Arrendamiento",
#     "Morbimortalidad",
#     "Activo",
#     "Estilo de vida",
#     "Operadores turísticos",
#     "Temperatura",
#     "Trazabilidad",
#     "transito",
#     "Delitos denunciados",
#     "Ámbito educativo",
#     "formación técnica",
#     "Vivienda",
#     "Horario",
#     "Calidad del aire",
#     "Ucep",
#     "Macroeconomía",
#     "Productos de supermercados",
#     "Agro",
#     "DGES",
#     "Lavado de activos",
#     "recolección",
#     "Trabajo doméstico en el hogar",
#     "Actividades agrícolas",
#     "Transparecia",
#     "Acceso y cobertura",
#     "Recursos y prestaciones",
#     "Transporte Público",
#     "Politicas públicas",
#     "Uruguay",
#     "Hogares",
#     "Por Mi Barrio",
#     "Precios minoritas",
#     "Vías de Montevideo",
#     "api",
#     "Ubicaciones notables",
#     "Casas de salud",
#     "Ámbitos de participación",
#     "nacimientos",
#     "Puestos de trabajo",
#     "Instaladores",
#     "LSQA",
#     "Habitabilidad",
#     "Población",
#     "Administración de justicia",
#     "MIRA",
#     "Biblioteca País",
#     "Responsables de transparencia",
#     "Perfiles",
#     "Alimentación perceptiva",
#     "Siniestros de Tránsito",
#     "IBH",
#     "Datoreferencial",
#     "oid",
#     "Solventes",
#     "política industrial",
#     "Agua",
#     "Instituto",
#     "Aplicación",
#     "Compras estatales",
#     "Ley 17.673",
#     "sensor",
#     "Estadísticas",
#     "música",
#     "Turismo emisivo",
#     "Ediles",
#     "Elecciones departamentales 2020",
#     "DINAGUA",
#     "Ciudades",
#     "Tranparencia Activa",
#     "Áreas forestales",
#     "Medicina altamente especializada",
#     "personas",
#     "datos geograficos",
#     "Parlameneto del Uruguay",
#     "Dictámenes",
#     "Líneas residenciales",
#     "Cámara de Senadores",
#     "CREA",
#     "Precios minoristas",
#     "Educación Incial y Primaria",
#     "convenios",
#     "Productos filatélicos",
#     "Penal",
#     "Zona Geográfica",
#     "borrar",
#     "Pliegos",
#     "residuos",
#     "Pandemia",
#     "Encuesta",
#     "Reservas",
#     "Perfil Puestos",
#     "Desarrollo Infantil",
#     "Criminalidad",
#     "Parque habitacional",
#     "Bases de datos",
#     "Tipo de contrato",
#     "Gobiernos municipales",
#     "Viento",
#     "Obras",
#     "Actividad parlamentaria",
#     "Gas Natural",
#     "Industria",
#     "Misiones Oficiales",
#     "RRHH",
#     "Código Postal",
#     "Bibliotecas",
#     "Pareja o ex pareja",
#     "Lineas Omnibus",
#     "Lactancia",
#     "Sexo",
#     "Ley de empleo",
#     "BCU",
#     "Telefonía comercial",
#     "LATU",
#     "medicina altamente especializada",
#     "Elección Nacional 2019",
#     "Usos",
#     "Crudos procesados",
#     "Volúmenes productos",
#     "Plazas",
#     "MA",
#     "Trans",
#     "espectáculos",
#     "PIDA",
#     "crédito",
#     "Recolección",
#     "Calidad del empleo",
#     "Guía de tramites",
#     "Equipamientos",
#     "Nacionales",
#     "Estructura de la Población",
#     "BEN",
#     "Confort del hogar",
#     "Cartografía",
#     "niñez y adolescencia",
#     "Compromiso de gestión",
#     "Ordenamiento territorial",
#     "Fibra óptica",
#     "Medio ambiente",
#     "TV",
#     "SINAE",
#     "COVID-19",
#     "Reportes",
#     "Autores de Obras",
#     "apelación",
#     "Personas politicamente expuestas",
#     "Sectores de actividad",
#     "Residuos Gestionados",
#     "Universidad",
#     "Inspecciones",
#     "Capacitación",
#     "Comunicación y participación",
#     "Abre Latam",
#     "Unidades ejecutoras",
#     "Seccionales policiales",
#     "Indice",
#     "Incendios",
#     "Trasparencia Activa",
#     "Iniciativas comunitarias",
#     "Proceso de refinación",
#     "Productos elaborados",
#     "Gobiernos departamentales",
#     "Demografía",
#     "Servicios de atención",
#     "PPI",
#     "desempeño",
#     "SARS-CoV-2",
#     "Proyectos",
#     "Jefaturas",
#     "índice",
#     "cultura",
#     "unaoid",
#     "Localidades",
#     "Desigualdad de ingresos",
#     "imae",
#     "Ceibal",
#     "Contenedor",
#     "ómnibus",
#     "Características de la población a la intemperie",
#     "Gastos de salud",
#     "Usos de TICS",
#     "Cuerpo legislativo",
#     "Cooperativa",
#     "rurales",
#     "Cooperativas de vivienda",
#     "Primera infancia",
#     "Rutas nacionales",
#     "medio ambiente",
#     "Erosión en Uruguay",
#     "facebook",
#     "Gestión administrativa",
#     "Sistema Nacional Integrado de Salud",
#     "PreciosGub",
#     "Profesionales y técnicos",
#     "Transparencia Activa",
#     "defunciones",
#     "Ortoimagen",
#     "Necesidades Básicas Insatisfechas",
#     "Docentes",
#     "youtube",
#     "baja",
#     "Accesibilidad",
#     "analisis de agua",
#     "actos médicos",
#     "Artículo n118",
#     "Libertades vigiladas",
#     "Atmosféricas",
#     "Objetivos Sanitarios Nacionales",
#     "Medio anbiente",
#     "Suministros",
#     "destino",
#     "Autorizaciones",
#     "Suscriptores",
#     "Consejo Ejecutivo",
#     "Estructura orgánica",
#     "Estados contables",
#     "Islas de Calor Urbanas",
#     "Elecciones",
#     "Zonas riparias",
#     "salas públicas",
#     "Salud Materno Infantil",
#     "Lugares públicos",
#     "Suelo Rural",
#     "banda sinfonica",
#     "DIEA",
#     "Evolución histórica",
#     "ddhh",
#     "Ubicación",
#     "Abuso sexual",
#     "CEMPRE",
#     "Fondo Capital",
#     "Covid",
#     "GÉNERO",
#     "Hipsografía nacional",
#     "sociedad de hecho",
#     "indicadores de eficiencia energética",
#     "Habilitación",
#     "Vacunación",
#     "Monumentos de Montevideo",
#     "Proyectos entrados",
#     "Servicios hospitalarios",
#     "Proveedores",
#     "Adquisiciones",
#     "Contabilidad",
#     "ficción",
#     "DGETP",
#     "Objetivos estrátegicos",
#     "Limpieza",
#     "Educación Secundaria",
#     "MSP",
#     "Catálogo de prestaciones de salud",
#     "reclamos",
#     "Gestión humana",
#     "STM",
#     "Enfermedades",
#     "Comedia Nacional",
#     "Sistema Penal",
#     "Longitudinal",
#     "Laboral",
#     "Compras Públicas",
#     "Tramites",
#     "ambiental",
#     "Declaración Juarada",
#     "Prueba",
#     "jardinería",
#     "Gases efecto invernadero",
#     "PAM",
#     "museos",
#     "limpieza",
#     "MRV",
#     "Recorridos",
#     "Omnibus",
#     "Factor",
#     "Registros",
#     "teatro",
#     "Postal",
#     "cortometraje",
#     "Vínculos con el Estado",
#     "Datos hidrologicos",
#     "responsables",
#     "Sanciones",
#     "Presupuesto Participativo",
#     "Proximidad",
#     "Funcionarios Públicos",
#     "Estaciones INIA",
#     "Inasistencias",
#     "espectáculos públicos",
#     "turismo",
#     "documentales",
#     "desfibrilador",
#     "Encomiendas",
#     "Petróleo y derivados",
#     "Habitabilidad - Materialidad",
#     "PPL por sexo",
#     "aplicación",
#     "Agenda",
#     "Personas mayores y cuidados",
#     "Ley empleo",
#     "Emergencia agropecuaria",
#     "Identificador"
#   ]
# }

# %%
# Vocabulary List
#
# En CKAN, los tags suelen formar parte de un vocabulario.
# Parece que en el catalogo de datos de gub uy no lo usaron desde un inicio, y por
# eso todos los tags no pertenecen a ningún vocabulario
endpoint_suffix = 'vocabulary_list'
url = build_url(endpoint_suffix)

pretty_print_json(do_get_request(url))
# Out:
# {
#   "help": "https://catalogodatos.gub.uy/es/api/3/action/help_show?name=vocabulary_list",
#   "success": true,
#   "result": []
# }

# %%
# Group List
#
# Lista los grupos del catalogo de datos. Los grupos son etiquetas a alto nivel
# de los distintos conjuntos de datos que existen.
endpoint_suffix = 'group_list'
url = build_url(endpoint_suffix)

pretty_print_json(do_get_request(url))
# Out:
# {
#   "help": "https://catalogodatos.gub.uy/es/api/3/action/help_show?name=group_list",
#   "success": true,
#   "result": [
#     "agro",
#     "alimentacion",
#     "cultura",
#     "deporte",
#     "desarrollo-social",
#     "economia",
#     "educacion",
#     "estadisticos",
#     "geograficos",
#     "industria",
#     "infraestructura",
#     "justicia",
#     "medio-ambiente",
#     "salud",
#     "seguridad-ciudadana",
#     "contexto-sociodemografico",
#     "trabajo",
#     "transparencia",
#     "transporte",
#     "turismo",
#     "violencia",
#     "vivienda"
#   ]
# }

# %%
# Group Show
#
# Dando un grupo, nos devuelve información de él, como la cantidad de datasets
# que hay publicados, y records "slim" de los mismos.
# Una alternativa para obtener los datasets de los groups seria pegarle a
# "group_package_show" directamente, en vez de mandar la flag en true para incluirlos.
# Además, en ese endpoint no vienen "slim", si no que vienen
endpoint_suffix = 'group_show?id=salud&include_datasets=true'
url = build_url(endpoint_suffix)

pretty_print_json(do_get_request(url))
# Out:
# {
#   "help": "https://catalogodatos.gub.uy/es/api/3/action/help_show?name=group_show",
#   "success": true,
#   "result": {
#     "approval_status": "approved",
#     "created": "2013-06-12T19:26:57.994845",
#     "description": " ",
#     "display_name": "Salud",
#     "id": "bacb6a54-e593-4bcc-ba2e-8e50c5cbd611",
#     "image_display_url": "https://catalogodatos.gub.uy/uploads/group/2019-08-22-233845.717947salud.png",
#     "image_url": "2019-08-22-233845.717947salud.png",
#     "is_organization": false,
#     "name": "salud",
#     "num_followers": 1,
#     "package_count": 268,
#     "state": "active",
#     "title": "Salud",
#     "type": "group",
#     "packages": [
#       {
#         "author": "Área Gobierno Electrónico",
#         "author_email": "agedatoscovid@msp.gub.uy",
#         "creator_user_id": "30e0c393-dec0-482c-b0fb-ad6a0a9cab3d",
#         "id": "e766fbf7-0cc5-4b9a-a093-b56e91e88133",
#         "isopen": true,
#         "license_id": "odc-uy",
#         "license_title": "Licencia de DAG de Uruguay",
#         "license_url": "https://www.gub.uy/agencia-gobierno-electronico-sociedad-informacion-conocimiento/sites/agencia-gobierno-electronico-sociedad-informacion-conocimiento/files/documentos/publicaciones/licencia_de_datos_abiertos_0.pdf",
#         "maintainer": "Área Gobierno Electrónico",
#         "maintainer_email": "agedatoscovid@msp.gub.uy",
#         "metadata_created": "2021-05-28T18:27:41.852926",
#         "metadata_modified": "2024-06-27T20:02:40.324548",
#         "name": "vacunacion-por-covid-19",
#         "notes": "Este conjunto de datos presenta diferentes recursos vinculados a la evolución del plan de vacunación Covid 19.\r\nContiene actos vacunales detallados y acumulados diarios de actos vacunales realizados, cantidad de agendados y en espera de agenda.\r\n\r\nSe agregan datos de la nueva franja etaria de 5 a 11 años a los datos del Histórico de actos vacunales.\r\n\r\nSe agregan datos de dosis 3 y 4 presentando totales diarios por tipo de vacuna, dosis, departamentos y rango etario en el Histórico de actos vacunales.",
#         "num_resources": 8,
#         "num_tags": 4,
#         "organization": {
#           "id": "8a74eecc-8fbb-47a1-b808-bb668b96db29",
#           "name": "msp",
#           "title": "Ministerio de Salud Publica",
#           "type": "organization",
#           "description": "Ministerio de Salud Pública.",
#           "image_url": "2020-08-04-132255.866985LOGO-MinSALUD.png",
#           "created": "2012-11-13T15:14:04.125121",
#           "is_organization": true,
#           "approval_status": "approved",
#           "state": "active"
#         },
#         "owner_org": "8a74eecc-8fbb-47a1-b808-bb668b96db29",
#         "private": false,
#         "relationships_as_object": [],
#         "relationships_as_subject": [],
#         "state": "active",
#         "title": "Vacunación por Covid-19",
#         "type": "dataset",
#         "update_frequency": "1",
#         "url": "https://monitor.uruguaysevacuna.gub.uy/",
#         "version": "4.0"
#       },
#       {
#         "author": "Registro de productos",
#         "author_email": "productos@imm.gub.uy",
#         "creator_user_id": "a2cc884e-9228-4c67-9918-9c1e7e9e41f8",
#         "id": "fe7c02ea-d3a3-4a21-9b5d-8743a96ece70",
#         "isopen": true,
#         "license_id": "odc-uy",
#         "license_title": "Licencia de DAG de Uruguay",
#         "license_url": "https://www.gub.uy/agencia-gobierno-electronico-sociedad-informacion-conocimiento/sites/agencia-gobierno-electronico-sociedad-informacion-conocimiento/files/documentos/publicaciones/licencia_de_datos_abiertos_0.pdf",
#         "maintainer": "Mónica Méndez",
#         "maintainer_email": "monica.mendez@imm.gub.uy",
#         "metadata_created": "2024-03-08T22:45:52.824449",
#         "metadata_modified": "2024-05-15T21:16:13.495554",
#         "name": "habilitacion-y-registro-de-alimentos",
#         "notes": "**D.974.** (Habilitación y registro de alimentos) Los alimentos destinados al expendio o consumo de la población departamental elaborados, transportados o comercializados en el Departamento de Montevideo cualquiera sea su origen, deberán habilitarse y registrarse en el Servicio de Regulación Alimentaria previamente a su comercialización y transporte .\r\n\r\n**Habilitación:** es el acto por el cual el Servicio de Regulación Alimentaria autoriza que un alimento dado pueda ser objeto de elaboración, fraccionamiento industrial o importación para su comercialización por parte de determinada empresa. Dicha empresa debe contar con la habilitación bromatológica correspondiente. La habilitación es por 5 años y tiene carácter precario y revocable.\r\n\r\n**Registro:** es el acto por el cual el Servicio de Regulación Alimentaria le adjudica a dicho producto una vez habilitado un número. Este número de registro deberá estar siempre visible en el rótulo del producto.\r\n\r\n##Más Información\r\n - [Trámite de Registro de productos](http://www.montevideo.gub.uy/tramites/habilitacion/registro-de-alimentos)\r\n - Dependencia Responsable: [Regulación Alimentaria](https://montevideo.gub.uy/institucional/dependencias/regulacion-alimentaria)\r\n - Sub Dependencia: [Registro de Productos](http://www.montevideo.gub.uy/tramites/dependencias/registro-de-productos)\r\n\r\n##Preguntas frecuentes\r\n**¿Dónde puedo denunciar la existencia de un producto que se comercializa no estando el mismo habilitado?**\r\n\r\nLa denuncia puede hacerse al Centro de Información al Consumidor de Alimentos(CICA) del Servicio de Regulación Alimentaria de la siguiente forma:\r\n\r\n 1. Personalmente en el 3º piso de la I.M en las oficina del CICA en el horario de atención al público (10:15 a 15:45).\r\n 2. Por teléfono al 1950 2131, fuera del horario de atención telefónica (de 10.30 h a 15.45 h) su denuncia o consulta puede ser registrada en un contestador automático donde usted dispone de un minuto para expresar su inquietud.\r\n 3. Via e-mail [cica@imm.gub.uy](mailto:cica@imm.gub.uy) o por el [formulario de denuncias, quejas y sugerencias](http://www.montevideo.gub.uy/empresas/regulacion-alimentaria/denuncias-quejas-y-sugerencias)\r\n\r\n###¿Quién me puede asesorar más sobre estos temas?\r\n\r\nPor más información puede dirigirse a [El Centro de Información al Consumidor de Alimentos(CICA)](http://www.montevideo.gub.uy/empresas/regulacion-alimentaria/centro-de-informacion-al-consumidor-de-alimentos) del Servicio de Regulación Alimentaria",
#         "num_resources": 2,
#         "num_tags": 4,
#         "organization": {
#           "id": "d9026405-35be-410e-b251-492fba99c57d",
#           "name": "intendencia-montevideo",
#           "title": "Intendencia de Montevideo",
#           "type": "organization",
#           "description": "Intendencia de Montevideo.",
#           "image_url": "20140704-185843.302456logoIM190px.png",
#           "created": "2012-11-19T14:58:38.342943",
#           "is_organization": true,
#           "approval_status": "approved",
#           "state": "active"
#         },
#         "owner_org": "d9026405-35be-410e-b251-492fba99c57d",
#         "private": false,
#         "relationships_as_object": [],
#         "relationships_as_subject": [],
#         "state": "active",
#         "title": "Habilitación y registro de alimentos.",
#         "type": "dataset",
#         "update_frequency": "0",
#         "url": "",
#         "version": ""
#       },
#       {
#         "author": "Unidad Ejecutiva del Plan de Movilidad Urbana – Depto. Movilidad",
#         "author_email": "richard.delgado@imm.gub.uy",
#         "creator_user_id": "a2cc884e-9228-4c67-9918-9c1e7e9e41f8",
#         "id": "d8b30b0f-50c9-4d0c-aa06-a16e3a1c65c0",
#         "isopen": true,
#         "license_id": "odc-uy",
#         "license_title": "Licencia de DAG de Uruguay",
#         "license_url": "https://www.gub.uy/agencia-gobierno-electronico-sociedad-informacion-conocimiento/sites/agencia-gobierno-electronico-sociedad-informacion-conocimiento/files/documentos/publicaciones/licencia_de_datos_abiertos_0.pdf",
#         "maintainer": "Nicolas Morales",
#         "maintainer_email": "nicolas.morales@imm.gub.uy",
#         "metadata_created": "2024-03-08T22:45:43.314923",
#         "metadata_modified": "2024-04-30T13:19:54.263798",
#         "name": "bicicircuitos-bicicletarios",
#         "notes": "Juego de datos que contiene información georreferenciada de bicicircuitos (ciclovías, bicisendas, calles 30 km/h), bicicletarios, estaciones “Movete” de préstamo de bicicletas públicas y talleres de reparación .\r\n\r\nLos datos se generan diariamente por lo que siempre se cuenta con la información actualizada al día anterior.\r\n\r\nInformación proporcionada por la [Unidad Ejecutiva del Plan de Movilidad Urbana](http://www.montevideo.gub.uy/institucional/dependencias/unidad-ejecutiva-del-plan-de-movilidad-urbana) de la Intendencia de Montevideo",
#         "num_resources": 3,
#         "num_tags": 4,
#         "organization": {
#           "id": "d9026405-35be-410e-b251-492fba99c57d",
#           "name": "intendencia-montevideo",
#           "title": "Intendencia de Montevideo",
#           "type": "organization",
#           "description": "Intendencia de Montevideo.",
#           "image_url": "20140704-185843.302456logoIM190px.png",
#           "created": "2012-11-19T14:58:38.342943",
#           "is_organization": true,
#           "approval_status": "approved",
#           "state": "active"
#         },
#         "owner_org": "d9026405-35be-410e-b251-492fba99c57d",
#         "private": false,
#         "relationships_as_object": [],
#         "relationships_as_subject": [],
#         "state": "active",
#         "title": "Bicicircuitos, bicicletarios",
#         "type": "dataset",
#         "update_frequency": "0",
#         "url": "https://montevideo.gub.uy/mapa-montevideo-en-bici",
#         "version": ""
#       },
#       {
#         "author": "Regulación Alimentaria",
#         "author_email": "regulacion.alimentaria@imm.gub.uy",
#         "creator_user_id": "a2cc884e-9228-4c67-9918-9c1e7e9e41f8",
#         "id": "6cb8bfbd-eb70-4086-8209-316e478d08b7",
#         "isopen": false,
#         "license_id": "",
#         "license_title": "",
#         "maintainer": "",
#         "maintainer_email": "",
#         "metadata_created": "2024-03-08T22:45:16.846929",
#         "metadata_modified": "2024-04-26T13:25:55.925172",
#         "name": "empresas-alimentarias",
#         "notes": "Contiene información sobre empresas y locales alimentarios que fueron registrados por el Servicio de Regulación Alimentaria, habilitados o en trámite de habilitación.",
#         "num_resources": 1,
#         "num_tags": 3,
#         "organization": {
#           "id": "d9026405-35be-410e-b251-492fba99c57d",
#           "name": "intendencia-montevideo",
#           "title": "Intendencia de Montevideo",
#           "type": "organization",
#           "description": "Intendencia de Montevideo.",
#           "image_url": "20140704-185843.302456logoIM190px.png",
#           "created": "2012-11-19T14:58:38.342943",
#           "is_organization": true,
#           "approval_status": "approved",
#           "state": "active"
#         },
#         "owner_org": "d9026405-35be-410e-b251-492fba99c57d",
#         "private": false,
#         "relationships_as_object": [],
#         "relationships_as_subject": [],
#         "state": "active",
#         "title": "Empresas y locales alimentarios",
#         "type": "dataset",
#         "update_frequency": "0",
#         "url": "",
#         "version": ""
#       },
#       {
#         "author": "Nadia Acuña",
#         "author_email": "nacuna@fnr.gub.uy",
#         "creator_user_id": "e0945188-bf55-42a5-a95e-8eece14af787",
#         "id": "20105f4b-f455-4435-a619-211fa465c59d",
#         "isopen": true,
#         "license_id": "odc-uy",
#         "license_title": "Licencia de DAG de Uruguay",
#         "license_url": "https://www.gub.uy/agencia-gobierno-electronico-sociedad-informacion-conocimiento/sites/agencia-gobierno-electronico-sociedad-informacion-conocimiento/files/documentos/publicaciones/licencia_de_datos_abiertos_0.pdf",
#         "maintainer": "Nadia Acuña",
#         "maintainer_email": "nacuna@fnr.gub.uy",
#         "metadata_created": "2019-03-07T17:19:03.695982",
#         "metadata_modified": "2024-04-25T14:51:51.432384",
#         "name": "fondo-nacional-de-recursos-gasto-por-tratamientos-fondo-nacional-de-recursos",
#         "notes": "A continuación se presenta la información del gasto realizado por año por tratamientos con medicamentos. Información historica del periodo 2016 a 2017. Actualmente no se cuenta con datos mas actualizados.",
#         "num_resources": 9,
#         "num_tags": 3,
#         "organization": {
#           "id": "03b022af-c6fc-4876-b66e-8ca285733e44",
#           "name": "fondo-nacional-de-recursos",
#           "title": "Fondo Nacional de Recursos",
#           "type": "organization",
#           "description": "El Fondo Nacional de Recursos (FNR) es una institución creada por el decreto Ley 14.897 con carácter de persona pública no estatal, que brinda cobertura financiera a procedimientos de medicina altamente especializada y a medicamentos de alto costo para toda la población residente en el país y usuaria del Sistema Nacional Integrado de Salud.",
#           "image_url": "2017-10-02-193751.059518LogotipoFNR.jpg",
#           "created": "2017-10-02T16:37:51.098312",
#           "is_organization": true,
#           "approval_status": "approved",
#           "state": "active"
#         },
#         "owner_org": "03b022af-c6fc-4876-b66e-8ca285733e44",
#         "private": false,
#         "relationships_as_object": [],
#         "relationships_as_subject": [],
#         "state": "active",
#         "title": "Gasto por Tratamientos con Medicamentos",
#         "type": "dataset",
#         "update_frequency": "-1",
#         "url": "https://catalogodatos.gub.uy/organization/fondo-nacional-de-recursos",
#         "version": "1"
#       },
#       {
#         "author": "Nadia Acuña",
#         "author_email": "nacuna@fnr.gub.uy",
#         "creator_user_id": "e0945188-bf55-42a5-a95e-8eece14af787",
#         "id": "abc90090-d74f-4c88-a98d-2b7f511e7b85",
#         "isopen": true,
#         "license_id": "odc-uy",
#         "license_title": "Licencia de DAG de Uruguay",
#         "license_url": "https://www.gub.uy/agencia-gobierno-electronico-sociedad-informacion-conocimiento/sites/agencia-gobierno-electronico-sociedad-informacion-conocimiento/files/documentos/publicaciones/licencia_de_datos_abiertos_0.pdf",
#         "maintainer": "Nadia Acuña",
#         "maintainer_email": "nacuna@fnr.gub.uy",
#         "metadata_created": "2019-04-04T17:54:15.841939",
#         "metadata_modified": "2024-04-25T14:43:35.700771",
#         "name": "fondo-nacional-de-recursos-solicitudes-de-prestaciones-fondo-nacional-de-recursos",
#         "notes": "A continuación se presenta la información sobre solicitudes de actos médicos y de inicios de tratamientos con medicamentos ingresados, por año en el período de 2016 a 2017. Actualmente no se cuenta con información mas actualizada.",
#         "num_resources": 8,
#         "num_tags": 4,
#         "organization": {
#           "id": "03b022af-c6fc-4876-b66e-8ca285733e44",
#           "name": "fondo-nacional-de-recursos",
#           "title": "Fondo Nacional de Recursos",
#           "type": "organization",
#           "description": "El Fondo Nacional de Recursos (FNR) es una institución creada por el decreto Ley 14.897 con carácter de persona pública no estatal, que brinda cobertura financiera a procedimientos de medicina altamente especializada y a medicamentos de alto costo para toda la población residente en el país y usuaria del Sistema Nacional Integrado de Salud.",
#           "image_url": "2017-10-02-193751.059518LogotipoFNR.jpg",
#           "created": "2017-10-02T16:37:51.098312",
#           "is_organization": true,
#           "approval_status": "approved",
#           "state": "active"
#         },
#         "owner_org": "03b022af-c6fc-4876-b66e-8ca285733e44",
#         "private": false,
#         "relationships_as_object": [],
#         "relationships_as_subject": [],
#         "state": "active",
#         "title": "Solicitudes de Prestaciones",
#         "type": "dataset",
#         "update_frequency": "-1",
#         "url": "https://catalogodatos.gub.uy/organization/fondo-nacional-de-recursos",
#         "version": "1"
#       },
#       {
#         "author": "Nadia Acuña",
#         "author_email": "nacuna@fnr.gub.uy",
#         "creator_user_id": "e0945188-bf55-42a5-a95e-8eece14af787",
#         "id": "2db182ac-213c-4f2c-ba4e-ec31d8de0a09",
#         "isopen": true,
#         "license_id": "odc-uy",
#         "license_title": "Licencia de DAG de Uruguay",
#         "license_url": "https://www.gub.uy/agencia-gobierno-electronico-sociedad-informacion-conocimiento/sites/agencia-gobierno-electronico-sociedad-informacion-conocimiento/files/documentos/publicaciones/licencia_de_datos_abiertos_0.pdf",
#         "maintainer": "Nadia Acuña",
#         "maintainer_email": "nacuna@fnr.gub.uy",
#         "metadata_created": "2019-02-27T19:33:10.140189",
#         "metadata_modified": "2024-04-25T14:41:27.382938",
#         "name": "fondo-nacional-de-recursos-gasto-por-actos-medicos-fondo-nacional-de-recursos",
#         "notes": "A continuación se presenta la información historica del gasto realizado por año por actos médicos en el periodo 2016 a 2018. Actualmente no se cuenta con datos mas actualizados.",
#         "num_resources": 9,
#         "num_tags": 5,
#         "organization": {
#           "id": "03b022af-c6fc-4876-b66e-8ca285733e44",
#           "name": "fondo-nacional-de-recursos",
#           "title": "Fondo Nacional de Recursos",
#           "type": "organization",
#           "description": "El Fondo Nacional de Recursos (FNR) es una institución creada por el decreto Ley 14.897 con carácter de persona pública no estatal, que brinda cobertura financiera a procedimientos de medicina altamente especializada y a medicamentos de alto costo para toda la población residente en el país y usuaria del Sistema Nacional Integrado de Salud.",
#           "image_url": "2017-10-02-193751.059518LogotipoFNR.jpg",
#           "created": "2017-10-02T16:37:51.098312",
#           "is_organization": true,
#           "approval_status": "approved",
#           "state": "active"
#         },
#         "owner_org": "03b022af-c6fc-4876-b66e-8ca285733e44",
#         "private": false,
#         "relationships_as_object": [],
#         "relationships_as_subject": [],
#         "state": "active",
#         "title": "Gasto por Actos Médicos",
#         "type": "dataset",
#         "update_frequency": "-1",
#         "url": "https://catalogodatos.gub.uy/organization/fondo-nacional-de-recursos",
#         "version": "1"
#       },
#       {
#         "author": "División Salud de la Intendencia de Montevideo",
#         "author_email": "division.salud@imm.gub.uy",
#         "creator_user_id": "a2cc884e-9228-4c67-9918-9c1e7e9e41f8",
#         "id": "e80a0b81-07b3-4fcc-8e42-a66926a71f54",
#         "isopen": true,
#         "license_id": "odc-uy",
#         "license_title": "Licencia de DAG de Uruguay",
#         "license_url": "https://www.gub.uy/agencia-gobierno-electronico-sociedad-informacion-conocimiento/sites/agencia-gobierno-electronico-sociedad-informacion-conocimiento/files/documentos/publicaciones/licencia_de_datos_abiertos_0.pdf",
#         "maintainer": "Daniela Lopez",
#         "maintainer_email": "daniela.matilde.lopez@imm.gub.uy",
#         "metadata_created": "2024-03-08T22:45:47.337324",
#         "metadata_modified": "2024-03-08T22:45:47.337330",
#         "name": "datos-de-los-servicios-de-policlinicas",
#         "notes": "Este conjunto de datos brinda la cantidad de atenciones realizadas para cada una de las policlínicas gestionadas por la Intendencia de Montevideo. Para cada una de dichas policlínicas, se indica por mes la cantidad de atenciones realizadas para las distintas especialidades como también las atenciones realizadas por sexo y franja etaria.",
#         "num_resources": 5,
#         "num_tags": 3,
#         "organization": {
#           "id": "d9026405-35be-410e-b251-492fba99c57d",
#           "name": "intendencia-montevideo",
#           "title": "Intendencia de Montevideo",
#           "type": "organization",
#           "description": "Intendencia de Montevideo.",
#           "image_url": "20140704-185843.302456logoIM190px.png",
#           "created": "2012-11-19T14:58:38.342943",
#           "is_organization": true,
#           "approval_status": "approved",
#           "state": "active"
#         },
#         "owner_org": "d9026405-35be-410e-b251-492fba99c57d",
#         "private": false,
#         "relationships_as_object": [],
#         "relationships_as_subject": [],
#         "state": "active",
#         "title": "Datos de los servicios de policlínicas",
#         "type": "dataset",
#         "update_frequency": "0",
#         "url": "",
#         "version": null
#       },
#       {
#         "author": "División Salud de la Intendencia de Montevideo",
#         "author_email": "division.salud@imm.gub.uy",
#         "creator_user_id": "a2cc884e-9228-4c67-9918-9c1e7e9e41f8",
#         "id": "54463712-b87f-4eae-9f71-e8621265769a",
#         "isopen": true,
#         "license_id": "odc-uy",
#         "license_title": "Licencia de DAG de Uruguay",
#         "license_url": "https://www.gub.uy/agencia-gobierno-electronico-sociedad-informacion-conocimiento/sites/agencia-gobierno-electronico-sociedad-informacion-conocimiento/files/documentos/publicaciones/licencia_de_datos_abiertos_0.pdf",
#         "maintainer": "Daniela Lopez",
#         "maintainer_email": "daniela.matilde.lopez@imm.gub.uy",
#         "metadata_created": "2024-03-08T22:45:10.823512",
#         "metadata_modified": "2024-03-08T22:45:10.823521",
#         "name": "vacunacion-gripe-covid-19",
#         "notes": "Número de dosis inoculadas en las policlínicas municipales en el marco de las campañas antigripal y Covid-19",
#         "num_resources": 3,
#         "num_tags": 4,
#         "organization": {
#           "id": "d9026405-35be-410e-b251-492fba99c57d",
#           "name": "intendencia-montevideo",
#           "title": "Intendencia de Montevideo",
#           "type": "organization",
#           "description": "Intendencia de Montevideo.",
#           "image_url": "20140704-185843.302456logoIM190px.png",
#           "created": "2012-11-19T14:58:38.342943",
#           "is_organization": true,
#           "approval_status": "approved",
#           "state": "active"
#         },
#         "owner_org": "d9026405-35be-410e-b251-492fba99c57d",
#         "private": false,
#         "relationships_as_object": [],
#         "relationships_as_subject": [],
#         "state": "active",
#         "title": "Vacunación Gripe, Covid-19",
#         "type": "dataset",
#         "update_frequency": "0",
#         "url": "",
#         "version": null
#       },
#       {
#         "author": "División Salud de la Intendencia de Montevideo",
#         "author_email": "division.salud@imm.gub.uy",
#         "creator_user_id": "a2cc884e-9228-4c67-9918-9c1e7e9e41f8",
#         "id": "4cf04cf0-3337-4ec9-b55e-d136a6865e81",
#         "isopen": true,
#         "license_id": "odc-uy",
#         "license_title": "Licencia de DAG de Uruguay",
#         "license_url": "https://www.gub.uy/agencia-gobierno-electronico-sociedad-informacion-conocimiento/sites/agencia-gobierno-electronico-sociedad-informacion-conocimiento/files/documentos/publicaciones/licencia_de_datos_abiertos_0.pdf",
#         "maintainer": "Daniela Lopez",
#         "maintainer_email": "daniela.matilde.lopez@imm.gub.uy",
#         "metadata_created": "2024-03-08T22:45:09.532918",
#         "metadata_modified": "2024-03-08T22:45:09.532927",
#         "name": "datos-covid-19",
#         "notes": "Este conjunto de datos presenta resultados de hisopados Covid -19 realizados por el equipo de Salud de la Intendencia Montevideo como la cantidad de casos positivos relevados y el seguimiento de los mismos de acuerdo a datos de la Unidad de Resolutividad y Enlace.\r\n\r\nPara todos los recursos la información se presenta de forma mensual a excepción de los datos históricos obtenidos previos al 30 de junio del 2021.",
#         "num_resources": 3,
#         "num_tags": 6,
#         "organization": {
#           "id": "d9026405-35be-410e-b251-492fba99c57d",
#           "name": "intendencia-montevideo",
#           "title": "Intendencia de Montevideo",
#           "type": "organization",
#           "description": "Intendencia de Montevideo.",
#           "image_url": "20140704-185843.302456logoIM190px.png",
#           "created": "2012-11-19T14:58:38.342943",
#           "is_organization": true,
#           "approval_status": "approved",
#           "state": "active"
#         },
#         "owner_org": "d9026405-35be-410e-b251-492fba99c57d",
#         "private": false,
#         "relationships_as_object": [],
#         "relationships_as_subject": [],
#         "state": "active",
#         "title": "Datos Covid-19",
#         "type": "dataset",
#         "update_frequency": "0",
#         "url": "",
#         "version": null
#       }
#     ],
#     "extras": [],
#     "tags": [],
#     "groups": []
#   }
# }

# %%
# Group Package Show
#
# Lista los datasets de un grupo dado
endpoint_suffix = 'group_package_show?id=salud'
url = build_url(endpoint_suffix)

pretty_print_json(do_get_request(url))
# Out:
# {
#   "help": "https://catalogodatos.gub.uy/es/api/3/action/help_show?name=group_package_show",
#   "success": true,
#   "result": [
#     {
#       "author": "Área Gobierno Electrónico",
#       "author_email": "agedatoscovid@msp.gub.uy",
#       "creator_user_id": "30e0c393-dec0-482c-b0fb-ad6a0a9cab3d",
#       "id": "e766fbf7-0cc5-4b9a-a093-b56e91e88133",
#       "isopen": true,
#       "license_id": "odc-uy",
#       "license_title": "Licencia de DAG de Uruguay",
#       "license_url": "https://www.gub.uy/agencia-gobierno-electronico-sociedad-informacion-conocimiento/sites/agencia-gobierno-electronico-sociedad-informacion-conocimiento/files/documentos/publicaciones/licencia_de_datos_abiertos_0.pdf",
#       "maintainer": "Área Gobierno Electrónico",
#       "maintainer_email": "agedatoscovid@msp.gub.uy",
#       "metadata_created": "2021-05-28T18:27:41.852926",
#       "metadata_modified": "2024-06-27T20:02:40.324548",
#       "name": "vacunacion-por-covid-19",
#       "notes": "Este conjunto de datos presenta diferentes recursos vinculados a la evolución del plan de vacunación Covid 19.\r\nContiene actos vacunales detallados y acumulados diarios de actos vacunales realizados, cantidad de agendados y en espera de agenda.\r\n\r\nSe agregan datos de la nueva franja etaria de 5 a 11 años a los datos del Histórico de actos vacunales.\r\n\r\nSe agregan datos de dosis 3 y 4 presentando totales diarios por tipo de vacuna, dosis, departamentos y rango etario en el Histórico de actos vacunales.",
#       "num_resources": 8,
#       "num_tags": 4,
#       "organization": {
#         "id": "8a74eecc-8fbb-47a1-b808-bb668b96db29",
#         "name": "msp",
#         "title": "Ministerio de Salud Publica",
#         "type": "organization",
#         "description": "Ministerio de Salud Pública.",
#         "image_url": "2020-08-04-132255.866985LOGO-MinSALUD.png",
#         "created": "2012-11-13T15:14:04.125121",
#         "is_organization": true,
#         "approval_status": "approved",
#         "state": "active"
#       },
#       "owner_org": "8a74eecc-8fbb-47a1-b808-bb668b96db29",
#       "private": false,
#       "state": "active",
#       "title": "Vacunación por Covid-19",
#       "type": "dataset",
#       "update_frequency": "1",
#       "url": "https://monitor.uruguaysevacuna.gub.uy/",
#       "version": "4.0",
#       "groups": [
#         {
#           "description": " ",
#           "display_name": "Salud",
#           "id": "bacb6a54-e593-4bcc-ba2e-8e50c5cbd611",
#           "image_display_url": "https://catalogodatos.gub.uy/uploads/group/2019-08-22-233845.717947salud.png",
#           "name": "salud",
#           "title": "Salud"
#         }
#       ],
#       "resources": [
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2021-05-28T18:46:03.790463",
#           "datastore_active": true,
#           "description": "Datos acumulados por día de los actos vacunales. Se presentan totales diarios por tipo de vacuna, dosis, departamentos y rango etario.",
#           "format": "XLSX",
#           "hash": "",
#           "id": "0bc949c5-aa3a-4af4-b66f-aadb8ead58d8",
#           "last_modified": "2024-06-27T20:02:34.757566",
#           "licence": "Licencia de DAG de Uruguay",
#           "metadata_modified": "2024-06-27T20:02:35.857615",
#           "mimetype": "application/vnd.openxmlformats-officedocument.spreadsheetml.sheet",
#           "mimetype_inner": null,
#           "name": "Historico de actos vacunales",
#           "package_id": "e766fbf7-0cc5-4b9a-a093-b56e91e88133",
#           "position": 0,
#           "qa": {
#             "resource_timestamp": null,
#             "archival_timestamp": "2022-05-31T11:26:49.400737",
#             "openness_score": 2,
#             "openness_score_reason": "Content of file appeared to be format \"XLS\" which receives openness score: 2.",
#             "format": "XLS",
#             "created": "2021-05-29T11:55:19.092319",
#             "updated": "2022-05-31T12:45:51.326554"
#           },
#           "resource_type": null,
#           "size": 697468,
#           "spatial_coverage": "Uruguay",
#           "state": "active",
#           "temporal_coverage": "Desde el 27/02/2021",
#           "update_frecuency": "1",
#           "url": "https://catalogodatos.gub.uy/dataset/e766fbf7-0cc5-4b9a-a093-b56e91e88133/resource/0bc949c5-aa3a-4af4-b66f-aadb8ead58d8/download/actos_vacunales.xlsx",
#           "url_type": "upload"
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2021-05-28T18:46:05.968306",
#           "datastore_active": false,
#           "description": "Datos acumulados por día de los actos vacunales. Se presentan totales diarios por tipo de vacuna, dosis, departamentos y rango etario.",
#           "format": "CSV",
#           "hash": "",
#           "id": "5c549ba0-126b-45e0-b43f-b0eea72cf2cf",
#           "last_modified": "2024-06-27T20:02:35.798600",
#           "licence": "Licencia de DAG de Uruguay",
#           "metadata_modified": "2024-06-27T20:02:39.543880",
#           "mimetype": "text/csv",
#           "mimetype_inner": null,
#           "name": "Historico de actos vacunales",
#           "package_id": "e766fbf7-0cc5-4b9a-a093-b56e91e88133",
#           "position": 1,
#           "qa": {
#             "resource_timestamp": null,
#             "archival_timestamp": "2022-05-31T11:26:50.161161",
#             "openness_score": 3,
#             "openness_score_reason": "Content of file appeared to be format \"CSV\" which receives openness score: 3.",
#             "format": "CSV",
#             "created": "2021-05-29T11:55:19.157013",
#             "updated": "2022-05-31T12:45:51.371210"
#           },
#           "resource_type": null,
#           "size": 483536,
#           "spatial_coverage": "Uruguay",
#           "state": "active",
#           "temporal_coverage": "Desde el 27/02/2021",
#           "update_frecuency": "1",
#           "url": "https://catalogodatos.gub.uy/dataset/e766fbf7-0cc5-4b9a-a093-b56e91e88133/resource/5c549ba0-126b-45e0-b43f-b0eea72cf2cf/download/actos_vacunales.csv",
#           "url_type": "upload"
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2021-05-28T18:46:08.303283",
#           "datastore_active": false,
#           "description": "Datos acumulados por día de los actos vacunales. Se presentan totales diarios por tipo de vacuna, dosis, departamentos y rango etario.",
#           "format": "XML",
#           "hash": "",
#           "id": "6906c06f-135c-4c64-b983-b9fbb42bf6ac",
#           "last_modified": "2024-06-27T20:02:39.500960",
#           "licence": "Licencia de DAG de Uruguay",
#           "metadata_modified": "2024-06-27T20:02:40.344084",
#           "mimetype": "application/xml",
#           "mimetype_inner": null,
#           "name": "Historico de actos vacunales",
#           "package_id": "e766fbf7-0cc5-4b9a-a093-b56e91e88133",
#           "position": 2,
#           "qa": {
#             "resource_timestamp": null,
#             "archival_timestamp": "2022-05-31T11:26:50.926425",
#             "openness_score": 3,
#             "openness_score_reason": "Content of file appeared to be format \"XML\" which receives openness score: 3.",
#             "format": "XML",
#             "created": "2021-05-29T11:55:19.172950",
#             "updated": "2022-05-31T12:45:51.384888"
#           },
#           "resource_type": null,
#           "size": 8422725,
#           "spatial_coverage": "Uruguay",
#           "state": "active",
#           "temporal_coverage": "Desde el 27/02/2021",
#           "update_frecuency": "1",
#           "url": "https://catalogodatos.gub.uy/dataset/e766fbf7-0cc5-4b9a-a093-b56e91e88133/resource/6906c06f-135c-4c64-b983-b9fbb42bf6ac/download/actos_vacunales.xml",
#           "url_type": "upload"
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2021-05-28T18:46:09.586758",
#           "datastore_active": true,
#           "description": "Metadatos de los actos vacunales",
#           "format": "JSON",
#           "hash": "",
#           "id": "e26f0e2e-7435-404a-b890-1301e325b838",
#           "last_modified": "2024-06-27T20:02:40.298264",
#           "licence": "Licencia de DAG de Uruguay",
#           "metadata_modified": "2024-06-27T20:02:40.344172",
#           "mimetype": "application/json",
#           "mimetype_inner": null,
#           "name": "Metadatos de historico de actos vacunales",
#           "package_id": "e766fbf7-0cc5-4b9a-a093-b56e91e88133",
#           "position": 3,
#           "qa": {
#             "resource_timestamp": null,
#             "archival_timestamp": "2022-05-31T11:26:51.742052",
#             "openness_score": 3,
#             "openness_score_reason": "Content of file appeared to be format \"CSV\" which receives openness score: 3.",
#             "format": "CSV",
#             "created": "2021-05-29T11:55:19.304870",
#             "updated": "2022-05-31T12:45:51.478676"
#           },
#           "resource_type": null,
#           "size": 45530,
#           "spatial_coverage": "Uruguay",
#           "state": "active",
#           "temporal_coverage": "Desde el 27/02/2021",
#           "update_frecuency": "1",
#           "url": "https://catalogodatos.gub.uy/dataset/e766fbf7-0cc5-4b9a-a093-b56e91e88133/resource/e26f0e2e-7435-404a-b890-1301e325b838/download/metadatos_actos_vacunales.json",
#           "url_type": "upload"
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2021-05-28T18:51:24.259883",
#           "datastore_active": true,
#           "description": "Histórico de cantidad de personas agendadas para dosis 1, dosis 2 y dosis de refuerzo por día. Este recurso incluye también datos de agendados a futuro y en espera a partir de la fecha de publicación.",
#           "format": "XLSX",
#           "hash": "",
#           "id": "d12a44e4-743c-4141-9897-4a3eccc84879",
#           "last_modified": "2024-05-14T16:05:13.913349",
#           "licence": "Licencia de DAG de Uruguay",
#           "metadata_modified": "2024-05-14T16:05:14.773499",
#           "mimetype": "application/vnd.openxmlformats-officedocument.spreadsheetml.sheet",
#           "mimetype_inner": null,
#           "name": "Agenda de vacunas",
#           "package_id": "e766fbf7-0cc5-4b9a-a093-b56e91e88133",
#           "position": 4,
#           "qa": {
#             "resource_timestamp": null,
#             "archival_timestamp": "2022-05-31T11:26:52.496352",
#             "openness_score": 2,
#             "openness_score_reason": "Content of file appeared to be format \"XLS\" which receives openness score: 2.",
#             "format": "XLS",
#             "created": "2021-05-29T11:55:19.327613",
#             "updated": "2022-05-31T12:45:51.559973"
#           },
#           "resource_type": null,
#           "size": 28521,
#           "spatial_coverage": "Uruguay",
#           "state": "active",
#           "temporal_coverage": "Desde 27/05/2021",
#           "update_frecuency": "1",
#           "url": "https://catalogodatos.gub.uy/dataset/e766fbf7-0cc5-4b9a-a093-b56e91e88133/resource/d12a44e4-743c-4141-9897-4a3eccc84879/download/datos_agenda.xlsx",
#           "url_type": "upload"
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2021-05-28T18:51:27.349739",
#           "datastore_active": true,
#           "description": "Histórico de cantidad de personas agendadas para dosis 1, dosis 2 y dosis de refuerzo por día. Este recurso incluye también datos de agendados a futuro y en espera a partir de la fecha de publicación.",
#           "format": "CSV",
#           "hash": "",
#           "id": "ab715989-7b62-4097-a3c1-2ee912705d97",
#           "last_modified": "2024-05-14T16:05:14.746811",
#           "licence": "Licencia de DAG de Uruguay",
#           "metadata_modified": "2024-05-14T16:05:15.874595",
#           "mimetype": "text/csv",
#           "mimetype_inner": null,
#           "name": "Agenda de vacunas",
#           "package_id": "e766fbf7-0cc5-4b9a-a093-b56e91e88133",
#           "position": 5,
#           "qa": {
#             "resource_timestamp": null,
#             "archival_timestamp": "2022-05-31T11:26:53.320737",
#             "openness_score": 3,
#             "openness_score_reason": "Content of file appeared to be format \"CSV\" which receives openness score: 3.",
#             "format": "CSV",
#             "created": "2021-05-29T11:55:19.352404",
#             "updated": "2022-05-31T12:45:51.612537"
#           },
#           "resource_type": null,
#           "size": 18437,
#           "spatial_coverage": "Uruguay",
#           "state": "active",
#           "temporal_coverage": "Desde 27/05/2021",
#           "update_frecuency": "1",
#           "url": "https://catalogodatos.gub.uy/dataset/e766fbf7-0cc5-4b9a-a093-b56e91e88133/resource/ab715989-7b62-4097-a3c1-2ee912705d97/download/datos_agenda.csv",
#           "url_type": "upload"
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2021-05-28T18:51:30.236945",
#           "datastore_active": false,
#           "description": "Histórico de cantidad de personas agendadas para dosis 1, dosis 2 y dosis de refuerzo por día. Este recurso incluye también datos de agendados a futuro y en espera a partir de la fecha de publicación.",
#           "format": "XML",
#           "hash": "",
#           "id": "109062fd-77bd-4a94-95c2-c8471f664aca",
#           "last_modified": "2024-05-14T16:05:15.844118",
#           "licence": "Licencia de DAG de Uruguay",
#           "metadata_modified": "2024-05-14T16:05:16.934517",
#           "mimetype": "application/xml",
#           "mimetype_inner": null,
#           "name": "Agenda de vacunas",
#           "package_id": "e766fbf7-0cc5-4b9a-a093-b56e91e88133",
#           "position": 6,
#           "qa": {
#             "resource_timestamp": null,
#             "archival_timestamp": "2022-05-31T11:26:54.105666",
#             "openness_score": 3,
#             "openness_score_reason": "Content of file appeared to be format \"XML\" which receives openness score: 3.",
#             "format": "XML",
#             "created": "2021-05-29T11:55:19.368551",
#             "updated": "2022-05-31T12:45:51.623605"
#           },
#           "resource_type": null,
#           "size": 218102,
#           "spatial_coverage": "Uruguay",
#           "state": "active",
#           "temporal_coverage": "Desde 27/05/2021",
#           "update_frecuency": "1",
#           "url": "https://catalogodatos.gub.uy/dataset/e766fbf7-0cc5-4b9a-a093-b56e91e88133/resource/109062fd-77bd-4a94-95c2-c8471f664aca/download/datos_agenda.xml",
#           "url_type": "upload"
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2021-05-28T18:51:31.508560",
#           "datastore_active": true,
#           "description": "Metadatos de agenda de vacunas.",
#           "format": "JSON",
#           "hash": "",
#           "id": "af73efe5-3804-4dfa-b6c4-ee5c8143eec0",
#           "last_modified": "2024-05-14T16:05:16.908406",
#           "licence": "Licencia de DAG de Uruguay",
#           "metadata_modified": "2024-05-14T17:02:39.393864",
#           "mimetype": "application/json",
#           "mimetype_inner": null,
#           "name": "Metadatos de agenda de vacunas",
#           "package_id": "e766fbf7-0cc5-4b9a-a093-b56e91e88133",
#           "position": 7,
#           "qa": {
#             "resource_timestamp": null,
#             "archival_timestamp": "2022-05-31T11:26:54.860939",
#             "openness_score": 3,
#             "openness_score_reason": "Content of file appeared to be format \"CSV\" which receives openness score: 3.",
#             "format": "CSV",
#             "created": "2021-05-29T11:55:19.448714",
#             "updated": "2022-05-31T12:45:51.662023"
#           },
#           "resource_type": null,
#           "size": 2248,
#           "spatial_coverage": "Uruguay",
#           "state": "active",
#           "temporal_coverage": "Desde 27/05/2021",
#           "update_frecuency": "1",
#           "url": "https://catalogodatos.gub.uy/dataset/e766fbf7-0cc5-4b9a-a093-b56e91e88133/resource/af73efe5-3804-4dfa-b6c4-ee5c8143eec0/download/metadatos_datos_agenda.json",
#           "url_type": "upload"
#         }
#       ],
#       "tags": [
#         {
#           "display_name": "Covid",
#           "id": "ddba937b-36df-4012-be2b-40e61110574c",
#           "name": "Covid",
#           "state": "active",
#           "vocabulary_id": null
#         },
#         {
#           "display_name": "Covid-19",
#           "id": "d84d72dd-778e-4f36-8866-19c6546b8bb0",
#           "name": "Covid-19",
#           "state": "active",
#           "vocabulary_id": null
#         },
#         {
#           "display_name": "SARS-CoV-2",
#           "id": "132aff02-02d3-41a1-af75-bf2b28c264ac",
#           "name": "SARS-CoV-2",
#           "state": "active",
#           "vocabulary_id": null
#         },
#         {
#           "display_name": "Vacunas",
#           "id": "2834cff5-375e-4a45-b65d-1f82a9e32e22",
#           "name": "Vacunas",
#           "state": "active",
#           "vocabulary_id": null
#         }
#       ],
#       "relationships_as_subject": [],
#       "relationships_as_object": []
#     },
#     {
#       "author": "Registro de productos",
#       "author_email": "productos@imm.gub.uy",
#       "creator_user_id": "a2cc884e-9228-4c67-9918-9c1e7e9e41f8",
#       "id": "fe7c02ea-d3a3-4a21-9b5d-8743a96ece70",
#       "isopen": true,
#       "license_id": "odc-uy",
#       "license_title": "Licencia de DAG de Uruguay",
#       "license_url": "https://www.gub.uy/agencia-gobierno-electronico-sociedad-informacion-conocimiento/sites/agencia-gobierno-electronico-sociedad-informacion-conocimiento/files/documentos/publicaciones/licencia_de_datos_abiertos_0.pdf",
#       "maintainer": "Mónica Méndez",
#       "maintainer_email": "monica.mendez@imm.gub.uy",
#       "metadata_created": "2024-03-08T22:45:52.824449",
#       "metadata_modified": "2024-05-15T21:16:13.495554",
#       "name": "habilitacion-y-registro-de-alimentos",
#       "notes": "**D.974.** (Habilitación y registro de alimentos) Los alimentos destinados al expendio o consumo de la población departamental elaborados, transportados o comercializados en el Departamento de Montevideo cualquiera sea su origen, deberán habilitarse y registrarse en el Servicio de Regulación Alimentaria previamente a su comercialización y transporte .\r\n\r\n**Habilitación:** es el acto por el cual el Servicio de Regulación Alimentaria autoriza que un alimento dado pueda ser objeto de elaboración, fraccionamiento industrial o importación para su comercialización por parte de determinada empresa. Dicha empresa debe contar con la habilitación bromatológica correspondiente. La habilitación es por 5 años y tiene carácter precario y revocable.\r\n\r\n**Registro:** es el acto por el cual el Servicio de Regulación Alimentaria le adjudica a dicho producto una vez habilitado un número. Este número de registro deberá estar siempre visible en el rótulo del producto.\r\n\r\n##Más Información\r\n - [Trámite de Registro de productos](http://www.montevideo.gub.uy/tramites/habilitacion/registro-de-alimentos)\r\n - Dependencia Responsable: [Regulación Alimentaria](https://montevideo.gub.uy/institucional/dependencias/regulacion-alimentaria)\r\n - Sub Dependencia: [Registro de Productos](http://www.montevideo.gub.uy/tramites/dependencias/registro-de-productos)\r\n\r\n##Preguntas frecuentes\r\n**¿Dónde puedo denunciar la existencia de un producto que se comercializa no estando el mismo habilitado?**\r\n\r\nLa denuncia puede hacerse al Centro de Información al Consumidor de Alimentos(CICA) del Servicio de Regulación Alimentaria de la siguiente forma:\r\n\r\n 1. Personalmente en el 3º piso de la I.M en las oficina del CICA en el horario de atención al público (10:15 a 15:45).\r\n 2. Por teléfono al 1950 2131, fuera del horario de atención telefónica (de 10.30 h a 15.45 h) su denuncia o consulta puede ser registrada en un contestador automático donde usted dispone de un minuto para expresar su inquietud.\r\n 3. Via e-mail [cica@imm.gub.uy](mailto:cica@imm.gub.uy) o por el [formulario de denuncias, quejas y sugerencias](http://www.montevideo.gub.uy/empresas/regulacion-alimentaria/denuncias-quejas-y-sugerencias)\r\n\r\n###¿Quién me puede asesorar más sobre estos temas?\r\n\r\nPor más información puede dirigirse a [El Centro de Información al Consumidor de Alimentos(CICA)](http://www.montevideo.gub.uy/empresas/regulacion-alimentaria/centro-de-informacion-al-consumidor-de-alimentos) del Servicio de Regulación Alimentaria",
#       "num_resources": 2,
#       "num_tags": 4,
#       "organization": {
#         "id": "d9026405-35be-410e-b251-492fba99c57d",
#         "name": "intendencia-montevideo",
#         "title": "Intendencia de Montevideo",
#         "type": "organization",
#         "description": "Intendencia de Montevideo.",
#         "image_url": "20140704-185843.302456logoIM190px.png",
#         "created": "2012-11-19T14:58:38.342943",
#         "is_organization": true,
#         "approval_status": "approved",
#         "state": "active"
#       },
#       "owner_org": "d9026405-35be-410e-b251-492fba99c57d",
#       "private": false,
#       "state": "active",
#       "title": "Habilitación y registro de alimentos.",
#       "type": "dataset",
#       "update_frequency": "0",
#       "url": "",
#       "version": "",
#       "extras": [
#         {
#           "key": "harvest_object_id",
#           "value": "060f9225-9b25-4b38-b0ab-1f9cade8c846"
#         },
#         {
#           "key": "harvest_source_id",
#           "value": "3fda661b-c43f-4348-971e-8bd65a3a71d1"
#         },
#         {
#           "key": "harvest_source_title",
#           "value": "intendencia-montevideo-prod"
#         }
#       ],
#       "groups": [
#         {
#           "description": " ",
#           "display_name": "Salud",
#           "id": "bacb6a54-e593-4bcc-ba2e-8e50c5cbd611",
#           "image_display_url": "https://catalogodatos.gub.uy/uploads/group/2019-08-22-233845.717947salud.png",
#           "name": "salud",
#           "title": "Salud"
#         }
#       ],
#       "resources": [
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2023-02-24T18:09:07.314665",
#           "datastore_active": false,
#           "description": "Descripción de campos del juego de datos.",
#           "format": "TXT",
#           "hash": "",
#           "id": "f8190159-3086-434c-a4f6-28e81280e0df",
#           "last_modified": null,
#           "metadata_modified": "2024-05-15T21:16:13.506473",
#           "mimetype": "text/plain",
#           "mimetype_inner": null,
#           "name": "Descripción de campos",
#           "package_id": "fe7c02ea-d3a3-4a21-9b5d-8743a96ece70",
#           "position": 0,
#           "resource_type": null,
#           "size": null,
#           "state": "active",
#           "url": "https://www.montevideo.gub.uy/sites/default/files/datos/v_productos_real.txt",
#           "url_type": null
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2023-02-24T18:13:55.648842",
#           "datastore_active": false,
#           "description": "Archivo de texto separado por coma con lista de productos registrados",
#           "format": "CSV",
#           "hash": "",
#           "id": "2d579a61-530f-4e6e-aceb-dcc5e65d7e84",
#           "last_modified": null,
#           "metadata_modified": "2024-05-15T21:16:13.506581",
#           "mimetype": "application/zip",
#           "mimetype_inner": null,
#           "name": "Productos registrados",
#           "package_id": "fe7c02ea-d3a3-4a21-9b5d-8743a96ece70",
#           "position": 1,
#           "resource_type": null,
#           "size": null,
#           "state": "active",
#           "url": "https://www.montevideo.gub.uy/sites/default/files/datos/v_productos_real.zip",
#           "url_type": null
#         }
#       ],
#       "tags": [
#         {
#           "display_name": "Alimentación",
#           "id": "bf121674-833d-4857-80c6-c3729e3cc88a",
#           "name": "Alimentación",
#           "state": "active",
#           "vocabulary_id": null
#         },
#         {
#           "display_name": "Habilitación",
#           "id": "5da8556a-cdbe-4b08-afd5-411a4b742966",
#           "name": "Habilitación",
#           "state": "active",
#           "vocabulary_id": null
#         },
#         {
#           "display_name": "Harvest",
#           "id": "2234c5bb-3ae1-4031-947a-63faa0a8d519",
#           "name": "Harvest",
#           "state": "active",
#           "vocabulary_id": null
#         },
#         {
#           "display_name": "registro",
#           "id": "f2890f97-3eab-4b48-8e0a-118765750382",
#           "name": "registro",
#           "state": "active",
#           "vocabulary_id": null
#         }
#       ],
#       "relationships_as_subject": [],
#       "relationships_as_object": []
#     },
#     {
#       "author": "Unidad Ejecutiva del Plan de Movilidad Urbana – Depto. Movilidad",
#       "author_email": "richard.delgado@imm.gub.uy",
#       "creator_user_id": "a2cc884e-9228-4c67-9918-9c1e7e9e41f8",
#       "id": "d8b30b0f-50c9-4d0c-aa06-a16e3a1c65c0",
#       "isopen": true,
#       "license_id": "odc-uy",
#       "license_title": "Licencia de DAG de Uruguay",
#       "license_url": "https://www.gub.uy/agencia-gobierno-electronico-sociedad-informacion-conocimiento/sites/agencia-gobierno-electronico-sociedad-informacion-conocimiento/files/documentos/publicaciones/licencia_de_datos_abiertos_0.pdf",
#       "maintainer": "Nicolas Morales",
#       "maintainer_email": "nicolas.morales@imm.gub.uy",
#       "metadata_created": "2024-03-08T22:45:43.314923",
#       "metadata_modified": "2024-04-30T13:19:54.263798",
#       "name": "bicicircuitos-bicicletarios",
#       "notes": "Juego de datos que contiene información georreferenciada de bicicircuitos (ciclovías, bicisendas, calles 30 km/h), bicicletarios, estaciones “Movete” de préstamo de bicicletas públicas y talleres de reparación .\r\n\r\nLos datos se generan diariamente por lo que siempre se cuenta con la información actualizada al día anterior.\r\n\r\nInformación proporcionada por la [Unidad Ejecutiva del Plan de Movilidad Urbana](http://www.montevideo.gub.uy/institucional/dependencias/unidad-ejecutiva-del-plan-de-movilidad-urbana) de la Intendencia de Montevideo",
#       "num_resources": 3,
#       "num_tags": 4,
#       "organization": {
#         "id": "d9026405-35be-410e-b251-492fba99c57d",
#         "name": "intendencia-montevideo",
#         "title": "Intendencia de Montevideo",
#         "type": "organization",
#         "description": "Intendencia de Montevideo.",
#         "image_url": "20140704-185843.302456logoIM190px.png",
#         "created": "2012-11-19T14:58:38.342943",
#         "is_organization": true,
#         "approval_status": "approved",
#         "state": "active"
#       },
#       "owner_org": "d9026405-35be-410e-b251-492fba99c57d",
#       "private": false,
#       "state": "active",
#       "title": "Bicicircuitos, bicicletarios",
#       "type": "dataset",
#       "update_frequency": "0",
#       "url": "https://montevideo.gub.uy/mapa-montevideo-en-bici",
#       "version": "",
#       "extras": [
#         {
#           "key": "harvest_object_id",
#           "value": "a64e19fe-60ab-4147-bc5b-53829d50743c"
#         },
#         {
#           "key": "harvest_source_id",
#           "value": "3fda661b-c43f-4348-971e-8bd65a3a71d1"
#         },
#         {
#           "key": "harvest_source_title",
#           "value": "intendencia-montevideo-prod"
#         }
#       ],
#       "groups": [
#         {
#           "description": " ",
#           "display_name": "Salud",
#           "id": "bacb6a54-e593-4bcc-ba2e-8e50c5cbd611",
#           "image_display_url": "https://catalogodatos.gub.uy/uploads/group/2019-08-22-233845.717947salud.png",
#           "name": "salud",
#           "title": "Salud"
#         },
#         {
#           "description": " ",
#           "display_name": "Transporte",
#           "id": "a7060f2b-a798-4e2a-b8f1-bff339979e04",
#           "image_display_url": "https://catalogodatos.gub.uy/uploads/group/2019-08-22-234030.071870transporte.png",
#           "name": "transporte",
#           "title": "Transporte"
#         }
#       ],
#       "resources": [
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2023-02-22T15:12:57.748548",
#           "datastore_active": false,
#           "description": "Trayectos de los Bicicircuitos presentes en Montevideo. Los bicicircuitos están categorizados en: Ciclovías (separación física en la calzada), Bicisenda (senda sobre vereda) o Calles 30 km/h",
#           "format": "SHP",
#           "hash": "",
#           "id": "46aa3e63-a3ab-4dca-b04f-b5f51abf44e3",
#           "last_modified": null,
#           "metadata_modified": "2024-04-30T13:19:54.275443",
#           "mimetype": null,
#           "mimetype_inner": null,
#           "name": "Trayectos de los Bicicircuitos",
#           "package_id": "d8b30b0f-50c9-4d0c-aa06-a16e3a1c65c0",
#           "position": 0,
#           "resource_type": null,
#           "size": null,
#           "state": "active",
#           "url": "http://intgis.montevideo.gub.uy/sit/php/common/datos/generar_zip2.php?nom_tab=v_bi_bicicircuitos&tipo=gis",
#           "url_type": null
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2023-02-22T15:14:49.365057",
#           "datastore_active": false,
#           "description": "Bicicletarios dónde se puede dejar “estacionada” la bicicleta particular. Se dispone información de la cantidad de módulos y si se encuentra en vereda o en calzada.",
#           "format": "SHP",
#           "hash": "",
#           "id": "d91f7cc2-7168-4dff-8142-e969d55114c4",
#           "last_modified": null,
#           "metadata_modified": "2024-04-30T13:19:54.275616",
#           "mimetype": null,
#           "mimetype_inner": null,
#           "name": "\"Estacionamiento” la bicicleta particular.",
#           "package_id": "d8b30b0f-50c9-4d0c-aa06-a16e3a1c65c0",
#           "position": 1,
#           "resource_type": null,
#           "size": null,
#           "state": "active",
#           "url": "http://intgis.montevideo.gub.uy/sit/php/common/datos/generar_zip2.php?nom_tab=v_bi_bicicletarios&tipo=gis",
#           "url_type": null
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2023-02-22T15:15:51.962651",
#           "datastore_active": false,
#           "description": "Descripción de los campos que contienen los diferentes archivos.",
#           "format": "TXT",
#           "hash": "",
#           "id": "cf645354-a4a5-406d-9d31-51fe1a524a7e",
#           "last_modified": "2023-04-18T19:43:53.432705",
#           "metadata_modified": "2024-04-30T13:19:54.275702",
#           "mimetype": "text/plain",
#           "mimetype_inner": null,
#           "name": "Descripción de campos",
#           "package_id": "d8b30b0f-50c9-4d0c-aa06-a16e3a1c65c0",
#           "position": 2,
#           "resource_type": null,
#           "size": 1894,
#           "state": "active",
#           "url": "https://ckan-data.montevideo.gub.uy/dataset/d8b30b0f-50c9-4d0c-aa06-a16e3a1c65c0/resource/cf645354-a4a5-406d-9d31-51fe1a524a7e/download/descripcion-de-campos.txt",
#           "url_type": null
#         }
#       ],
#       "tags": [
#         {
#           "display_name": "Harvest",
#           "id": "2234c5bb-3ae1-4031-947a-63faa0a8d519",
#           "name": "Harvest",
#           "state": "active",
#           "vocabulary_id": null
#         },
#         {
#           "display_name": "bicicletario",
#           "id": "337998d6-004a-4682-a496-c5beb6fc71a1",
#           "name": "bicicletario",
#           "state": "active",
#           "vocabulary_id": null
#         },
#         {
#           "display_name": "bicicletas",
#           "id": "7b627cdf-e676-4863-bc3c-d828e0bd85f8",
#           "name": "bicicletas",
#           "state": "active",
#           "vocabulary_id": null
#         },
#         {
#           "display_name": "movilidad",
#           "id": "2235bdcc-89a3-49ce-a251-dc80338d31d2",
#           "name": "movilidad",
#           "state": "active",
#           "vocabulary_id": null
#         }
#       ],
#       "relationships_as_subject": [],
#       "relationships_as_object": []
#     },
#     {
#       "author": "Regulación Alimentaria",
#       "author_email": "regulacion.alimentaria@imm.gub.uy",
#       "creator_user_id": "a2cc884e-9228-4c67-9918-9c1e7e9e41f8",
#       "id": "6cb8bfbd-eb70-4086-8209-316e478d08b7",
#       "isopen": false,
#       "license_id": "",
#       "license_title": "",
#       "maintainer": "",
#       "maintainer_email": "",
#       "metadata_created": "2024-03-08T22:45:16.846929",
#       "metadata_modified": "2024-04-26T13:25:55.925172",
#       "name": "empresas-alimentarias",
#       "notes": "Contiene información sobre empresas y locales alimentarios que fueron registrados por el Servicio de Regulación Alimentaria, habilitados o en trámite de habilitación.",
#       "num_resources": 1,
#       "num_tags": 3,
#       "organization": {
#         "id": "d9026405-35be-410e-b251-492fba99c57d",
#         "name": "intendencia-montevideo",
#         "title": "Intendencia de Montevideo",
#         "type": "organization",
#         "description": "Intendencia de Montevideo.",
#         "image_url": "20140704-185843.302456logoIM190px.png",
#         "created": "2012-11-19T14:58:38.342943",
#         "is_organization": true,
#         "approval_status": "approved",
#         "state": "active"
#       },
#       "owner_org": "d9026405-35be-410e-b251-492fba99c57d",
#       "private": false,
#       "state": "active",
#       "title": "Empresas y locales alimentarios",
#       "type": "dataset",
#       "update_frequency": "0",
#       "url": "",
#       "version": "",
#       "extras": [
#         {
#           "key": "harvest_object_id",
#           "value": "cf8db2e1-1668-40c3-86a5-3ceecc000781"
#         },
#         {
#           "key": "harvest_source_id",
#           "value": "3fda661b-c43f-4348-971e-8bd65a3a71d1"
#         },
#         {
#           "key": "harvest_source_title",
#           "value": "intendencia-montevideo-prod"
#         }
#       ],
#       "groups": [
#         {
#           "description": " ",
#           "display_name": "Salud",
#           "id": "bacb6a54-e593-4bcc-ba2e-8e50c5cbd611",
#           "image_display_url": "https://catalogodatos.gub.uy/uploads/group/2019-08-22-233845.717947salud.png",
#           "name": "salud",
#           "title": "Salud"
#         }
#       ],
#       "resources": [
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2024-01-26T16:16:53.591994",
#           "datastore_active": false,
#           "description": "Contiene información de empresas y locales alimentarios que fueron registrados por el Servicio de Regulación Alimentaria, habilitados o en trámite de habilitación.",
#           "format": "CSV",
#           "hash": "",
#           "id": "79773c9a-51db-4cdf-a794-0e5aaec34cd2",
#           "last_modified": "2024-01-26T16:16:53.570015",
#           "metadata_modified": "2024-04-26T13:25:55.936947",
#           "mimetype": "text/csv",
#           "mimetype_inner": null,
#           "name": "Empresas y locales alimentarios",
#           "package_id": "6cb8bfbd-eb70-4086-8209-316e478d08b7",
#           "position": 0,
#           "resource_type": null,
#           "size": 2308748,
#           "state": "active",
#           "url": "https://ckan-data.montevideo.gub.uy/dataset/6cb8bfbd-eb70-4086-8209-316e478d08b7/resource/79773c9a-51db-4cdf-a794-0e5aaec34cd2/download/empresaslocalesalimentarios.csv",
#           "url_type": null
#         }
#       ],
#       "tags": [
#         {
#           "display_name": "Alimentación",
#           "id": "bf121674-833d-4857-80c6-c3729e3cc88a",
#           "name": "Alimentación",
#           "state": "active",
#           "vocabulary_id": null
#         },
#         {
#           "display_name": "Harvest",
#           "id": "2234c5bb-3ae1-4031-947a-63faa0a8d519",
#           "name": "Harvest",
#           "state": "active",
#           "vocabulary_id": null
#         },
#         {
#           "display_name": "Regulación Alimentaria",
#           "id": "0212a5da-1b2c-41fd-876d-52bd90897eac",
#           "name": "Regulación Alimentaria",
#           "state": "active",
#           "vocabulary_id": null
#         }
#       ],
#       "relationships_as_subject": [],
#       "relationships_as_object": []
#     },
#     {
#       "author": "Nadia Acuña",
#       "author_email": "nacuna@fnr.gub.uy",
#       "creator_user_id": "e0945188-bf55-42a5-a95e-8eece14af787",
#       "id": "20105f4b-f455-4435-a619-211fa465c59d",
#       "isopen": true,
#       "license_id": "odc-uy",
#       "license_title": "Licencia de DAG de Uruguay",
#       "license_url": "https://www.gub.uy/agencia-gobierno-electronico-sociedad-informacion-conocimiento/sites/agencia-gobierno-electronico-sociedad-informacion-conocimiento/files/documentos/publicaciones/licencia_de_datos_abiertos_0.pdf",
#       "maintainer": "Nadia Acuña",
#       "maintainer_email": "nacuna@fnr.gub.uy",
#       "metadata_created": "2019-03-07T17:19:03.695982",
#       "metadata_modified": "2024-04-25T14:51:51.432384",
#       "name": "fondo-nacional-de-recursos-gasto-por-tratamientos-fondo-nacional-de-recursos",
#       "notes": "A continuación se presenta la información del gasto realizado por año por tratamientos con medicamentos. Información historica del periodo 2016 a 2017. Actualmente no se cuenta con datos mas actualizados.",
#       "num_resources": 9,
#       "num_tags": 3,
#       "organization": {
#         "id": "03b022af-c6fc-4876-b66e-8ca285733e44",
#         "name": "fondo-nacional-de-recursos",
#         "title": "Fondo Nacional de Recursos",
#         "type": "organization",
#         "description": "El Fondo Nacional de Recursos (FNR) es una institución creada por el decreto Ley 14.897 con carácter de persona pública no estatal, que brinda cobertura financiera a procedimientos de medicina altamente especializada y a medicamentos de alto costo para toda la población residente en el país y usuaria del Sistema Nacional Integrado de Salud.",
#         "image_url": "2017-10-02-193751.059518LogotipoFNR.jpg",
#         "created": "2017-10-02T16:37:51.098312",
#         "is_organization": true,
#         "approval_status": "approved",
#         "state": "active"
#       },
#       "owner_org": "03b022af-c6fc-4876-b66e-8ca285733e44",
#       "private": false,
#       "state": "active",
#       "title": "Gasto por Tratamientos con Medicamentos",
#       "type": "dataset",
#       "update_frequency": "-1",
#       "url": "https://catalogodatos.gub.uy/organization/fondo-nacional-de-recursos",
#       "version": "1",
#       "groups": [
#         {
#           "description": " ",
#           "display_name": "Salud",
#           "id": "bacb6a54-e593-4bcc-ba2e-8e50c5cbd611",
#           "image_display_url": "https://catalogodatos.gub.uy/uploads/group/2019-08-22-233845.717947salud.png",
#           "name": "salud",
#           "title": "Salud"
#         },
#         {
#           "description": "",
#           "display_name": "Transparencia",
#           "id": "8552e8e2-e342-43fe-ab27-4e3c50564f9b",
#           "image_display_url": "https://catalogodatos.gub.uy/uploads/group/2019-08-22-234010.387437transparencia.png",
#           "name": "transparencia",
#           "title": "Transparencia"
#         }
#       ],
#       "resources": [
#         {
#           "archiver": "{'is_broken_printable': 'Downloaded OK', 'updated': '2020-01-05T05:07:47.127006', 'cache_filepath': u'/var/lib/ckan/default/resources/042/ce4/3d-39ba-4be5-87a7-e1d71c4a36cf', 'last_success': '2020-01-05T05:07:47.127006', 'size': 56755L, 'is_broken': False, 'failure_count': 0, 'etag': None, 'status': 'Archived successfully', 'url_redirected_to': u'https://catalogodatos.gub.uy/dataset/20105f4b-f455-4435-a619-211fa465c59d/resource/042ce43d-39ba-4be5-87a7-e1d71c4a36cf/download/glosario_tratamientos.pdf', 'hash': u'93783032d32db134154da454a2151e0c59be3795', 'status_id': 0, 'reason': u'', 'last_modified': None, 'resource_timestamp': '2019-12-03T17:50:24.977923', 'mimetype': u'application/pdf', 'cache_url': u'https://catalogodatos.gub.uy/dataset/20105f4b-f455-4435-a619-211fa465c59d/resource/042ce43d-39ba-4be5-87a7-e1d71c4a36cf/download/glosario_tratamientos.pdf', 'created': '2019-03-08T04:19:01.148375', 'first_failure': None}",
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2019-03-07T18:36:55.499495",
#           "datastore_active": false,
#           "description": "Catálogo de palabras, expresiones y siglas utilizadas en los conjuntos de datos.",
#           "format": "PDF",
#           "hash": "",
#           "id": "042ce43d-39ba-4be5-87a7-e1d71c4a36cf",
#           "last_modified": "2019-03-07T18:36:55.419386",
#           "metadata_modified": "2024-04-25T14:45:59.307277",
#           "mimetype": "application/pdf",
#           "mimetype_inner": null,
#           "name": "Glosario",
#           "package_id": "20105f4b-f455-4435-a619-211fa465c59d",
#           "position": 0,
#           "qa": {
#             "resource_timestamp": null,
#             "archival_timestamp": "2022-05-31T08:00:18.913350",
#             "openness_score": 1,
#             "openness_score_reason": "Content of file appeared to be format \"PDF\" which receives openness score: 1.",
#             "format": "PDF",
#             "created": "2019-03-08T05:30:30.883652",
#             "updated": "2022-05-31T11:33:54.240137"
#           },
#           "resource_type": null,
#           "size": 56755,
#           "spatial_coverage": "Uruguay",
#           "spatial_ref_system": "",
#           "state": "active",
#           "temporal_coverage": "",
#           "update_frequency": "-1",
#           "url": "https://catalogodatos.gub.uy/dataset/20105f4b-f455-4435-a619-211fa465c59d/resource/042ce43d-39ba-4be5-87a7-e1d71c4a36cf/download/glosario_tratamientos.pdf",
#           "url_type": "upload"
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2019-12-03T17:50:02.930692",
#           "datastore_active": true,
#           "description": "Gasto realizado durante el año 2016 por Tratamientos con Medicamentos.",
#           "format": "CSV",
#           "hash": "",
#           "id": "40e4e358-985e-4554-b370-3c884c2056bc",
#           "last_modified": "2020-01-29T14:28:42.972327",
#           "metadata_modified": "2024-04-25T14:49:23.773820",
#           "mimetype": "text/csv",
#           "mimetype_inner": null,
#           "name": "Tratamientos con medicamentos - 2016",
#           "package_id": "20105f4b-f455-4435-a619-211fa465c59d",
#           "position": 1,
#           "qa": {
#             "resource_timestamp": null,
#             "archival_timestamp": "2022-05-31T08:00:17.148192",
#             "openness_score": 3,
#             "openness_score_reason": "Content of file appeared to be format \"CSV\" which receives openness score: 3.",
#             "format": "CSV",
#             "created": "2019-12-03T16:01:07.904310",
#             "updated": "2022-05-31T11:33:54.183453"
#           },
#           "resource_type": null,
#           "size": 1399033,
#           "spatial_coverage": "Uruguay",
#           "spatial_ref_system": "",
#           "state": "active",
#           "temporal_coverage": "2016",
#           "update_frequency": "-1",
#           "url": "https://catalogodatos.gub.uy/dataset/20105f4b-f455-4435-a619-211fa465c59d/resource/40e4e358-985e-4554-b370-3c884c2056bc/download/datos-gastos-por-tratamientos-fondo-nacional-de-recursos-2016.csv",
#           "url_type": "upload"
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2019-03-07T17:37:25.842772",
#           "datastore_active": true,
#           "description": "Gasto realizado durante el año 2016 por Tratamientos con Medicamentos.",
#           "format": "XLSX",
#           "hash": "",
#           "id": "612c3401-8e32-42f3-9f51-947a485662f1",
#           "last_modified": "2020-01-28T17:37:44.202896",
#           "metadata_modified": "2024-04-25T14:48:53.218251",
#           "mimetype": "application/vnd.openxmlformats-officedocument.spreadsheetml.sheet",
#           "mimetype_inner": null,
#           "name": "Tratamientos con medicamentos - 2016",
#           "package_id": "20105f4b-f455-4435-a619-211fa465c59d",
#           "position": 2,
#           "qa": {
#             "resource_timestamp": null,
#             "archival_timestamp": "2022-05-31T08:00:16.281258",
#             "openness_score": 2,
#             "openness_score_reason": "Content of file appeared to be format \"XLSX\" which receives openness score: 2.",
#             "format": "XLSX",
#             "created": "2019-03-08T05:30:30.861833",
#             "updated": "2022-05-31T11:33:54.128862"
#           },
#           "resource_type": null,
#           "size": 741599,
#           "spatial_coverage": "Uruguay",
#           "spatial_ref_system": "",
#           "state": "active",
#           "temporal_coverage": "2016",
#           "update_frequency": "-1",
#           "url": "https://catalogodatos.gub.uy/dataset/20105f4b-f455-4435-a619-211fa465c59d/resource/612c3401-8e32-42f3-9f51-947a485662f1/download/datos-gastos-por-tratamientos-fondo-nacional-de-recursos-2016.xlsx",
#           "url_type": "upload"
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2020-01-28T19:16:38.852369",
#           "datastore_active": false,
#           "description": "Gasto realizado durante el año 2016 por Tratamientos con Medicamentos.",
#           "format": "XML",
#           "hash": "",
#           "id": "a2e05a4b-1d3e-4899-92d6-c526c4c58f62",
#           "last_modified": "2020-01-28T19:16:38.772335",
#           "metadata_modified": "2024-04-25T14:49:59.501281",
#           "mimetype": "application/xml",
#           "mimetype_inner": null,
#           "name": "Tratamientos con medicamentos - 2016",
#           "package_id": "20105f4b-f455-4435-a619-211fa465c59d",
#           "position": 3,
#           "qa": {
#             "resource_timestamp": null,
#             "archival_timestamp": "2022-05-31T08:00:19.714467",
#             "openness_score": 3,
#             "openness_score_reason": "Content of file appeared to be format \"XML\" which receives openness score: 3.",
#             "format": "XML",
#             "created": "2020-01-29T16:52:55.267036",
#             "updated": "2022-05-31T11:33:54.251864"
#           },
#           "resource_type": null,
#           "size": 4534931,
#           "spatial_coverage": "Uruguay",
#           "spatial_ref_system": "",
#           "state": "active",
#           "temporal_coverage": "2016",
#           "update_frequency": "-1",
#           "url": "https://catalogodatos.gub.uy/dataset/20105f4b-f455-4435-a619-211fa465c59d/resource/a2e05a4b-1d3e-4899-92d6-c526c4c58f62/download/datos-gastos-por-tratamientos-fondo-nacional-de-recursos-2016.xml",
#           "url_type": "upload"
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2019-03-07T17:37:23.872859",
#           "datastore_active": true,
#           "description": "Datos descriptivos del gasto realizado durante el año 2016 por Tratamientos con Medicamentos.",
#           "format": "JSON",
#           "hash": "",
#           "id": "26667803-d222-40c1-a0dd-bac919c26a7a",
#           "last_modified": "2020-01-28T17:40:50.106116",
#           "metadata_modified": "2024-04-25T14:50:15.355305",
#           "mimetype": "application/json",
#           "mimetype_inner": null,
#           "name": "Metadatos de Tratamientos con medicamentos - 2016",
#           "package_id": "20105f4b-f455-4435-a619-211fa465c59d",
#           "position": 4,
#           "qa": {
#             "resource_timestamp": null,
#             "archival_timestamp": "2022-05-31T08:00:18.042218",
#             "openness_score": 3,
#             "openness_score_reason": "Content of file appeared to be format \"CSV\" which receives openness score: 3.",
#             "format": "CSV",
#             "created": "2019-03-08T05:30:30.801831",
#             "updated": "2022-05-31T11:33:54.228376"
#           },
#           "resource_type": null,
#           "size": 2608,
#           "spatial_coverage": "Uruguay",
#           "spatial_ref_system": "",
#           "state": "active",
#           "temporal_coverage": "2016",
#           "update_frequency": "-1",
#           "url": "https://catalogodatos.gub.uy/dataset/20105f4b-f455-4435-a619-211fa465c59d/resource/26667803-d222-40c1-a0dd-bac919c26a7a/download/datos-gastos-por-tratamientos-fondo-nacional-de-recursos-2016.json",
#           "url_type": "upload"
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
# ...
#           "cache_url": null,
#           "created": "2023-03-02T15:53:41.393289",
#           "datastore_active": false,
#           "description": "Presenta la cantidad de atenciones por período, policlínica y especialidad registradas en el Sistema de Gestión de Consultas. La actualización es mensual y se irá agregando a este juego el número de atenciones del siguiente mes. La publicación se actualiza a mes vencido.",
#           "format": "CSV",
#           "hash": "",
#           "id": "6421ebfe-f565-48c4-9157-dfc4306b439e",
#           "last_modified": "2023-05-03T19:59:26.897828",
#           "metadata_modified": "2024-03-08T22:45:47.328929",
#           "mimetype": "text/csv",
#           "mimetype_inner": null,
#           "name": "Nro de atenciones por especialidad - 2022",
#           "package_id": "e80a0b81-07b3-4fcc-8e42-a66926a71f54",
#           "position": 4,
#           "resource_type": null,
#           "size": 33428,
#           "state": "active",
#           "url": "https://ckan-data.montevideo.gub.uy/dataset/e80a0b81-07b3-4fcc-8e42-a66926a71f54/resource/6421ebfe-f565-48c4-9157-dfc4306b439e/download/cantatencionesporespecialidad2022.csv",
#           "url_type": null
#         }
#       ],
#       "tags": [
#         {
#           "display_name": "Atención en salud",
#           "id": "1dca9b04-c1dc-4af6-aed2-2b7325ab697a",
#           "name": "Atención en salud",
#           "state": "active",
#           "vocabulary_id": null
#         },
#         {
#           "display_name": "Harvest",
#           "id": "2234c5bb-3ae1-4031-947a-63faa0a8d519",
#           "name": "Harvest",
#           "state": "active",
#           "vocabulary_id": null
#         },
#         {
#           "display_name": "Salud",
#           "id": "82e648a8-fba4-4c74-bc2e-72499ac77cd9",
#           "name": "Salud",
#           "state": "active",
#           "vocabulary_id": null
#         }
#       ],
#       "relationships_as_subject": [],
#       "relationships_as_object": []
#     },
#     {
#       "author": "División Salud de la Intendencia de Montevideo",
#       "author_email": "division.salud@imm.gub.uy",
#       "creator_user_id": "a2cc884e-9228-4c67-9918-9c1e7e9e41f8",
#       "id": "54463712-b87f-4eae-9f71-e8621265769a",
#       "isopen": true,
#       "license_id": "odc-uy",
#       "license_title": "Licencia de DAG de Uruguay",
#       "license_url": "https://www.gub.uy/agencia-gobierno-electronico-sociedad-informacion-conocimiento/sites/agencia-gobierno-electronico-sociedad-informacion-conocimiento/files/documentos/publicaciones/licencia_de_datos_abiertos_0.pdf",
#       "maintainer": "Daniela Lopez",
#       "maintainer_email": "daniela.matilde.lopez@imm.gub.uy",
#       "metadata_created": "2024-03-08T22:45:10.823512",
#       "metadata_modified": "2024-03-08T22:45:10.823521",
#       "name": "vacunacion-gripe-covid-19",
#       "notes": "Número de dosis inoculadas en las policlínicas municipales en el marco de las campañas antigripal y Covid-19",
#       "num_resources": 3,
#       "num_tags": 4,
#       "organization": {
#         "id": "d9026405-35be-410e-b251-492fba99c57d",
#         "name": "intendencia-montevideo",
#         "title": "Intendencia de Montevideo",
#         "type": "organization",
#         "description": "Intendencia de Montevideo.",
#         "image_url": "20140704-185843.302456logoIM190px.png",
#         "created": "2012-11-19T14:58:38.342943",
#         "is_organization": true,
#         "approval_status": "approved",
#         "state": "active"
#       },
#       "owner_org": "d9026405-35be-410e-b251-492fba99c57d",
#       "private": false,
#       "state": "active",
#       "title": "Vacunación Gripe, Covid-19",
#       "type": "dataset",
#       "update_frequency": "0",
#       "url": "",
#       "version": null,
#       "extras": [
#         {
#           "key": "harvest_object_id",
#           "value": "9d58265b-1faf-495b-9210-e85c60f578f1"
#         },
#         {
#           "key": "harvest_source_id",
#           "value": "3fda661b-c43f-4348-971e-8bd65a3a71d1"
#         },
#         {
#           "key": "harvest_source_title",
#           "value": "intendencia-montevideo-prod"
#         }
#       ],
#       "groups": [
#         {
#           "description": " ",
#           "display_name": "Salud",
#           "id": "bacb6a54-e593-4bcc-ba2e-8e50c5cbd611",
#           "image_display_url": "https://catalogodatos.gub.uy/uploads/group/2019-08-22-233845.717947salud.png",
#           "name": "salud",
#           "title": "Salud"
#         }
#       ],
#       "resources": [
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2023-02-27T17:45:28.685138",
#           "datastore_active": false,
#           "description": "En este archivo se detalla el significado de cada campo.",
#           "format": "TXT",
#           "hash": "",
#           "id": "7062fd57-4ca1-43ca-9882-32d2e92984ff",
#           "last_modified": "2023-05-04T12:12:32.411830",
#           "metadata_modified": "2024-03-08T22:45:10.798203",
#           "mimetype": "text/plain",
#           "mimetype_inner": null,
#           "name": "Descripción de los campos",
#           "package_id": "54463712-b87f-4eae-9f71-e8621265769a",
#           "position": 0,
#           "resource_type": null,
#           "size": 584,
#           "state": "active",
#           "url": "https://ckan-data.montevideo.gub.uy/dataset/54463712-b87f-4eae-9f71-e8621265769a/resource/7062fd57-4ca1-43ca-9882-32d2e92984ff/download/metadata.txt",
#           "url_type": null
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2023-02-27T17:46:08.969389",
#           "datastore_active": false,
#           "description": "Número de dosis inoculadas en las policlínicas en el marco de la campaña antigripal.",
#           "format": "CSV",
#           "hash": "",
#           "id": "52ca2ec6-fae8-4324-90db-bc34ae86d73e",
#           "last_modified": "2023-05-04T12:11:43.327876",
#           "metadata_modified": "2024-03-08T22:45:10.800163",
#           "mimetype": "text/csv",
#           "mimetype_inner": null,
#           "name": "Vacunación Gripe",
#           "package_id": "54463712-b87f-4eae-9f71-e8621265769a",
#           "position": 1,
#           "resource_type": null,
#           "size": 4277,
#           "state": "active",
#           "url": "https://ckan-data.montevideo.gub.uy/dataset/54463712-b87f-4eae-9f71-e8621265769a/resource/52ca2ec6-fae8-4324-90db-bc34ae86d73e/download/vacunaciongripe.csv",
#           "url_type": null
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2023-02-27T17:47:37.943313",
#           "datastore_active": false,
#           "description": "Número de dosis inoculadas en las policlínicas en el marco de la campaña Covid-19. También se indica el número de dosis inoculados por el equipo móvil de salud.",
#           "format": "CSV",
#           "hash": "",
#           "id": "61d41062-f6f7-424f-bfdc-7e8223cba7d8",
#           "last_modified": "2023-05-04T12:11:12.743351",
#           "metadata_modified": "2024-03-08T22:45:10.802350",
#           "mimetype": "text/csv",
#           "mimetype_inner": null,
#           "name": "Vacunación Covid-19",
#           "package_id": "54463712-b87f-4eae-9f71-e8621265769a",
#           "position": 2,
#           "resource_type": null,
#           "size": 1015,
#           "state": "active",
#           "url": "https://ckan-data.montevideo.gub.uy/dataset/54463712-b87f-4eae-9f71-e8621265769a/resource/61d41062-f6f7-424f-bfdc-7e8223cba7d8/download/vacunacioncovid.csv",
#           "url_type": null
#         }
#       ],
#       "tags": [
#         {
#           "display_name": "Covid",
#           "id": "ddba937b-36df-4012-be2b-40e61110574c",
#           "name": "Covid",
#           "state": "active",
#           "vocabulary_id": null
#         },
#         {
#           "display_name": "Gripe",
#           "id": "6a1d6ea5-9f12-4d91-9d38-b63386fd0041",
#           "name": "Gripe",
#           "state": "active",
#           "vocabulary_id": null
#         },
#         {
#           "display_name": "Harvest",
#           "id": "2234c5bb-3ae1-4031-947a-63faa0a8d519",
#           "name": "Harvest",
#           "state": "active",
#           "vocabulary_id": null
#         },
#         {
#           "display_name": "Salud",
#           "id": "82e648a8-fba4-4c74-bc2e-72499ac77cd9",
#           "name": "Salud",
#           "state": "active",
#           "vocabulary_id": null
#         }
#       ],
#       "relationships_as_subject": [],
#       "relationships_as_object": []
#     },
#     {
#       "author": "División Salud de la Intendencia de Montevideo",
#       "author_email": "division.salud@imm.gub.uy",
#       "creator_user_id": "a2cc884e-9228-4c67-9918-9c1e7e9e41f8",
#       "id": "4cf04cf0-3337-4ec9-b55e-d136a6865e81",
#       "isopen": true,
#       "license_id": "odc-uy",
#       "license_title": "Licencia de DAG de Uruguay",
#       "license_url": "https://www.gub.uy/agencia-gobierno-electronico-sociedad-informacion-conocimiento/sites/agencia-gobierno-electronico-sociedad-informacion-conocimiento/files/documentos/publicaciones/licencia_de_datos_abiertos_0.pdf",
#       "maintainer": "Daniela Lopez",
#       "maintainer_email": "daniela.matilde.lopez@imm.gub.uy",
#       "metadata_created": "2024-03-08T22:45:09.532918",
#       "metadata_modified": "2024-03-08T22:45:09.532927",
#       "name": "datos-covid-19",
#       "notes": "Este conjunto de datos presenta resultados de hisopados Covid -19 realizados por el equipo de Salud de la Intendencia Montevideo como la cantidad de casos positivos relevados y el seguimiento de los mismos de acuerdo a datos de la Unidad de Resolutividad y Enlace.\r\n\r\nPara todos los recursos la información se presenta de forma mensual a excepción de los datos históricos obtenidos previos al 30 de junio del 2021.",
#       "num_resources": 3,
#       "num_tags": 6,
#       "organization": {
#         "id": "d9026405-35be-410e-b251-492fba99c57d",
#         "name": "intendencia-montevideo",
#         "title": "Intendencia de Montevideo",
#         "type": "organization",
#         "description": "Intendencia de Montevideo.",
#         "image_url": "20140704-185843.302456logoIM190px.png",
#         "created": "2012-11-19T14:58:38.342943",
#         "is_organization": true,
#         "approval_status": "approved",
#         "state": "active"
#       },
#       "owner_org": "d9026405-35be-410e-b251-492fba99c57d",
#       "private": false,
#       "state": "active",
#       "title": "Datos Covid-19",
#       "type": "dataset",
#       "update_frequency": "0",
#       "url": "",
#       "version": null,
#       "extras": [
#         {
#           "key": "harvest_object_id",
#           "value": "71cf9dfc-0f29-44e5-b806-a900df1a5e68"
#         },
#         {
#           "key": "harvest_source_id",
#           "value": "3fda661b-c43f-4348-971e-8bd65a3a71d1"
#         },
#         {
#           "key": "harvest_source_title",
#           "value": "intendencia-montevideo-prod"
#         }
#       ],
#       "groups": [
#         {
#           "description": " ",
#           "display_name": "Salud",
#           "id": "bacb6a54-e593-4bcc-ba2e-8e50c5cbd611",
#           "image_display_url": "https://catalogodatos.gub.uy/uploads/group/2019-08-22-233845.717947salud.png",
#           "name": "salud",
#           "title": "Salud"
#         }
#       ],
#       "resources": [
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2023-02-27T23:44:21.916539",
#           "datastore_active": false,
#           "description": "En este archivo se detalla el significado de cada campo.",
#           "format": "TXT",
#           "hash": "",
#           "id": "48132a1b-5187-4d9f-adad-9a1d36aff790",
#           "last_modified": "2023-05-03T19:58:03.634214",
#           "metadata_modified": "2024-03-08T22:45:09.497514",
#           "mimetype": "text/plain",
#           "mimetype_inner": null,
#           "name": "Descripción de los campos",
#           "package_id": "4cf04cf0-3337-4ec9-b55e-d136a6865e81",
#           "position": 0,
#           "resource_type": null,
#           "size": 1578,
#           "state": "active",
#           "url": "https://ckan-data.montevideo.gub.uy/dataset/4cf04cf0-3337-4ec9-b55e-d136a6865e81/resource/48132a1b-5187-4d9f-adad-9a1d36aff790/download/metadata.txt",
#           "url_type": null
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2023-02-27T23:45:21.419147",
#           "datastore_active": false,
#           "description": "Este recurso presenta la cantidad de resultados de Tests PCR Covid-19 positivos como también la cantidad de Tests de Antígenos. Para los Tests de Antígenos se presenta el total de tests realizados como también la cantidad de resultados positivos y negativos. Los datos obtenidos se basan en los tests realizados por las Policlínicas del Servicio de Atención a la Salud por Región como también por el Equipo Móvil de hisopados Región Oeste (coordinación RAP - ASSE -IM).",
#           "format": "CSV",
#           "hash": "",
#           "id": "013916b5-0062-4a8c-8e0b-5d6d0e85cbe6",
#           "last_modified": "2023-05-03T19:57:23.582829",
#           "metadata_modified": "2024-03-08T22:45:09.499669",
#           "mimetype": "text/csv",
#           "mimetype_inner": null,
#           "name": "Resultado de test PCR y Antígenos",
#           "package_id": "4cf04cf0-3337-4ec9-b55e-d136a6865e81",
#           "position": 1,
#           "resource_type": null,
#           "size": 2634,
#           "state": "active",
#           "url": "https://ckan-data.montevideo.gub.uy/dataset/4cf04cf0-3337-4ec9-b55e-d136a6865e81/resource/013916b5-0062-4a8c-8e0b-5d6d0e85cbe6/download/resultadohisopados.csv",
#           "url_type": null
#         },
#         {
#           "cache_last_updated": null,
#           "cache_url": null,
#           "created": "2023-02-27T23:46:11.919625",
#           "datastore_active": false,
#           "description": "Cantidad de usuarios Covid 19 positivos a los que se les realizó seguimiento en las Policlínicas y en la URE. Los seguimiento de cada periodo corresponden a los casos detectados en el periodo más casos detectados en periodos anteriores.",
#           "format": "CSV",
#           "hash": "",
#           "id": "d5ecc3b9-a7f4-46e4-b919-86fb4eec2ff7",
#           "last_modified": "2023-05-03T19:56:57.381502",
#           "metadata_modified": "2024-03-08T22:45:09.501886",
#           "mimetype": "text/csv",
#           "mimetype_inner": null,
#           "name": "Cantidad de seguimientos Covid-19 positivos",
#           "package_id": "4cf04cf0-3337-4ec9-b55e-d136a6865e81",
#           "position": 2,
#           "resource_type": null,
#           "size": 1561,
#           "state": "active",
#           "url": "https://ckan-data.montevideo.gub.uy/dataset/4cf04cf0-3337-4ec9-b55e-d136a6865e81/resource/d5ecc3b9-a7f4-46e4-b919-86fb4eec2ff7/download/seguimientocovidpositivo.csv",
#           "url_type": null
#         }
#       ],
#       "tags": [
#         {
#           "display_name": "Coronavirus",
#           "id": "e28bc263-de16-47b1-9624-ea58fd5a54ee",
#           "name": "Coronavirus",
#           "state": "active",
#           "vocabulary_id": null
#         },
#         {
#           "display_name": "Covid",
#           "id": "ddba937b-36df-4012-be2b-40e61110574c",
#           "name": "Covid",
#           "state": "active",
#           "vocabulary_id": null
#         },
#         {
#           "display_name": "Harvest",
#           "id": "2234c5bb-3ae1-4031-947a-63faa0a8d519",
#           "name": "Harvest",
#           "state": "active",
#           "vocabulary_id": null
#         },
#         {
#           "display_name": "Hisopados",
#           "id": "befd4896-1f13-4a8d-aed6-abcd8c00bb2b",
#           "name": "Hisopados",
#           "state": "active",
#           "vocabulary_id": null
#         },
#         {
#           "display_name": "SARS-Cov2",
#           "id": "e1aee537-18e4-4928-8080-58ee5f3141bb",
#           "name": "SARS-Cov2",
#           "state": "active",
#           "vocabulary_id": null
#         },
#         {
#           "display_name": "Salud",
#           "id": "82e648a8-fba4-4c74-bc2e-72499ac77cd9",
#           "name": "Salud",
#           "state": "active",
#           "vocabulary_id": null
#         }
#       ],
#       "relationships_as_subject": [],
#       "relationships_as_object": []
#     }
#   ]
# }

# %%
# Organization List
#
# Lista las organizaciones del catalogo de datos. Son las entidades que suben información
# a el data lake.
# También hay un Organization show que muestra información de las organizaciones, como con los grupos.
endpoint_suffix = 'organization_list'
url = build_url(endpoint_suffix)

pretty_print_json(do_get_request(url))
# Out:
# {
#   "help": "https://catalogodatos.gub.uy/es/api/3/action/help_show?name=organization_list",
#   "success": true,
#   "result": [
#     "acau",
#     "agesic",
#     "ancap",
#     "anep",
#     "acce",
#     "banco-central-del-uruguay",
#     "banco-de-la-republica-oriental-del-uruguay",
#     "centro_ceibal",
#     "cei",
#     "ces",
#     "correo",
#     "corte-electoral",
#     "creative-commons-uruguay",
#     "data",
#     "defensa-del-consumidor",
#     "dinacia",
#     "direccion-nacional-de-catastro",
#     "dna",
#     "educacion-permanente-udelar",
#     "facultad-de-ciencias-economicas-y-de-administracion-departamento-de-documentacion-y-biblioteca",
#     "facultad-de-psicologia",
#     "fiscalia-general-de-la-nacion",
#     "fondo-nacional-de-recursos",
#     "ide",
#     "inau",
#     "ine",
#     "inia",
#     "instituto-nacional-de-colonizacion",
#     "intendencia-de-canelones",
#     "intendencia-de-durazno",
#     "intendencia-de-florida",
#     "intendencia-montevideo",
#     "idp",
#     "intendencia-de-rocha",
#     "intendencia-de-san-jose",
#     "inumet",
#     "junta-departamental-de-florida",
#     "junta-departamental-de-maldonado",
#     "la-diaria",
#     "latu",
#     "mgap",
#     "mides",
#     "ambiente",
#     "miem",
#     "tic-ministerio-del-interior",
#     "msp",
#     "ministerio-de-transporte-y-obras-publicas",
#     "ministerio-de-turismo",
#     "museo-nacional-de-artes-visuales",
#     "opp",
#     "onsc",
#     "parlamento-uruguayo",
#     "suprema-corte-de-justicia",
#     "sinae01",
#     "uaip",
#     "unasev",
#     "urcdp",
#     "ursea",
#     "ursec",
#     "uruguay-atp",
#     "ute"
#   ]
# }

# %%
# Resource Show
#
# Un resource es parte de un package, pueden ser los metadatos o la información en un formato
# en especifico (csv, xml, json).
# Muestra toda la info de un resource dando su ID
endpoint_suffix = 'resource_show?id=7f0d6b75-13d2-4872-a5aa-9ab7d4aaffd0'
url = build_url(endpoint_suffix)

pretty_print_json(do_get_request(url))
# Out:
# {
#   "help": "https://catalogodatos.gub.uy/es/api/3/action/help_show?name=resource_show",
#   "success": true,
#   "result": {
#     "archiver": "{'is_broken_printable': 'Downloaded OK', 'updated': '2020-07-21T09:18:41.814617', 'cache_filepath': u'/var/lib/ckan/default/resources/7f0/d6b/75-13d2-4872-a5aa-9ab7d4aaffd0', 'last_success': '2020-07-21T09:18:41.814617', 'size': 5461L, 'is_broken': False, 'failure_count': 0, 'etag': None, 'status': 'Archived successfully', 'url_redirected_to': u'https://catalogodatos.gub.uy/dataset/0da96d3c-6904-45f1-aeda-39a6be807f96/resource/7f0d6b75-13d2-4872-a5aa-9ab7d4aaffd0/download/metadatos_ursea-base_de_autorizaciones.json', 'hash': u'2cbfa032adf54563cb1b16ead201eadc51bee20b', 'status_id': 0, 'reason': u'', 'last_modified': None, 'resource_timestamp': '2019-12-17T14:18:16.163822', 'mimetype': u'application/json', 'cache_url': u'https://catalogodatos.gub.uy/dataset/0da96d3c-6904-45f1-aeda-39a6be807f96/resource/7f0d6b75-13d2-4872-a5aa-9ab7d4aaffd0/download/metadatos_ursea-base_de_autorizaciones.json', 'created': '2019-12-18T07:18:05.812575', 'first_failure': None}",
#     "cache_last_updated": null,
#     "cache_url": null,
#     "created": "2019-12-17T14:18:14.812414",
#     "datastore_active": false,
#     "description": "Descripción de las características de los productos eléctricos autorizados según RSPEBT. ",
#     "format": "JSON",
#     "hash": "",
#     "id": "7f0d6b75-13d2-4872-a5aa-9ab7d4aaffd0",
#     "last_modified": "2019-12-17T14:18:14.751859",
#     "metadata_modified": "2019-12-17T14:18:14.812414",
#     "mimetype": "application/json",
#     "mimetype_inner": null,
#     "name": "Metadatos de atributos de la Base de Productos Autorizados RSPEBT",
#     "package_id": "0da96d3c-6904-45f1-aeda-39a6be807f96",
#     "position": 0,
#     "qa": {
#       "resource_timestamp": null,
#       "archival_timestamp": "2022-05-31T11:25:29.647533",
#       "openness_score": 3,
#       "openness_score_reason": "Content of file appeared to be format \"CSV\" which receives openness score: 3.",
#       "format": "CSV",
#       "created": "2019-12-18T08:26:54.840793",
#       "updated": "2022-05-31T12:45:20.767531"
#     },
#     "resource_type": null,
#     "size": 5461,
#     "state": "active",
#     "url": "https://catalogodatos.gub.uy/dataset/0da96d3c-6904-45f1-aeda-39a6be807f96/resource/7f0d6b75-13d2-4872-a5aa-9ab7d4aaffd0/download/metadatos_ursea-base_de_autorizaciones.json",
#     "url_type": "upload"
#   }
# }

# %%
# Datastore Search
#
# Busca por resource, la información contenida en el mismo incluyendo metadatos estructurales (fields)
# Se puede especificar la cantidad de rows a recuperar
endpoint_suffix = 'datastore_search?resource_id=dec0a55d-1d86-4100-88ec-fc8dad06a363&limit=3'
url = build_url(endpoint_suffix)

pretty_print_json(do_get_request(url))
# Out:
# {
#   "help": "https://catalogodatos.gub.uy/es/api/3/action/help_show?name=datastore_search",
#   "success": true,
#   "result": {
#     "include_total": true,
#     "limit": 3,
#     "records_format": "objects",
#     "resource_id": "dec0a55d-1d86-4100-88ec-fc8dad06a363",
#     "total_estimation_threshold": null,
#     "records": [
#       {
#         "_id": 1,
#         "ID": 10,
#         "Sexo": 0,
#         "Edad": 46,
#         "Lugar_Nac": 91,
#         "Dep_Nac": 911,
#         "Localidad": "Colon",
#         "País": " ",
#         "Lugar_residencia_15a": 101,
#         "Departamento_15a": 911,
#         "Localidad_15a": "Colon",
#         "País_15a": " ",
#         "Lugar_residencia_CC": 111,
#         "Deptartamento_CC": "911",
#         "Localidad_CC": "Colon",
#         "País_CC": " ",
#         "Lugar_residencia_actual": 121,
#         "Deptartamento_RA": 913,
#         "Localidad_RA": "Lomas de Solymar",
#         "Estado_conyugal": 2132,
#         "Num_hijos": 0,
#         "Padres_Ud": 0,
#         "Cónyuge_comp_Ud": 1,
#         "Cónyuge_padres_Ud": 0,
#         "Hijos_Ud": 0,
#         "Hermanos_Ud": 0,
#         "Abuelos_Ud": 0,
#         "Suegros_Ud": 0,
#         "Otros_Familiares_Ud": 1,
#         "Otras_Personas_Ud": 0,
#         "Único_percibe_ingresos_hogar": 1.611,
#         "Vivienda_Ud_es": 2.175,
#         "Titulado_Uy": 3.18,
#         "Centro_estudio_T": 3.181,
#         "Centro_estudio_E": " ",
#         "País_D": " ",
#         "Año_comienzo_carrera": 1.987,
#         "Año_grad": 2.012,
#         "Máximo_niv_educativo": 3.211,
#         "Nombre_C": " ",
#         "Nombre_Inst": " ",
#         "País_E": " ",
#         "Por_qué_no_posgrado": 3.233,
#         "Próximos_tres_años_posgrado": 3.241,
#         "Tipo_estudio_posgrado": 2.412,
#         "Áreas_interés_formacion_1": "Primera Infancia",
#         "Áreas_interés_formacion_2": " ",
#         "Nro_trabajos": 243,
#         "Buscando_trabajo_N": null,
#         "Buscando_otro_trabajo_T": 2.611,
#         "Razón_busca_otro_trabajo": null,
#         "Posición_Ocupacional": 4.242,
#         "Sector": 42.421,
#         "Razón_trabaja_más_un_lugar": 261,
#         "Tiempo_más_un_lugar": 271,
#         "Cuánto_hace_busca_trabajo": null,
#         "Tiempo_trabaja_ininterrumpida": "25",
#         "Hs_promedio_trab_semana": "32",
#         "Ingresos_mensuales_pesos_último_año": 5283,
#         "Aprox_porcentaje_ingreso_hogar_aportado_Ud": 5.293,
#         "Área_inser_1": 63.306,
#         "Área_inser_2": null,
#         "Área_inser_3": null,
#         "Área_inser_4": null,
#         "Otras_áreas": "Docente en UTU"
#       },
#       {
#         "_id": 2,
#         "ID": 88,
#         "Sexo": 0,
#         "Edad": 25,
#         "Lugar_Nac": 91,
#         "Dep_Nac": 913,
#         "Localidad": "Las Piedras",
#         "País": " ",
#         "Lugar_residencia_15a": 101,
#         "Departamento_15a": 911,
#         "Localidad_15a": "Colón",
#         "País_15a": " ",
#         "Lugar_residencia_CC": 111,
#         "Deptartamento_CC": "911",
#         "Localidad_CC": "Colón",
#         "País_CC": " ",
#         "Lugar_residencia_actual": 121,
#         "Deptartamento_RA": 913,
#         "Localidad_RA": "La Paz",
#         "Estado_conyugal": 2131,
#         "Num_hijos": 1,
#         "Padres_Ud": 0,
#         "Cónyuge_comp_Ud": 0,
#         "Cónyuge_padres_Ud": 0,
#         "Hijos_Ud": 1,
#         "Hermanos_Ud": 0,
#         "Abuelos_Ud": 0,
#         "Suegros_Ud": 0,
#         "Otros_Familiares_Ud": 0,
#         "Otras_Personas_Ud": 0,
#         "Único_percibe_ingresos_hogar": 1.61,
#         "Vivienda_Ud_es": 2.171,
#         "Titulado_Uy": 3.18,
#         "Centro_estudio_T": 3.181,
#         "Centro_estudio_E": " ",
#         "País_D": " ",
#         "Año_comienzo_carrera": 2.007,
#         "Año_grad": 2.012,
#         "Máximo_niv_educativo": 3.211,
#         "Nombre_C": " ",
#         "Nombre_Inst": " ",
#         "País_E": " ",
#         "Por_qué_no_posgrado": 3.235,
#         "Próximos_tres_años_posgrado": 3.241,
#         "Tipo_estudio_posgrado": 2.412,
#         "Áreas_interés_formacion_1": "Educacional",
#         "Áreas_interés_formacion_2": "Sexología",
#         "Nro_trabajos": 241,
#         "Buscando_trabajo_N": null,
#         "Buscando_otro_trabajo_T": 2.61,
#         "Razón_busca_otro_trabajo": 261,
#         "Posición_Ocupacional": 4.246,
#         "Sector": 42.421,
#         "Razón_trabaja_más_un_lugar": null,
#         "Tiempo_más_un_lugar": null,
#         "Cuánto_hace_busca_trabajo": null,
#         "Tiempo_trabaja_ininterrumpida": "2",
#         "Hs_promedio_trab_semana": "25",
#         "Ingresos_mensuales_pesos_último_año": 5281,
#         "Aprox_porcentaje_ingreso_hogar_aportado_Ud": 5.293,
#         "Área_inser_1": null,
#         "Área_inser_2": null,
#         "Área_inser_3": null,
#         "Área_inser_4": null,
#         "Otras_áreas": " "
#       },
#       {
#         "_id": 3,
#         "ID": 89,
#         "Sexo": 0,
#         "Edad": 45,
#         "Lugar_Nac": 91,
#         "Dep_Nac": 9.115,
#         "Localidad": "Salto",
#         "País": " ",
#         "Lugar_residencia_15a": 101,
#         "Departamento_15a": 9.115,
#         "Localidad_15a": "Salto",
#         "País_15a": " ",
#         "Lugar_residencia_CC": 111,
#         "Deptartamento_CC": "911",
#         "Localidad_CC": "Montevideo",
#         "País_CC": " ",
#         "Lugar_residencia_actual": 121,
#         "Deptartamento_RA": 911,
#         "Localidad_RA": "Montevideo",
#         "Estado_conyugal": 2131,
#         "Num_hijos": 0,
#         "Padres_Ud": 0,
#         "Cónyuge_comp_Ud": 0,
#         "Cónyuge_padres_Ud": 0,
#         "Hijos_Ud": 0,
#         "Hermanos_Ud": 0,
#         "Abuelos_Ud": 0,
#         "Suegros_Ud": 0,
#         "Otros_Familiares_Ud": 0,
#         "Otras_Personas_Ud": 0,
#         "Único_percibe_ingresos_hogar": 1.61,
#         "Vivienda_Ud_es": 2.178,
#         "Titulado_Uy": 3.18,
#         "Centro_estudio_T": 3.182,
#         "Centro_estudio_E": " ",
#         "País_D": " ",
#         "Año_comienzo_carrera": 1.988,
#         "Año_grad": 1.996,
#         "Máximo_niv_educativo": 3.212,
#         "Nombre_C": "Curso Derecho y Género",
#         "Nombre_Inst": "Facultad de Derecho",
#         "País_E": "UY",
#         "Por_qué_no_posgrado": null,
#         "Próximos_tres_años_posgrado": 3.241,
#         "Tipo_estudio_posgrado": null,
#         "Áreas_interés_formacion_1": "Políticas Públicas",
#         "Áreas_interés_formacion_2": "Educación",
#         "Nro_trabajos": 241,
#         "Buscando_trabajo_N": null,
#         "Buscando_otro_trabajo_T": 2.61,
#         "Razón_busca_otro_trabajo": 263,
#         "Posición_Ocupacional": 42.41,
#         "Sector": 42.422,
#         "Razón_trabaja_más_un_lugar": null,
#         "Tiempo_más_un_lugar": null,
#         "Cuánto_hace_busca_trabajo": null,
#         "Tiempo_trabaja_ininterrumpida": "6",
#         "Hs_promedio_trab_semana": "30",
#         "Ingresos_mensuales_pesos_último_año": 5282,
#         "Aprox_porcentaje_ingreso_hogar_aportado_Ud": 5.294,
#         "Área_inser_1": null,
#         "Área_inser_2": null,
#         "Área_inser_3": null,
#         "Área_inser_4": null,
#         "Otras_áreas": "No ejerzo la profesión"
#       }
#     ],
#     "fields": [
#       {
#         "id": "_id",
#         "type": "int"
#       },
#       {
#         "id": "ID",
#         "type": "numeric"
#       },
#       {
#         "id": "Sexo",
#         "type": "numeric"
#       },
#       {
#         "id": "Edad",
#         "type": "numeric"
#       },
#       {
#         "id": "Lugar_Nac",
#         "type": "numeric"
#       },
#       {
#         "id": "Dep_Nac",
#         "type": "numeric"
#       },
#       {
#         "id": "Localidad",
#         "type": "text"
#       },
#       {
#         "id": "País",
#         "type": "text"
#       },
#       {
#         "id": "Lugar_residencia_15a",
#         "type": "numeric"
#       },
#       {
#         "id": "Departamento_15a",
#         "type": "numeric"
#       },
#       {
#         "id": "Localidad_15a",
#         "type": "text"
#       },
#       {
#         "id": "País_15a",
#         "type": "text"
#       },
#       {
#         "id": "Lugar_residencia_CC",
#         "type": "numeric"
#       },
#       {
#         "id": "Deptartamento_CC",
#         "type": "text"
#       },
#       {
#         "id": "Localidad_CC",
#         "type": "text"
#       },
#       {
#         "id": "País_CC",
#         "type": "text"
#       },
#       {
#         "id": "Lugar_residencia_actual",
#         "type": "numeric"
#       },
#       {
#         "id": "Deptartamento_RA",
#         "type": "numeric"
#       },
#       {
#         "id": "Localidad_RA",
#         "type": "text"
#       },
#       {
#         "id": "Estado_conyugal",
#         "type": "numeric"
#       },
#       {
#         "id": "Num_hijos",
#         "type": "numeric"
#       },
#       {
#         "id": "Padres_Ud",
#         "type": "numeric"
#       },
#       {
#         "id": "Cónyuge_comp_Ud",
#         "type": "numeric"
#       },
#       {
#         "id": "Cónyuge_padres_Ud",
#         "type": "numeric"
#       },
#       {
#         "id": "Hijos_Ud",
#         "type": "numeric"
#       },
#       {
#         "id": "Hermanos_Ud",
#         "type": "numeric"
#       },
#       {
#         "id": "Abuelos_Ud",
#         "type": "numeric"
#       },
#       {
#         "id": "Suegros_Ud",
#         "type": "numeric"
#       },
#       {
#         "id": "Otros_Familiares_Ud",
#         "type": "numeric"
#       },
#       {
#         "id": "Otras_Personas_Ud",
#         "type": "numeric"
#       },
#       {
#         "id": "Único_percibe_ingresos_hogar",
#         "type": "numeric"
#       },
#       {
#         "id": "Vivienda_Ud_es",
#         "type": "numeric"
#       },
#       {
#         "id": "Titulado_Uy",
#         "type": "numeric"
#       },
#       {
#         "id": "Centro_estudio_T",
#         "type": "numeric"
#       },
#       {
#         "id": "Centro_estudio_E",
#         "type": "text"
#       },
#       {
#         "id": "País_D",
#         "type": "text"
#       },
#       {
#         "id": "Año_comienzo_carrera",
#         "type": "numeric"
#       },
#       {
#         "id": "Año_grad",
#         "type": "numeric"
#       },
#       {
#         "id": "Máximo_niv_educativo",
#         "type": "numeric"
#       },
#       {
#         "id": "Nombre_C",
#         "type": "text"
#       },
#       {
#         "id": "Nombre_Inst",
#         "type": "text"
#       },
#       {
#         "id": "País_E",
#         "type": "text"
#       },
#       {
#         "id": "Por_qué_no_posgrado",
#         "type": "numeric"
#       },
#       {
#         "id": "Próximos_tres_años_posgrado",
#         "type": "numeric"
#       },
#       {
#         "id": "Tipo_estudio_posgrado",
#         "type": "numeric"
#       },
#       {
#         "id": "Áreas_interés_formacion_1",
#         "type": "text"
#       },
#       {
#         "id": "Áreas_interés_formacion_2",
#         "type": "text"
#       },
#       {
#         "id": "Nro_trabajos",
#         "type": "numeric"
#       },
#       {
#         "id": "Buscando_trabajo_N",
#         "type": "numeric"
#       },
#       {
#         "id": "Buscando_otro_trabajo_T",
#         "type": "numeric"
#       },
#       {
#         "id": "Razón_busca_otro_trabajo",
#         "type": "numeric"
#       },
#       {
#         "id": "Posición_Ocupacional",
#         "type": "numeric"
#       },
#       {
#         "id": "Sector",
#         "type": "numeric"
#       },
#       {
#         "id": "Razón_trabaja_más_un_lugar",
#         "type": "numeric"
#       },
#       {
#         "id": "Tiempo_más_un_lugar",
#         "type": "numeric"
#       },
#       {
#         "id": "Cuánto_hace_busca_trabajo",
#         "type": "numeric"
#       },
#       {
#         "id": "Tiempo_trabaja_ininterrumpida",
#         "type": "text"
#       },
#       {
#         "id": "Hs_promedio_trab_semana",
#         "type": "text"
#       },
#       {
#         "id": "Ingresos_mensuales_pesos_último_año",
#         "type": "numeric"
#       },
#       {
#         "id": "Aprox_porcentaje_ingreso_hogar_aportado_Ud",
#         "type": "numeric"
#       },
#       {
#         "id": "Área_inser_1",
#         "type": "numeric"
#       },
#       {
#         "id": "Área_inser_2",
#         "type": "numeric"
#       },
#       {
#         "id": "Área_inser_3",
#         "type": "numeric"
#       },
#       {
#         "id": "Área_inser_4",
#         "type": "numeric"
#       },
#       {
#         "id": "Otras_áreas",
#         "type": "text"
#       }
#     ],
#     "_links": {
#       "start": "/api/3/action/datastore_search?resource_id=dec0a55d-1d86-4100-88ec-fc8dad06a363&limit=3",
#       "next": "/api/3/action/datastore_search?resource_id=dec0a55d-1d86-4100-88ec-fc8dad06a363&limit=3&offset=3"
#     },
#     "total": 7543,
#     "total_was_estimated": false
#   }
# }

# %%
# Package Autocomplete
#
# Dado un String, devuelve todos los datasets que lo tienen contenido en el nombre o titulo.
# Existe este endpoint tambien para group, organization, tag..
endpoint_suffix = 'package_autocomplete?q=encuesta'
url = build_url(endpoint_suffix)

pretty_print_json(do_get_request(url))
# Out:
# {
#   "help": "https://catalogodatos.gub.uy/es/api/3/action/help_show?name=package_autocomplete",
#   "success": true,
#   "result": [
#     {
#       "name": "educacion-permanente-udelar-encuesta-a-docentes-2019",
#       "title": "Encuesta a docentes - 2019",
#       "match_field": "name",
#       "match_displayed": "educacion-permanente-udelar-encuesta-a-docentes-2019"
#     },
#     {
#       "name": "encuesta-origen-destino-montevideo",
#       "title": "Encuesta Origen-Destino Montevideo",
#       "match_field": "name",
#       "match_displayed": "encuesta-origen-destino-montevideo"
#     },
#     {
#       "name": "encuesta-de-turismo-receptivo",
#       "title": "Encuesta de Turismo Receptivo",
#       "match_field": "name",
#       "match_displayed": "encuesta-de-turismo-receptivo"
#     },
#     {
#       "name": "encuesta-de-cruceros",
#       "title": "Encuesta de Cruceros",
#       "match_field": "name",
#       "match_displayed": "encuesta-de-cruceros"
#     },
#     {
#       "name": "ine-encuesta-continua-de-hogares-2012",
#       "title": "Encuesta Continua de Hogares 2012",
#       "match_field": "name",
#       "match_displayed": "ine-encuesta-continua-de-hogares-2012"
#     },
#     {
#       "name": "ine-ech2011",
#       "title": "Encuesta Continua de Hogares 2011",
#       "match_field": "title",
#       "match_displayed": "Encuesta Continua de Hogares 2011 (ine-ech2011)"
#     },
#     {
#       "name": "miem-encuestas-consumos-energia-industrial",
#       "title": "Encuestas Consumos de Energía Industrial",
#       "match_field": "name",
#       "match_displayed": "miem-encuestas-consumos-energia-industrial"
#     },
#     {
#       "name": "ine-encuesta-continua-de-hogares-ano-2015",
#       "title": "Encuesta Continua de Hogares año 2015",
#       "match_field": "name",
#       "match_displayed": "ine-encuesta-continua-de-hogares-ano-2015"
#     },
#     {
#       "name": "onsc-encuesta_capacidades_fp",
#       "title": "Encuesta de capacidades de los funcionarios",
#       "match_field": "name",
#       "match_displayed": "onsc-encuesta_capacidades_fp"
#     },
#     {
#       "name": "ine-encuesta-continua-de-hogares-ano-2014",
#       "title": "Encuesta Continua de Hogares año 2014",
#       "match_field": "name",
#       "match_displayed": "ine-encuesta-continua-de-hogares-ano-2014"
#     }
#   ]
# }

# %% [markdown]
# Cabe destacar que para todos los elementos en general (package, resource, group, tag, organization) existen conjuntos de endpoints similares, los de show, que proveen información detallada, los de list, que listan estos elementos, los de search, que permiten aplicar filtros, etc. No abarcamos todos como ejemplo a modo de sintetizar.
#
# A pesar de que hay muchos más endpoints, omitimos todos los relacionados a usuarios, gestion de tareas y mantenimiento de organizaciones porque no es en lo que nos queremos enfocar. Y por otro lado, todas las acciones de creación, modificación y eliminación fueron omitidas porque requieren de permisos adicionales (cookie de auth) para poder pegarle a la API, tal y como se dijo al inicio. Suponemos que esto también excede nuestro alcance, sería raro que tuviesemos acceso de gestión directa sobre esta información sensible de las entidades gubernamentales.

# %% [markdown]
# # Obtención de Organigramas con transparencia activa

# %%
import json
from types import SimpleNamespace

# Podemos incluso hacer queries pidiendo solo packages que tengan ciertos tags asociados,
# en este caso buscamos los relacionados a "tierras"
endpoint_suffix = 'package_search?fq=tags:Organigrama'
url = build_url(endpoint_suffix)

response = do_get_request(url)

# Serializar JSON a Objeto
obj = json.loads(json.dumps(response), object_hook=lambda d: SimpleNamespace(**d))

# Niveles del Objeto serializado
#
# Result
## [Results]
### [Resources]
#### Buscar "format" CSV
#### Imprimir "url" e "id"

# Extraer los elementos que tienen el formato "CSV"
csv_resources = [
    resource
    for result in obj.result.results
    for resource in result.resources
    if resource.format == 'CSV'
]

# Crear una lista de cadenas con la URL y el ID
output_list = [f"url: {resource.url}, id: {resource.id}" for resource in csv_resources]

# Convertir la lista a una cadena
output_str = '\n'.join(output_list)

print(f"Un total de", obj.result.count, "recursos")
print(output_str)
# Out:
# Un total de 12 recursos
# url: https://catalogodatos.gub.uy/dataset/e0d6824c-0dde-4f22-8f06-343ba0f33d64/resource/0bb92ddf-01da-4336-812b-21488d8aeed5/download/organigrama-del-organismo.csv, id: 0bb92ddf-01da-4336-812b-21488d8aeed5
# url: https://catalogodatos.gub.uy/dataset/c355deb7-4ea2-4256-a116-f53560acd3a1/resource/b8cba44e-f5e3-48a8-868f-ba7b21b5c5d3/download/organigrama-del-organismo.csv, id: b8cba44e-f5e3-48a8-868f-ba7b21b5c5d3
# url: https://catalogodatos.gub.uy/dataset/42636d4d-e3b5-4eca-b107-d97baaefd9ab/resource/9694cce8-ca17-40f5-aee8-ffd4144290bc/download/datos-del-organigrama-del-organismo.csv, id: 9694cce8-ca17-40f5-aee8-ffd4144290bc
# url: https://catalogodatos.gub.uy/dataset/782f8962-5018-4df3-a6ca-9fcaf304b9bd/resource/4b58569a-0e04-4777-8fee-57a152d4340f/download/organigrama-del-organismo.csv, id: 4b58569a-0e04-4777-8fee-57a152d4340f
# url: https://catalogodatos.gub.uy/dataset/a7575d0a-9df2-42f3-9296-d61a8d33fd52/resource/a87ace2f-b75b-4406-b813-c7d21771db03/download/organigrama-ursec.csv, id: a87ace2f-b75b-4406-b813-c7d21771db03
# url: https://catalogodatos.gub.uy/dataset/81b34f21-5cee-4ca0-91f6-9c4cfe6c90a2/resource/892da481-d210-479c-9b5a-1c7f82d387dc/download/organigrama-uaip.csv, id: 892da481-d210-479c-9b5a-1c7f82d387dc
# url: https://catalogodatos.gub.uy/dataset/76dc279e-82ff-4f02-947f-8bcd7a19aaa1/resource/de2e4073-570f-4b79-bb7a-7d3dfec1c238/download/organigrama-miem-2023.csv, id: de2e4073-570f-4b79-bb7a-7d3dfec1c238
# url: https://catalogodatos.gub.uy/dataset/ff8c45f7-fe15-4e6e-b43f-4648bb3ab4e0/resource/06012849-ab0a-4b60-b9af-82386fccbf18/download/datos-del-organigrama.csv, id: 06012849-ab0a-4b60-b9af-82386fccbf18
# url: https://catalogodatos.gub.uy/dataset/ff8c45f7-fe15-4e6e-b43f-4648bb3ab4e0/resource/92bc37e9-42db-4d2d-afbc-a9442e7052c3/download/datos-del-organigrama.csv, id: 92bc37e9-42db-4d2d-afbc-a9442e7052c3
# url: https://catalogodatos.gub.uy/dataset/ff8c45f7-fe15-4e6e-b43f-4648bb3ab4e0/resource/c953437a-0a61-4d8b-bd46-fec567e0780e/download/datos-del-organigrama.csv, id: c953437a-0a61-4d8b-bd46-fec567e0780e
# url: https://catalogodatos.gub.uy/dataset/5823fb5b-139b-4851-aca1-bdba9e7c89eb/resource/c16f6539-0963-42d9-9a2e-6210c37a3ad4/download/datos_organigramalatu.csv, id: c16f6539-0963-42d9-9a2e-6210c37a3ad4
# url: https://catalogodatos.gub.uy/dataset/ad956bb2-cbc3-4e90-92f8-b2bbce366d43/resource/03d299c4-e8e0-45f0-9206-81984ca7b439/download/datos-del-organigrama-del-organismo.csv, id: 03d299c4-e8e0-45f0-9206-81984ca7b439
# url: https://catalogodatos.gub.uy/dataset/ad956bb2-cbc3-4e90-92f8-b2bbce366d43/resource/798f5e29-af23-47cc-8e9e-7fe7abb9484e/download/datos-organigrama-2020.csv, id: 798f5e29-af23-47cc-8e9e-7fe7abb9484e
# url: https://catalogodatos.gub.uy/dataset/ad956bb2-cbc3-4e90-92f8-b2bbce366d43/resource/212354b6-72dd-427c-9fcd-4b06cf21606d/download/datos-organigrama-2021.csv, id: 212354b6-72dd-427c-9fcd-4b06cf21606d
# url: https://catalogodatos.gub.uy/dataset/ad956bb2-cbc3-4e90-92f8-b2bbce366d43/resource/11238d12-4fa0-4c89-9f8f-075f33ae373e/download/datos-organigrama-2022.csv, id: 11238d12-4fa0-4c89-9f8f-075f33ae373e

# %%
# Para descargar los datasets recuperados
download_folder = "DownloadedDatasets"
os.makedirs(download_folder, exist_ok=True)

for resource in csv_resources:
   file_name = os.path.join(download_folder, f"file_{resource.id}.csv")
   file_response = requests.get(resource.url)

   if file_response.status_code == 200:
      with open(file_name, 'wb') as file:
        file.write(file_response.content)
      print(f"Downloaded {resource.url} to {file_name}")
   else:
      print(f"Failed to download {resource.url}")
# Out:
# Downloaded https://catalogodatos.gub.uy/es/api/3/action/package_search?fq=tags:Organigrama to DownloadedDatasets/file_0bb92ddf-01da-4336-812b-21488d8aeed5.csv
# Downloaded https://catalogodatos.gub.uy/es/api/3/action/package_search?fq=tags:Organigrama to DownloadedDatasets/file_b8cba44e-f5e3-48a8-868f-ba7b21b5c5d3.csv
# Downloaded https://catalogodatos.gub.uy/es/api/3/action/package_search?fq=tags:Organigrama to DownloadedDatasets/file_9694cce8-ca17-40f5-aee8-ffd4144290bc.csv
# Downloaded https://catalogodatos.gub.uy/es/api/3/action/package_search?fq=tags:Organigrama to DownloadedDatasets/file_4b58569a-0e04-4777-8fee-57a152d4340f.csv
# Downloaded https://catalogodatos.gub.uy/es/api/3/action/package_search?fq=tags:Organigrama to DownloadedDatasets/file_a87ace2f-b75b-4406-b813-c7d21771db03.csv
# Downloaded https://catalogodatos.gub.uy/es/api/3/action/package_search?fq=tags:Organigrama to DownloadedDatasets/file_892da481-d210-479c-9b5a-1c7f82d387dc.csv
# Downloaded https://catalogodatos.gub.uy/es/api/3/action/package_search?fq=tags:Organigrama to DownloadedDatasets/file_de2e4073-570f-4b79-bb7a-7d3dfec1c238.csv
# Downloaded https://catalogodatos.gub.uy/es/api/3/action/package_search?fq=tags:Organigrama to DownloadedDatasets/file_06012849-ab0a-4b60-b9af-82386fccbf18.csv
# Downloaded https://catalogodatos.gub.uy/es/api/3/action/package_search?fq=tags:Organigrama to DownloadedDatasets/file_92bc37e9-42db-4d2d-afbc-a9442e7052c3.csv
# Downloaded https://catalogodatos.gub.uy/es/api/3/action/package_search?fq=tags:Organigrama to DownloadedDatasets/file_c953437a-0a61-4d8b-bd46-fec567e0780e.csv
# Downloaded https://catalogodatos.gub.uy/es/api/3/action/package_search?fq=tags:Organigrama to DownloadedDatasets/file_c16f6539-0963-42d9-9a2e-6210c37a3ad4.csv
# Downloaded https://catalogodatos.gub.uy/es/api/3/action/package_search?fq=tags:Organigrama to DownloadedDatasets/file_03d299c4-e8e0-45f0-9206-81984ca7b439.csv
# Downloaded https://catalogodatos.gub.uy/es/api/3/action/package_search?fq=tags:Organigrama to DownloadedDatasets/file_798f5e29-af23-47cc-8e9e-7fe7abb9484e.csv
# Downloaded https://catalogodatos.gub.uy/es/api/3/action/package_search?fq=tags:Organigrama to DownloadedDatasets/file_212354b6-72dd-427c-9fcd-4b06cf21606d.csv
# Downloaded https://catalogodatos.gub.uy/es/api/3/action/package_search?fq=tags:Organigrama to DownloadedDatasets/file_11238d12-4fa0-4c89-9f8f-075f33ae373e.csv
